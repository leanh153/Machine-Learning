# %% [markdown]
# #Building a song recommender
#
#
# #Fire up GraphLab Create

# %%
import sklearn, pandas
import numpy as np

# %% [markdown]
# #Load music data

# %%
#song_data = graphlab.SFrame('song_data.gl/')
song_data = pandas.read_csv('song_data.csv')

# %% [markdown]
# ## Explore data
#
# Music data shows how many times a user listened to a song, as well as the details of the song.

# %%
song_data.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title         artist                             song
# 0         The Cove   Jack Johnson          The Cove - Jack Johnson
# 1  Entre Dos Aguas  Paco De Lucia  Entre Dos Aguas - Paco De Lucia
# 2         Stronger     Kanye West            Stronger - Kanye West
# 3   Constellations   Jack Johnson    Constellations - Jack Johnson
# 4     Learn To Fly   Foo Fighters      Learn To Fly - Foo Fighters

# %% [markdown]
# ##Showing the most popular songs in the dataset

# %%
#graphlab.canvas.set_target('ipynb')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#song_data['song'].show()
# most listened time on ONE user
best_songs = song_data.sort_values('listen_count', ascending=False).head(20)
counter_labels = best_songs['title']
counts = best_songs['listen_count']
counter_pos = np.arange(20)
plt.barh(counter_pos, counts)
plt.yticks(counter_pos, counter_labels)
plt.show()

# %%
len(song_data)
# Out:
# 1116609

# %% [markdown]
# ##Count number of unique users in the dataset

# %%
users = song_data['user_id'].unique()

# %%
len(users)
users
# Out:
# array(['b80344d063b5ccb3212f76538f3d9e43d87dca9e',
#        '85c1f87fea955d09b4bec2e36aee110927aedf9a',
#        'bd4c6e843f00bd476847fb75c47b4fb430a06856', ...,
#        '9a51c7b254e90470fff3d34ef5cc516d21633471',
#        'a955513fb89fdb0d5e8437a5cf8a9b3a0abad4d5',
#        '276e43ad698705e5011e5091f367d951b21246f5'], dtype=object)

# %% [markdown]
# <b>Quiz: Who has the most listeners? Most listen count? Least listen count?<b>

# %%
# most listeners
data_group_by_artist = song_data.groupby(['artist'])
data_with_unique_user = data_group_by_artist['user_id'].unique().to_frame('list_id')
data_with_unique_user['num_listeners'] = data_with_unique_user['list_id'].apply(lambda x: len(x))
data_with_unique_user.sort_values(by='num_listeners', ascending=False)
# Out:
#                                                                   list_id  \
# artist
# Kings Of Leon           [b80344d063b5ccb3212f76538f3d9e43d87dca9e, e00...
# Coldplay                [9d6f0ead607ac2a6c2460e4d14fb439a146b7dec, 3f9...
# Harmonia                [b80344d063b5ccb3212f76538f3d9e43d87dca9e, e00...
# Björk                   [e006b1a48f466bf59feefed32bec6494495a4436, 0af...
# Florence + The Machine  [e006b1a48f466bf59feefed32bec6494495a4436, 169...
# ...                                                                   ...
# Giannis Aggelakas       [97f20f565d807cea14839c9f9789670293a7da3d, 090...
# harvey summers          [050b132921f5bc4465a0b0d96cbd4e5bb7ba5781, d72...
# Reel Feelings           [8b0578e3b7ee700785e4c9d9726bba44b3472bad, 335...
# Elvis Perkins           [71bcab946e1f21440b2e402edcf9123525815c8b, 357...
# William Tabbert         [cd14f385a170f7f041d2a030cc48c598c45f4d63, 44d...
#
#                         num_listeners
# artist
# Kings Of Leon                    7373
# Coldplay                         6340
# Harmonia                         5970
# Björk                            5834
# Florence + The Machine           5615
# ...                               ...
# Giannis Aggelakas                  23
# harvey summers                     22
# Reel Feelings                      22
# Elvis Perkins                      20
# William Tabbert                    12
#
# [3375 rows x 2 columns]

# %%
# artist with most listens count
data_group_by_artist['listen_count'].sum().sort_values()
# Out:
# artist
# William Tabbert                         14
# Reel Feelings                           24
# Beyoncé feat. Bun B and Slim Thug       26
# Boggle Karaoke                          30
# Diplo                                   30
#                                      ...
# Florence + The Machine               33387
# Coldplay                             35362
# Björk                                38889
# Dwight Yoakam                        40619
# Kings Of Leon                        43218
# Name: listen_count, Length: 3375, dtype: int64

# %% [markdown]
# #Create a song recommender

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(song_data, train_size=0.8, test_size=0.2, random_state=0)
print(len(train_data), len(test_data))
#train_data,test_data = song_data.random_split(.8,seed=0)
# Out:
# 893287 223322

# %% [markdown]
# ## Simple popularity-based recommender

# %%
#popularity_model = graphlab.popularity_recommender.create(train_data,
#                                                         user_id='user_id',
#                                                         item_id='song')
popularity = pandas.DataFrame(song_data).groupby('song')['listen_count'].agg('sum').to_frame('total_listen_count')
popularity = popularity.sort_values('total_listen_count', ascending=False)

# %% [markdown]
# ###Use the popularity model to make some predictions
#
# A popularity model makes the same prediction for all users, so provides no personalization.

# %%
popularity.head(10)
#popularity_model.recommend(users=[users[0]])
# Out:
#                                                     total_listen_count
# song
# You\'re The One - Dwight Yoakam                                  40619
# Undo - Björk                                                     36059
# Revelry - Kings Of Leon                                          30391
# Horn Concerto No. 4 in E flat K495: II. Romance...               21953
# Sehr kosmisch - Harmonia                                         21646
# Dog Days Are Over (Radio Edit) - Florence + The...               15889
# Secrets - OneRepublic                                            14149
# Ain\'t Misbehavin - Sam Cooke                                    14029
# Invalid - Tub Ring                                               13701
# Catch You Baby (Steve Pitron & Max Sanna Radio ...               12506

# %%
#popularity_model.recommend(users=[users[1]])

# %% [markdown]
# ## Build a song recommender with personalization
#
# We now create a model that allows us to make personalized recommendations to each user.
#
# Be patient, the song-to-user mapping is very large, so calculation of similarity onto itself is expensive

# %%
#personalized_model = graphlab.item_similarity_recommender.create(train_data,
#                                                                user_id='user_id',
#                                                                item_id='song')
# First, create data of songs listeners. We can use a customized word-count for this task. First, we group the data by the song
song_data_grouped = song_data.groupby("song")["user_id"].agg(lambda val: " ".join(val.values))
#song_data_grouped.head()
# Now we convert the ids using CountVectorizer.
from sklearn.feature_extraction.text import CountVectorizer
values = CountVectorizer(max_features=1000).fit_transform(song_data_grouped.values)
dense_values = values.todense()

print('dense value', dense_values.shape)
# Calculate songs similarity using Jaccard 
from scipy.spatial.distance import cdist
similarity = cdist(dense_values, dense_values, 'jaccard')
print('similarity', similarity.shape)
# Out:
# dense value (9952, 1000)
# similarity (9952, 9952)

# %%
# the similarity above is 0 for absolute match to 1 for no match. Let's use a random song:
random_song = 2010
print("Random song name: {:s}".format(song_data_grouped.index[random_song]))
# get the most similar, excluding the first (because obviously one song is most similar to itself)
def retrieve_similar_items(song_id, values_kept=20):
    return np.argsort(similarity[song_id])[1:1+values_kept]
similar_10 = retrieve_similar_items(random_song, values_kept=10)
print("List of 10 similar songs:\n{}".format("\n".join((song_data_grouped.index[similar_10]))))
# Out:
# Random song name: Disco Heaven - Lady GaGa
# List of 10 similar songs:
# Hope For The Hopeless - A Fine Frenzy
# The Medallion Calls - Klaus Badelt
# They Do_ They Don\'t - Jack Johnson
# Anything But Ordinary - Avril Lavigne
# City Of The Dead - The Clash
# FANTASY - Mariah Carey
# That\'s How You Like It - Beyoncé feat. Jay-Z
# Ain\'t Talkin\'  \'Bout Love (Remastered Version) - Van Halen
# Amsterdam - Coldplay
# Mediocre Bad Guys - Jack Johnson

# %%
song_data_grouped.head()
# Out:
# song
# #!*@ You Tonight [Featuring R. Kelly] (Explicit Album Version) - The Notorious B.I.G.    9236fe7fcb3905ea0daf49408f15a3c8b085b094 83ec2...
# #40 - DAVE MATTHEWS BAND                                                                 b55d68f1a8759157038eb6688e5d6bb1b6336567 caa19...
# & Down - Boys Noize                                                                      bab8d135cf88852063ed4a084dd24c783d7ff841 e22fc...
# (Anaesthesia) Pulling Teath - Metallica                                                  8ee90038724c4957eb4df16f3e9c6ed2b570a3ec b963b...
# (Antichrist Television Blues) - Arcade Fire                                              a7c4e5316026288c499a59ff03d8732d58206c92 ba230...
# Name: user_id, dtype: object

# %%
song_data_grouped.index
# Out:
# Index(['#!*@ You Tonight [Featuring R. Kelly] (Explicit Album Version) - The Notorious B.I.G.',
#        '#40 - DAVE MATTHEWS BAND', '& Down - Boys Noize',
#        '(Anaesthesia) Pulling Teath - Metallica',
#        '(Antichrist Television Blues) - Arcade Fire',
#        '(I Cant Get No) Satisfaction - Cat Power',
#        '(I Can\'t Get Me No) Satisfaction - Devo',
#        '(I Got That) Boom Boom - Britney Spears featuring Ying Yang Twins',
#        '(I Just) Died In Your Arms - Cutting Crew',
#        '(I\'ve Had) The Time Of My Life - Bill Medley & Jennifer Warnes',
#        ...
#        'sillyworld (Album Version) - Stone Sour',
#        'sleep_ eat food_ have visions - Four Tet',
#        'smile around the face - Four Tet', 'sun drums and soil - Four Tet',
#        'teachme (Album Version) - Musiq Soulchild', 'the Love Song - K-OS',
#        'you were there with me - Four Tet',
#        '¡Viva La Gloria! (Album Version) - Green Day',
#        '¿Lo Ves? [Piano Y Voz] - Alejandro Sanz', 'Época - Gotan Project'],
#       dtype='object', name='song', length=9952)

# %%
# Now, we build the recommender basing on the song similarity and the user's own listening history.
song_lookup_dict = {name: i for i, name in enumerate(song_data_grouped.index)}
def congregate_song(row, values_kept=20):
    #print('current song: \n', row['song'])
    songs_data = similarity[row["song"]]
    #print('song data for similarity: \n', songs_data)
    #print('np.expand_dims(row["listen_count"], axis=1) value: \n', np.expand_dims(row["listen_count"], axis=1))
    # song data will look like this  [[8254, 2409, 7843, 1649, 4718, 518, 6257, 7704,...]
    # and listen count look like this[[1, 2, 1, 1, 1, 5, 1, 1, 1, 1, 1, 5, 1, 1, 5,...]
    # then we multiply each pair of those by index then sorting them
    song_and_listen = songs_data * np.expand_dims(row["listen_count"], axis=1)
    #print('song_and_listen after multiply np.expan_dims: \n', song_and_listen)
    song_and_listen = np.argsort(np.sum(song_and_listen, axis=0))
    #print('song_and_listen after argsort: \n', song_and_listen)
    #print(song_and_listen.shape)
    if(values_kept is not None and values_kept != 0):
        return song_and_listen[:values_kept]
    else:
        return song_and_listen

def recommend(users, song_number=20):
    # filter the data
    users_data_id = song_data["user_id"].isin(users)
    #print('user_data_id', users_data_id)
    users_data = song_data.loc[users_data_id].groupby("user_id")["song", "listen_count"].agg({
        "song": lambda x: np.vectorize(song_lookup_dict.get)(x.values).tolist(),
        "listen_count": lambda x: x.values.tolist()
    })
    #print('users data before adding recommendation column', users_data)
    users_data["recommend"] = users_data.apply(lambda x: congregate_song(x, values_kept=song_number), axis=1)
    #print('users data after add recommendation column', users_data)
    return users_data

def show_songs_list(users_data):
    #users_data.reindex(columns=["song", "listen_count"])
    for row in users_data.iterrows():
        print("User {:s}'s recommended songs:'\n{:s}".format(
            row[0], 
            "\n".join( (song_data_grouped.index[song_id] for song_id in row[-1]["recommend"]))
        ))
#recommend(users[:2])`

# %%
song_lookup_dict
# Out:
# {'#!*@ You Tonight [Featuring R. Kelly] (Explicit Album Version) - The Notorious B.I.G.': 0,
#  '#40 - DAVE MATTHEWS BAND': 1,
#  '& Down - Boys Noize': 2,
#  '(Anaesthesia) Pulling Teath - Metallica': 3,
#  '(Antichrist Television Blues) - Arcade Fire': 4,
#  '(I Can\x19t Get No) Satisfaction - Cat Power': 5,
#  "(I Can\\'t Get Me No) Satisfaction - Devo": 6,
#  '(I Got That) Boom Boom - Britney Spears featuring Ying Yang Twins': 7,
#  '(I Just) Died In Your Arms - Cutting Crew': 8,
#  "(I\\'ve Had) The Time Of My Life - Bill Medley & Jennifer Warnes": 9,
#  "(If You\\'re Wondering If I Want You To) I Want You To - Weezer": 10,
#  '(Keep Feeling) Fascination (2003 Digital Remaster) - The Human League': 11,
#  '(Nice Dream) - Radiohead': 12,
#  "(Nothing\\'s Too Good) For My Baby (1999 Digital Remaster) - Louis Prima And Keely Smith": 13,
#  '(Oh) Pretty Woman (Remastered Album Version) - Van Halen': 14,
#  '(Remember The Days Of The) Old Schoolyard - Cat Stevens': 15,
#  "(Sittin\\' On) The Dock Of The Bay - Otis Redding": 16,
#  '(Splash) Turn Twist - Jimmy Eat World': 17,
#  "(The Symphony Of) Blase\\' - Anberlin": 18,
#  '(They Long To Be) Close To You - Carpenters': 19,
#  '(You Drive Me) Crazy (The Stop Remix!) - Britney Spears': 20,
#  "(\\'Til) I Kissed You - Everly Brothers": 21,
#  '(iii) - The Gerbils': 22,
#  '...Baby One More Time - Britney Spears': 23,
#  '..Come Around - Collie Buddz': 24,
#  '0010 - Ayabie': 25,
#  '1.36 - Coldplay': 26,
#  '10 A.M. Automatic - The Black Keys': 27,
#  '10 Miles Wide - Escape The Fate': 28,
#  '100° - Shout Out Louds': 29,
#  '10:15 Saturday Night - The Cure': 30,
#  '11 am - Incubus': 31,
#  '1234 - Feist': 32,
#  "14 Years - Guns N\\' Roses": 33,
#  '143 - Musiq': 34,
#  '15 Step - Radiohead': 35,
#  '1517 - The Whitest Boy Alive': 36,
#  '16 Candles - The Crests': 37,
#  '18 And Life (LP Version) - Skid Row': 38,
#  '19-2000 - Gorillaz': 39,
#  '1958 - A Day To Remember': 40,
#  '1981 - Deadmau 5': 41,
#  "1983 (Daedelus\\'s Odd-Dance Party Remix) - Flying Lotus": 42,
#  '1983 - Flying Lotus': 43,
#  '1991 - Crystal Castles': 44,
#  '2 Become 1 - Spice Girls': 45,
#  '2080 - Yeasayer': 46,
#  '21 Guns [feat. Green Day & The Cast Of American Idiot] (Album Version) - Green Day': 47,
#  '22 - Lily Allen': 48,
#  '221 - keller williams': 49,
#  '24 - Jem': 50,
#  '240 Years Before Your Time - The Black Keys': 51,
#  "2nd Self - Umphrey\\'s McGee": 52,
#  '3 - Britney Spears': 53,
#  '3 Rounds and a Sound - Blind Pilot': 54,
#  '369 (feat. B.o.B.) [Step Up 2 The Streets O.S.T. Version] - Cupid feat. B.o.B.': 55,
#  '38:45 (A Thievery Number) - Thievery Corporation': 56,
#  '3AM (LP Version) - matchbox twenty': 57,
#  '42 - Coldplay': 58,
#  '45 (Album Version) - Shinedown': 59,
#  '4th Dimensional Transition - MGMT': 60,
#  '5 Minutes Alone [Live Version] - Pantera': 61,
#  '5.45 - Gang Of Four': 62,
#  '505 - Arctic Monkeys': 63,
#  '53rd & 3rd   (Remastered Version ) - Ramones': 64,
#  "5\\' O\\'Clock In the Morning - Village People": 65,
#  '5_ 6_ 7_ 8 - Steps': 66,
#  '7 - Prince & The New Power Generation': 67,
#  '83 - John Mayer': 68,
#  '911 - Wyclef Jean / Mary J. Blige': 69,
#  'A Beautiful Mine - RJD2': 70,
#  'A Beggar On A Beach Of Gold - Mike And The Mechanics': 71,
#  'A Better Place_ A Better Time (Album Version) - Streetlight Manifesto': 72,
#  'A Better Son/Daughter - Rilo Kiley': 73,
#  'A Book Like This - Angus & Julia Stone': 74,
#  'A Boy Brushed Red Living In Black And White - Underoath': 75,
#  'A Candlelit Dinner With Inamorta (feat. NO) - Asking Alexandria': 76,
#  'A Cautionary Song - The Decemberists': 77,
#  'A Certain Romance - Arctic Monkeys': 78,
#  'A Cloak Of Elvenkind - Marcy Playground': 79,
#  'A Comet Appears (Album) - The Shins': 80,
#  'A Crippling Blow - The Killers': 81,
#  'A Cura - Lulu  Santos': 82,
#  'A Day Late - Anberlin': 83,
#  'A Day Without Me - U2': 84,
#  'A Days Work (feat. P.O.S) - BK-One': 85,
#  'A Decade Under The Influence (Album Version) - Taking Back Sunday': 86,
#  'A Deeper Shade Of Soul - Ray Barretto': 87,
#  'A Dios Le Pido - Juanes': 88,
#  'A Dirge for the Underground - Attica! Attica!': 89,
#  'A Dream - Cut Copy': 90,
#  'A Dream - Rebecka Törnqvist': 91,
#  'A Dustland Fairytale - The Killers': 92,
#  "A Dying Cub Fan\\'s Last Request - Steve Goodman": 93,
#  'A Face In The Crowd - Tom Petty': 94,
#  'A Foggy Day (In London Town) (Album Version) - Michael Bublé': 95,
#  'A Forest - Bat For Lashes': 96,
#  'A Gentle Dissolve - Thievery Corporation': 97,
#  'A Girl Like You - Edwyn Collins': 98,
#  'A Girl Like You - The Smithereens': 99,
#  'A Good Heart - Feargal Sharkey': 100,
#  'A Good Idea At The Time - Ok Go': 101,
#  'A Great Big Sled - The Killers / Toni Halliday': 102,
#  'A Guitar And A Heart - M83': 103,
#  'A Horse Is Not A Home - Miike Snow': 104,
#  'A Kind Of Hope - Pilot Speed': 105,
#  'A Kiss Is Not A Contract (Album Version) - Flight Of The Conchords': 106,
#  'A La Mierda - Ska-P': 107,
#  'A Lack Of Color (Album Version) - Death Cab for Cutie': 108,
#  'A Life Worth Living - Aereogramme': 109,
#  "A Lion\\'s Heart - The Tallest Man On Earth": 110,
#  'A Little Bit Longer - Jonas Brothers': 111,
#  'A Little Bit Of Riddim - Michael Franti & Spearhead / Cherine Anderson': 112,
#  'A Little Less Sixteen Candles_ A Little More "Touch Me - Fall Out Boy': 113,
#  'A Little More Country Than That - Easton Corbin': 114,
#  'A Little Something - Casual featuring Del Tha Funkee Homosapien': 115,
#  'A Little Something Refreshing - No Doubt': 116,
#  "A Little\\'s Enough - Angels and Airwaves": 117,
#  'A Lo Cubano - Orishas': 118,
#  'A Lonely September (Album) - Plain White T S': 119,
#  'A Man/Me/Then Jim (Album Version) - Rilo Kiley': 120,
#  'A Message - Coldplay': 121,
#  'A Message To You Rudy - The Specials': 122,
#  'A Million Miles Away - Rihanna': 123,
#  'A Million Ways - Ok Go': 124,
#  'A Moment Like This - Leona Lewis': 125,
#  'A New Level [Live Version] - Pantera': 126,
#  'A Night In Torino - Parov Stelar': 127,
#  'A Nightmare To Remember (Album Version) - Dream Theater': 128,
#  'A Pain That I\x19m Used To - Depeche Mode': 129,
#  'A Party Song (The Walk of Shame) - All Time Low': 130,
#  'A Perfect Sonnet - Bright Eyes': 131,
#  'A Perfectly Good Heart - Taylor Swift': 132,
#  'A Prayer - East Blues Experience': 133,
#  'A Primera Vista - Pedro Aznar': 134,
#  'A Quai - Yann Tiersen': 135,
#  'A Reminder - Radiohead': 136,
#  'A Ribbon - Devendra Banhart': 137,
#  'A Rush Of Blood To The Head - Coldplay': 138,
#  'A Single Moment Of Sincerity (feat. NO) - Asking Alexandria': 139,
#  'A Sisters Social Agony - Camera Obscura': 140,
#  'A Small Victory (2009 Remastered) - Faith No More': 141,
#  'A Song About Hope - Ulrich Schnauss': 142,
#  'A Song For The Lovers - Richard Ashcroft': 143,
#  'A Strangely Isolated Place - Ulrich Schnauss': 144,
#  'A Stranger - A Perfect Circle': 145,
#  'A Summer Song - Chad & Jeremy': 146,
#  'A Sunday Smile - Beirut': 147,
#  'A Teenager In Love - Dion & The Belmonts': 148,
#  'A Thousand Miles - Vanessa Carlton': 149,
#  'A Ti - Sin Bandera': 150,
#  'A Time To Be So Small - Interpol': 151,
#  'A Veces Vuelvo - Catupecu Machu': 152,
#  'A Warm Place - Nine Inch Nails': 153,
#  'A Warning (Dub) - Thievery Corporation': 154,
#  'A Well Respected Man - The Kinks': 155,
#  'A Whisper - Coldplay': 156,
#  'A Whiter Shade Of Pale - Procol Harum': 157,
#  'A Wolf At The Door - Radiohead': 158,
#  "A Woman\\'s Worth - Alicia Keys": 159,
#  'A World Without Love - Peter And Gordon': 160,
#  'A Year - Loudon Wainwright III': 161,
#  'A fuego lento - Rosana': 162,
#  'A-Punk (Album) - Vampire Weekend': 163,
#  'A.T.H.F. (Aqua Teen Hunger Force) (Album Version) - Danger Doom': 164,
#  'AMERIKA - Rammstein': 165,
#  'AMOUR - Rammstein': 166,
#  'ATWA - System of a Down': 167,
#  "Aber Dich Gibt\\'s Nur Einmal Für Mich - Guildo Horn": 168,
#  'About A Girl (Album Version) - The Academy Is...': 169,
#  'Above The Clouds (Edited) - Gang Starr/Inspectah Deck': 170,
#  'Above You - The Whitest Boy Alive': 171,
#  'Abracadabra - Steve Miller Band': 172,
#  'Abrazame  (Version Acustica) - Camila': 173,
#  'Abrazame - Camila': 174,
#  'Absence of Fear - War Of Ages': 175,
#  'Absolutely Zero (LP Version) - Jason Mraz': 176,
#  'Absolution: Of Flight and Failure - A Hope For Home': 177,
#  'Acadian Coast - Soltero': 178,
#  'Acapella - Kelis': 179,
#  'Acapulco 1922 - Herb Alpert And The Tijuana Brass': 180,
#  'Accidental Babies - Damien Rice': 181,
#  'Accidntel Deth (Album Version) - Rilo Kiley': 182,
#  'Acende O Candieiro (2003 Digital Remaster) - Adoniran Barbosa - Com Nosso Samba': 183,
#  'Achy Breaky Heart - Billy Ray Cyrus': 184,
#  'Acid Rain - Liquid Tension Experiment': 185,
#  'Ackrite - Dr. Dre / Hittman': 186,
#  'Across 110th Street - Bobby Womack': 187,
#  'Across The Universe - Jim Sturgess': 188,
#  'Act Naturally (Album Version) - Leon Russell': 189,
#  'Act Nice and Gentle - The Black Keys': 190,
#  'Act Too (Love Of My Life) - The Roots / Common': 191,
#  "Adam\\'s Song - Blink-182": 192,
#  'Add It Up - Violent Femmes': 193,
#  'Addams Groove - MC Hammer': 194,
#  'Addicted - Amy Winehouse': 195,
#  'Addicted - Enrique Iglesias': 196,
#  'Addicted To Love - Robert Palmer': 197,
#  'Adelante - Sash!': 198,
#  'Adhesive (LP Version) - Stone Temple Pilots': 199,
#  'Adios - Gustavo Cerati': 200,
#  'Adios - Rammstein': 201,
#  'Adir Adirim (Featuring Victoria Hanna) - Balkan Beat Box': 202,
#  'Adrenalin - Eisbrecher': 203,
#  'Adrift & At Peace - Nine Inch Nails': 204,
#  'Adrift - Jack Johnson': 205,
#  'Adventures In Solitude - The New Pornographers': 206,
#  'Advertising Space - Robbie Williams': 207,
#  'Aerials - System of a Down': 208,
#  'Aero Zeppelin - Nirvana': 209,
#  'Aerodynamic (Daft Punk Remix) - Daft Punk': 210,
#  'Aerodynamic (Slum Village Remix) - Daft Punk': 211,
#  'Aerodynamic - Daft Punk': 212,
#  'Aerodynamite - Daft Punk': 213,
#  'Aeroplane (Album Version) - Red Hot Chili Peppers': 214,
#  'Aeroplane Blues - The Black Keys': 215,
#  'Afortunada - Francisca Valenzuela': 216,
#  'Africadën - Cheikh Lô': 217,
#  'African Pride - Buju Banton': 218,
#  'Afroman - Plastilina Mosh': 219,
#  'After All (Love Theme From Chances Are) - Cher / Peter Cetera': 220,
#  'After An Afternoon (Eagles Ballroom Live Version) - Jason Mraz': 221,
#  'After Hours - We Are Scientists': 222,
#  'After The Gold Rush (Album Version) - Neil Young': 223,
#  'After The Love Has Gone - Damage': 224,
#  'Afterlife (Album Version) - Avenged Sevenfold': 225,
#  'Afternoon (Album) - Carla Bruni': 226,
#  'Agaetis Byrjun - Sigur Ros': 227,
#  'Again & Again - the bird and the bee': 228,
#  'Again - Flyleaf': 229,
#  'Again - Pnau': 230,
#  'Again Again - Lady GaGa': 231,
#  'Again I Go Unnoticed - Dashboard Confessional': 232,
#  'Against The Peruvian Monster - Man Man': 233,
#  'Age Of Consent - New Order': 234,
#  'Ageless beauty - Stars': 235,
#  'Aghia Sophia (2008 Digital Remaster) - CCCP - Fedeli Alla Linea': 236,
#  'Agitated [Live From Le Zenith] - Muse': 237,
#  'Agua - Jarabe De Palo': 238,
#  'Aguas De Marco - João Gilberto': 239,
#  'Agüela (Mi Abuela & The Magnificent Seven & Bust A Move) - Molotov': 240,
#  "Ain\\'t Got A Lot of Money - Slightly Stoopid": 241,
#  "Ain\\'t It Fun - Guns N\\' Roses": 242,
#  "Ain\\'t Misbehavin - Sam Cooke": 243,
#  "Ain\\'t Misbehavin\\' - Louis Armstrong": 244,
#  "Ain\\'t My Bitch - Metallica": 245,
#  "Ain\\'t No Reason - Brett Dennen": 246,
#  "Ain\\'t No Rest For The Wicked (Original Version) - Cage The Elephant": 247,
#  "Ain\\'t No Sunshine - Lighthouse Family": 248,
#  "Ain\\'t No Way (You Won\\'t Love Me) - Chris Brown": 249,
#  "Ain\\'t Nobody - Chaka Khan": 250,
#  "Ain\\'t Talkin\\'  \\'Bout Love (Remastered Version) - Van Halen": 251,
#  "Ain\\'t Talkin\\' \\'Bout Love (Remastered Live Version) - Van Halen": 252,
#  "Ain\\'t That A Bitch - Lil Wayne": 253,
#  'Air & Lack Thereof - James Blake': 254,
#  'Air - Steve Anderson': 255,
#  'Air Force Ones - Nelly / David Banner / 8-Ball': 256,
#  'Airplanes - Local Natives': 257,
#  'Airwar - Crystal Castles': 258,
#  'Airwave (Original Version) - Rank 1': 259,
#  'Aja - Steely Dan': 260,
#  'Ajde sonce zajde - Leb I Sol': 261,
#  'Al Di Fuori Di Me - Phil Collins': 262,
#  'Al Vacío - No Te Va Gustar': 263,
#  'Al otro lado del Río - Jorge Drexler / Jeff Eckels / Carina Voly / John Vriesacker / Ana Laan / Leo Sidran / Ben Sidran': 264,
#  'Alala (Album) - CSS': 265,
#  'Alaska - Camera Obscura': 266,
#  'Alcohol - Gogol Bordello': 267,
#  'Aldebaran - Enya': 268,
#  'Alejandro - Lady GaGa': 269,
#  'Alejate De Mi - Camila': 270,
#  'Alerion (feat. NO) - Asking Alexandria': 271,
#  'Alexandra - Aventura': 272,
#  'Alguien Soy Yo - Enrique Iglesias': 273,
#  'Alice - Avril Lavigne': 274,
#  'Alice Practise - Crystal Castles': 275,
#  'Alienated - Keri Hilson': 276,
#  'Alive (2006 Remastered Album Version) - P.O.D.': 277,
#  'Alive (nightmare) - Kid Cudi / Ratatat': 278,
#  'Alive - Daft Punk': 279,
#  'Alkime - Soulive': 280,
#  "All About The Benjamins (Album Version) - P. Diddy feat. The Notorious B.I.G._ The Lox_ Lil\\' Kim": 281,
#  'All Alone - Gorillaz': 282,
#  'All Along The Watchtower - DAVE MATTHEWS BAND': 283,
#  'All Along The Watchtower - Jimi Hendrix': 284,
#  'All Apologies - Herbie Hancock': 285,
#  'All At Once - Jack Johnson': 286,
#  'All At Once - The Fray': 287,
#  "All Day Sucker / Easy Goin\\' Evening - Najee": 288,
#  'All Ears - The Whitest Boy Alive': 289,
#  'All Fall Down - OneRepublic': 290,
#  'All Falls Down - Kanye West / Syleena Johnson': 291,
#  'All Fired Up - Interpol': 292,
#  'All For Love - Bryan Adams / Sting / Rod Stewart': 293,
#  'All For Swinging You Around - The New Pornographers': 294,
#  'All Hands Against His Own - The Black Keys': 295,
#  'All I - Jill Scott': 296,
#  'All I Do Is Win (feat. T-Pain_ Ludacris_ Snoop Dogg & Rick Ross) - DJ Khaled': 297,
#  'All I Ever Wanted - Basshunter': 298,
#  'All I Ever Wanted - Kelly Clarkson': 299,
#  'All I Ever Wanted - Train': 300,
#  'All I Hear - Train': 301,
#  'All I Need - Air': 302,
#  'All I Need - Method Man': 303,
#  'All I Need - [re:jazz]': 304,
#  'All I Want (Live LP Version) - Joni Mitchell': 305,
#  'All I Want - LCD Soundsystem': 306,
#  'All I Want Is You (Josh Harris Remix) - Kim Sozzi': 307,
#  'All In - Lifehouse': 308,
#  'All In Forms - Bonobo': 309,
#  'All In Good Time - Richard Souther': 310,
#  'All In My Blood [Pittsburgh Sound] [Radio Edit] - Wiz Khalifa': 311,
#  'All In The Suit That You Wear (Album Version) - Stone Temple Pilots': 312,
#  'All Is Love - Karen O And The Kids': 313,
#  'All Men Are Liars - Nick Lowe': 314,
#  'All Mine - Portishead': 315,
#  'All My Best Friends Are Metalheads - Less Than Jake': 316,
#  'All My Friends - Amos Lee': 317,
#  'All My Friends - LCD Soundsystem': 318,
#  'All My Friends Say - Luke Bryan': 319,
#  'All My Life - Foo Fighters': 320,
#  'All My Life - K-Ci & JoJo': 321,
#  'All My Loving - Jim Sturgess': 322,
#  'All My Mistakes (US4BW0700133) - The Avett Brothers': 323,
#  'All Night - Damian Marley / Stephen Marley': 324,
#  'All Night Long (All Night) - Lionel Richie': 325,
#  'All Night Long - Junior Kimbrough And The Soul Blues Boys': 326,
#  'All Night Operator (Part 1) - Goldfrapp': 327,
#  'All Of Me - Angus & Julia Stone': 328,
#  'All Of The Champs That Ever Lived - Octopus Project': 329,
#  'All Of This - Blink-182': 330,
#  'All Outta Angst - NOFX': 331,
#  'All Over Me - Drowning Pool': 332,
#  'All Over Me - Josh Turner': 333,
#  'All Over You - Live': 334,
#  'All Right Now - Free': 335,
#  'All She Wants Is - Duran Duran': 336,
#  'All Star - Nando Reis': 337,
#  'All Star - Smash Mouth': 338,
#  'All Summer Long (Album Version) - Kid Rock': 339,
#  'All Summer Long - The Beach Boys': 340,
#  'All That I Need - STEVE CAMP': 341,
#  "All That I\\'m Asking For - Lifehouse": 342,
#  'All That She Wants (Banghra Version) - Ace of Base': 343,
#  'All That She Wants - Ace of Base': 344,
#  'All That We Perceive - Thievery Corporation': 345,
#  "All That\\'s Left - Thrice": 346,
#  'All The Above [feat. T-Pain] (Explicit Album Version) - Maino': 347,
#  'All The Kings Horns - Sufjan Stevens': 348,
#  'All The Old Showstoppers - The New Pornographers': 349,
#  'All The Pretty Faces - The Killers': 350,
#  'All The Right Moves - OneRepublic': 351,
#  'All The Same - Sick Puppies': 352,
#  'All The Things That Go To Make Heaven And Earth - The New Pornographers': 353,
#  'All The Way (Single Version) - Craig David': 354,
#  'All The Wild Horses - Ray LaMontagne': 355,
#  "All The Woman (Recorded Live In London \\'99) - Tina Turner": 356,
#  'All These Things I Hate [revolve Around Me] [album Version] - Bullet For My Valentine': 357,
#  "All These Things That I\\'ve Done - The Killers": 358,
#  'All Things To All Men - The Cinematic Orchestra feat. Roots Manuva': 359,
#  'All This Beauty - The Weepies': 360,
#  'All This Time - OneRepublic': 361,
#  'All To All - Broken Social Scene': 362,
#  "All Tomorrow\\'s Parties - The Velvet Underground / Nico": 363,
#  'All We Are - Matt Nathanson': 364,
#  'All We Are - OneRepublic': 365,
#  'All We Ever Do Is Say Goodbye - John Mayer': 366,
#  'All We Know (Album Version) - Paramore': 367,
#  'All You Ever Wanted - The Black Keys': 368,
#  'All You Need Is Love - Jim Sturgess / Dana Fuchs': 369,
#  'Alley Cats - Hot Chip': 370,
#  'Alley Oop (Girls Version) (2007 Digital Remaster) - The Bonzo Dog Band': 371,
#  'Allison - Pixies': 372,
#  'Alma De Diamante - Luis Alberto Spinetta': 373,
#  'Almaz - Randy Crawford': 374,
#  "Almeno Tu Nell\\'Universo - Elisa": 375,
#  'Almost Cut My Hair - Crosby_ Stills_ Nash and Young': 376,
#  'Almost Easy (Album Version) - Avenged Sevenfold': 377,
#  'Almost Grown - Chuck Berry': 378,
#  'Almost Here (Album Version) - The Academy Is...': 379,
#  'Almost Lover (Album Version) - A Fine Frenzy': 380,
#  "Alone Again (Naturally) - Gilbert O\\'Sullivan": 381,
#  'Alone In Kyoto - Air': 382,
#  'Alone In This Bed (Capeside) - Framing Hanley': 383,
#  'Alone With You - Deadmau5': 384,
#  'Alone in the dark - Airwave': 385,
#  'Alpha Beta Gaga - Air': 386,
#  'Alpha Male - Röyksopp': 387,
#  'Already Gone - Kelly Clarkson': 388,
#  'Alright - Darius Rucker': 389,
#  'Alright - Mystikal': 390,
#  'Alright Hear This - Beastie Boys': 391,
#  'Also Frightened - Animal Collective': 392,
#  "Always (7\\'\\' Mix) - Erasure": 393,
#  'Always - Atlantic Starr': 394,
#  'Always - Blink-182': 395,
#  'Always - Saliva': 396,
#  'Always Coming Back Home To You - Atmosphere': 397,
#  'Always Like This - Bombay Bicycle Club': 398,
#  'Always Love (Album Version) - Nada Surf': 399,
#  'Always On My Mind (Album Version) - Michael Bublé': 400,
#  'Always Remember - Train': 401,
#  'Always Something There To Remind Me - Naked Eyes': 402,
#  'Always Where I Need To Be - The Kooks': 403,
#  'Aló - Plastilina Mosh': 404,
#  'Am I A Fool - Sense Field': 405,
#  'Am I Evil? - Metallica': 406,
#  'Am I High (Feat. Malice) - N.E.R.D. FEATURING MALICE': 407,
#  'Amame - Juanes': 408,
#  'Amanda - Boston': 409,
#  'Amanecer - Nino Bravo': 410,
#  'Amapola - Sanalejo': 411,
#  'Amarga Vida - Don Omar': 412,
#  'Amarte Es Un Placer - Luis Miguel': 413,
#  'Amazing - Seal': 414,
#  'Amazing Grace (1999 Digital Remaster) - Bryan Ferry': 415,
#  'Ambling Alp (DJ /Rupture & Brent Arnold Remix) - Yeasayer': 416,
#  'Ameno - Era': 417,
#  'American Idiot [feat. Green Day & The Cast Of American Idiot] (Album Version) - Green Day': 418,
#  'American Ride - Toby Keith': 419,
#  'American Soldier - Toby Keith': 420,
#  'American Star - Lil Wayne / Shanell': 421,
#  'American Superstar [Feat. Lil Wayne] (Explicit Album Version) - Flo Rida': 422,
#  'American Terrorist [feat. Matthew Santos] (Explicit Album Version) - Lupe Fiasco': 423,
#  'American Wedding - Gogol Bordello': 424,
#  'Amerika (Album Version) - Jaco Pastorius Big Band': 425,
#  'Amerika - Left Lane Cruiser': 426,
#  'Amie - Damien Rice': 427,
#  'Amish Paradise (Parody of "Gangsta\\\'s Paradise" by Coolio) - Weird Al Yankovic': 428,
#  'Amityville - Eminem / Bizarre': 429,
#  'Amor De Madre - Aventura': 430,
#  'Amor Prohibido - Selena': 431,
#  'Amor de Loca Juventud - Buena Vista Social Club': 432,
#  'Amores De Barra - Ella Baila Sola': 433,
#  'Amsterdam - Coldplay': 434,
#  'Amy Amy Amy / Outro - Amy Winehouse': 435,
#  'América - M83': 436,
#  'An Ending (Ascent) (2005 Digital Remaster) - Brian Eno': 437,
#  'An Island - Devendra Banhart': 438,
#  'An Ocean Between Us - As I Lay Dying': 439,
#  'An Unsavoury Urge - The Rogue Element': 440,
#  'Ana - Maná': 441,
#  'Ana - Pixies': 442,
#  "Ana\\'s Song (Open Fire) - Silverchair": 443,
#  'Analyse - Thom Yorke': 444,
#  'And It Spread - The Avett Brothers': 445,
#  'And The Boys - Angus & Julia Stone': 446,
#  'Andalucia - Medina Azahara': 447,
#  'Andar Conmigo - Julieta Venegas': 448,
#  'Andvari - Sigur Rós': 449,
#  "Andy_ You\\'re A Star - The Killers": 450,
#  'Anesthetize [Album Version] - Porcupine Tree': 451,
#  'Angel - Amanda Perez': 452,
#  'Angel - Jack Johnson': 453,
#  'Angel - Jimi Hendrix': 454,
#  'Angel - Matt Nathanson': 455,
#  'Angel / Better Together - Jack Johnson': 456,
#  'Angel De Orión - Antonio Vega': 457,
#  'Angel Echoes - Four Tet': 458,
#  'Angel From Montgomery - Bonnie Raitt': 459,
#  'Angel Malherido - El Barrio': 460,
#  'Angel Of Death - Slayer': 461,
#  'Angel On My Shoulder (EDX Radio Edit) - Kaskade': 462,
#  'Angel With The Scabbed Wings - Marilyn Manson': 463,
#  'Angeles - Elliott Smith': 464,
#  'Angelica - Lamb': 465,
#  'Angelina - Neil Innes': 466,
#  'Angels (Album Version) - Within Temptation': 467,
#  'Angels Cry - Mariah Carey': 468,
#  'Angels Fall First - Nightwish': 469,
#  'Angie (1993 Digital Remaster) - The Rolling Stones': 470,
#  'Angry Chair - Alice In Chains': 471,
#  'Animal - Miike Snow': 472,
#  'Animal Instinct - The Cranberries': 473,
#  'Animals [Live In Atlanta] - Nickelback': 474,
#  'Annan Water - The Decemberists': 475,
#  "Anne\\'s Song - Faith No More": 476,
#  'Annie (Album Version) - James Blunt': 477,
#  'Annihilation - A Perfect Circle': 478,
#  'Annihilation By The Hands Of God (Album Version) - Roadrunner United': 479,
#  'Anoche Soñé Contigo - Kevin Johansen': 480,
#  'Anonanimal - Andrew Bird': 481,
#  'Anonymous - Bobby Valentino / Timbaland': 482,
#  'Anonymous - Sleater-kinney': 483,
#  'Another Day - Angus & Julia Stone': 484,
#  'Another Day In Paradise - Phil Collins': 485,
#  'Another Girl Another Planet - Blink-182': 486,
#  'Another Great Divide - Split Enz': 487,
#  'Another Place - Mischa Daniels': 488,
#  'Another Rainy Day - Corinne Bailey Rae': 489,
#  'Another Saturday Night - Cat Stevens': 490,
#  'Another Song About The Weekend - A Day To Remember': 491,
#  'Another Song About The Weekend [Acoustic] - A Day To Remember': 492,
#  'Another Time Another Place - U2': 493,
#  'Another Town - Regina Spektor': 494,
#  "Another Travelin\\' Song (Album Version) - Bright Eyes": 495,
#  'Another Try - Josh Turner': 496,
#  'Another Way To Die - Jack White & Alicia Keys': 497,
#  'Ante Up (Robbin Hoodz Theory) - M.O.P.': 498,
#  'Anthem For The Year 2000 - Silverchair': 499,
#  'Anthems For a Seventeen Year-Old Girl - Broken Social Scene': 500,
#  'Anxiety - Black Eyed Peas / Papa Roach': 501,
#  'Any Colour You Like - Easy Star All-Stars': 502,
#  'Any Man - Eminem': 503,
#  'Anybody Wanna Take Me Home - Ryan Adams': 504,
#  'Anyone Else But You - Michael Cera & Ellen Page': 505,
#  'Anyone Else But You - The Moldy Peaches': 506,
#  'Anything But Ordinary - Avril Lavigne': 507,
#  'Anything New - Digitalism': 508,
#  'Anytime You Need A Friend - Mariah Carey': 509,
#  'Anywhere Is - Enya': 510,
#  'Apache (LP Version) - The Sugarhill Gang': 511,
#  'Apologize - OneRepublic': 512,
#  'Apology - Alesana': 513,
#  'Apple - Sander Van Doorn': 514,
#  'Apple Orchard - Beach House': 515,
#  'April 8th - Neutral Milk Hotel': 516,
#  'April Showers - Sugarland': 517,
#  "Apuesta Por El Rock \\'N\\' Roll - Héroes del Silencio": 518,
#  'Aqui No Es Asi - Caifanes': 519,
#  'Arboretum - Max Richter': 520,
#  'Arc Of Time (time Code) (Album Version) - Bright Eyes': 521,
#  'Arcade Robot - Boys Noize': 522,
#  'Arcadia - Apparat': 523,
#  'Arco Arena - Cake': 524,
#  'Arde el cielo - Maná': 525,
#  'Are We The Waiting [feat. Green Day & The Cast Of American Idiot] (Album Version) - Green Day': 526,
#  'Are You Dead Yet - Children Of Bodom': 527,
#  'Are You Gonna Be My Girl (Album Version) - JET': 528,
#  'Are You Hurting The One You Love? - Florence + The Machine': 529,
#  'Are You In? - Incubus': 530,
#  'Are You That Somebody? ( LP Version ) - Aaliyah': 531,
#  'Area Codes - Ludacris / Nate Dogg': 532,
#  'Arguru - Deadmau5': 533,
#  'Arise - Flyleaf': 534,
#  'Arizona - Kings Of Leon': 535,
#  'Arma dispuesta - Che Sudaka': 536,
#  'Armada Latina (feat. Pitbull and Marc Anthony) - Cypress Hill featuring Pitbull and Marc Anthony': 537,
#  'Armchairs - Andrew Bird': 538,
#  'Armed And Ready (2009 Digital Remaster) - The Michael Schenker Group': 539,
#  'Armistice - Phoenix': 540,
#  'Armour Love - La Roux': 541,
#  'Arms Of A Woman - Amos Lee': 542,
#  'Army of Me - Björk': 543,
#  'Around The World (Motorbass Vice Mix) - Daft Punk': 544,
#  'Around The World (Radio Edit) - Daft Punk': 545,
#  'Around The World / Harder Better Faster Stronger - Daft Punk': 546,
#  'Arriving Somewhere But Not Here (Album Version) - Porcupine Tree': 547,
#  'Arroyito - Fonseca': 548,
#  "Art Isn\\'t Real (City Of Sin) - Deer Tick": 549,
#  'Art is Hard - Cursive': 550,
#  'Artifacts of the black rain - In Flames': 551,
#  'As Good As I Once Was - Toby Keith': 552,
#  'As I Am - Miley Cyrus': 553,
#  'As I Rise - The Decemberists': 554,
#  'As Lovers Go - Dashboard Confessional': 555,
#  'As Serious As Your Life - Four Tet': 556,
#  'As The Sun Still Burns Away (2002 Digital Remaster) - Ten Years After': 557,
#  'As The World Turns - Eminem': 558,
#  'Asche Zu Asche - Rammstein': 559,
#  'Asesíname - Charly García': 560,
#  'Ashes - Pepper': 561,
#  'Ashes And Wine - A Fine Frenzy': 562,
#  'Ashes To Ashes - Faith No More': 563,
#  'Ask - The Smiths': 564,
#  'Ask Me No Questions - Johnny Thunders': 565,
#  'Ask The Mountains - Vangelis': 566,
#  'Ask about me - Girl Talk': 567,
#  'Asking Around For You - Joe Bonamassa': 568,
#  'Asleep - The Smiths': 569,
#  'Asleep On A Sunbeam - Belle & Sebastian': 570,
#  'Astair - Matt Costa': 571,
#  'Astro Zombies - The Misfits': 572,
#  'Astronaut - Beach House': 573,
#  'At Last - Beyoncé': 574,
#  'At The Back Of The Shell - The Kills': 575,
#  'At The Beach - The Avett Brothers': 576,
#  'At The Beginning (LP Version) - Richard Marx & Donna Lewis': 577,
#  'At The Bottom Of Everything - Bright Eyes': 578,
#  'Atlantic - Keane': 579,
#  'Atlantis To Interzone - Klaxons': 580,
#  'Atlas Air - Massive Attack': 581,
#  "Atomic \\'98 (Xenomania Mix) - Blondie": 582,
#  'Atrevete Y Mirame - Limi-T 21': 583,
#  'Atrevido - Orishas': 584,
#  'Atrévete te te - Calle 13': 585,
#  'Attention (Album Version) - The Academy Is...': 586,
#  'Attention - The Raconteurs': 587,
#  'Attica Blues - Archie Shepp': 588,
#  'Auburn and Ivory - Beach House': 589,
#  'Audience Of One - Cold War Kids': 590,
#  'Audience Of One - Rise Against': 591,
#  'Auditorium - Mos Def / Slick Rick': 592,
#  'Aunt Eggma Blowtorch - Neutral Milk Hotel': 593,
#  'Australia (Album) - The Shins': 594,
#  'Australia - Jonas Brothers': 595,
#  'Auto Rock - Mogwai': 596,
#  'Auto rojo - Vilma Palma e Vampiros': 597,
#  'Auto-Dub - Skream': 598,
#  'Autobiography - Ashlee Simpson': 599,
#  'Automatik - Livvi Franc': 600,
#  'Automobile (Feat. Eazy-E) - N.W.A featuring Eazy-E': 601,
#  'Automotywacja - Vienio & Pele': 602,
#  'Autumn (Album) - Carla Bruni': 603,
#  'Autumn Almanac - The Kinks': 604,
#  'Autumn Music 2 - Max Richter': 605,
#  "Autumn\\'s Child - Devendra Banhart": 606,
#  'Available [feat. Akon] (Album Version) - Flo Rida': 607,
#  'Avalon - Sigur Ros': 608,
#  'Ave Maria - Beyoncé': 609,
#  'Ave Maria - Celtic Woman': 610,
#  'Ave Maria No Morro - João Gilberto': 611,
#  'Avery Island / April 1st - Neutral Milk Hotel': 612,
#  'Awake - Angels Of Light & Akron/Family': 613,
#  'Awake - Godsmack': 614,
#  'Awake - Secondhand Serenade': 615,
#  'Away From The Sun - 3 Doors Down': 616,
#  'Away With Murder - Camera Obscura': 617,
#  'Aww Skeet Skeet - Lil Jon / The East Side Boyz / DJ Flexx': 618,
#  'Axel F (Radio Edit) - Crazy Frog': 619,
#  'Axel F - Harold Faltermeyer': 620,
#  'Ay Dios - Franco De Vita': 621,
#  'Ay Mama - Devendra Banhart': 622,
#  'Azure - Paul Kalkbrenner': 623,
#  'B-B-B-Baby - The Disco Boys': 624,
#  'B.I.G. (Interlude)(Amended Version) - The Notorious B.I.G.': 625,
#  'B.O.B. - OutKast': 626,
#  'BB Good - Jonas Brothers': 627,
#  'BENZIN - Rammstein': 628,
#  'Babel - Massive Attack': 629,
#  'Baby (Album Version) - Devendra Banhart': 630,
#  'Baby (Album Version) - Serj Tankian': 631,
#  'Baby - the bird and the bee': 632,
#  'Baby Blue Eyes (Album Version) - A Rocket To The Moon': 633,
#  'Baby Boy [feat. Beyonce] - Sean Paul': 634,
#  'Baby Come Back - Player': 635,
#  'Baby Daddy (Amended Version) - Lil Scrappy': 636,
#  'Baby Did A Bad Bad Thing (LP Version) - Chris Isaak': 637,
#  'Baby Doll (Edited) - N.E.R.D.': 638,
#  'Baby Fratelli - The Fratellis': 639,
#  'Baby Got Back - Sir Mix-A-Lot': 640,
#  'Baby I Want You - Amos Lee': 641,
#  "Baby I\\'m A Fool - Melody Gardot": 642,
#  "Baby I\\'m Yours - Arctic Monkeys": 643,
#  "Baby I\\'m-A Want You (LP Version) - Bread": 644,
#  "Baby It\\'s You - JoJo / Lil\\' Bow Wow": 645,
#  'Baby Let Me Take You Home - The Animals': 646,
#  'Baby Love - The Supremes': 647,
#  'Baby M - Marumari': 648,
#  "Baby Now That I\\'ve Found You - Alison Krauss / Union Station": 649,
#  "Baby [You\\'ve Got What It Takes] [with Sharon Jones & the Dap-Kings] - Michael Bublé": 650,
#  'Baby said - Hot Chip': 651,
#  "Baby\\'s Got Sauce - G. Love & Special Sauce": 652,
#  'Baby_ I Go Crazy - Josh Turner': 653,
#  'Baby_ I Love Your Way (Album Version) - Big Mountain': 654,
#  "Baby_ It\\'s Fact - Hellogoodbye": 655,
#  'Babylon - Angus & Julia Stone': 656,
#  'Babylon - David Gray': 657,
#  'Babylon - The New York Dolls': 658,
#  'Babylon Sisters - Steely Dan': 659,
#  'Bachelorette (Family Tree Version) - Bjork': 660,
#  'Back 2 Good (LP Version) - matchbox twenty': 661,
#  'Back Against The Wall - Cage The Elephant': 662,
#  'Back At One - Brian McKnight': 663,
#  'Back Down - 50 Cent': 664,
#  'Back Home (Album Version) - Fort Minor (Featuring Common And Styles Of Beyond)': 665,
#  'Back In The Day - Erykah Badu': 666,
#  'Back In Time (LP Version) - Huey Lewis And The News': 667,
#  'Back In Time - V V Brown': 668,
#  'Back It Up - Caro Emerald': 669,
#  'Back Porch - The Presidents of the United States of America': 670,
#  'Back That Azz Up - Juvenile / Mannie Fresh / Lil Wayne': 671,
#  'Back To Black - Amy Winehouse': 672,
#  'Back To Life (Album Version) - Rock Kills Kid': 673,
#  'Back To Life (However Do You Want Me) (2003 Digital Remaster) (Feat. Caron Wheeler) - Soul II Soul Featuring Caron Wheeler': 674,
#  'Back To Me - The All-American Rejects': 675,
#  'Back To School (Mini Maggit) (LP Version) - Deftones': 676,
#  'Back To The Ground - Jamie Cullum': 677,
#  'Back To The Old House - The Smiths': 678,
#  'Back To You - John Mayer': 679,
#  'Back from hell - NARNIA': 680,
#  'Backdoor Love Affair (LP Version) - ZZ Top': 681,
#  'Backdrifts - Radiohead': 682,
#  'Backstabber - Ke$ha': 683,
#  'Bad - U2': 684,
#  'Bad Actors - Flying Lotus': 685,
#  "Bad Apples - Guns N\\' Roses": 686,
#  'Bad Boys - Alexandra Burke Feat. Flo Rida': 687,
#  'Bad Company - Five Finger Death Punch': 688,
#  'Bad Day (Album Version) - Daniel Powter': 689,
#  'Bad Detective - New York Dolls': 690,
#  'Bad Girlfriend [Explicit] - Theory Of A Deadman': 691,
#  'Bad Is Bad - Huey Lewis & The News': 692,
#  'Bad Luck - Hot Chip': 693,
#  'Bad Meets Evil - Eminem / Royce Da 5-9': 694,
#  'Bad Moon Rising - Creedence Clearwater Revival': 695,
#  'Bad News - Kanye West': 696,
#  'Bad Sneakers - Steely Dan': 697,
#  'Bad Trails - Battles': 698,
#  'Bad Weed - Junior Murvin': 699,
#  'Bada - Flaminio Maphia': 700,
#  'Bag Lady - Erykah Badu': 701,
#  'Baggy Trousers - Madness': 702,
#  'Bagpipes From Baghdad - Eminem': 703,
#  'Baila Esta Cumbia - Selena': 704,
#  'Bailamos - Enrique Iglesias': 705,
#  'Baker Street (Edit) - Gerry Rafferty': 706,
#  "Baker\\'s Blue Jay Yarn - Dakota Oak": 707,
#  'Balaclava - Arctic Monkeys': 708,
#  'Balada Del Diablo y La Muerte - La Renga': 709,
#  'Ball & Chain (Album) - Social Distortion': 710,
#  'Ball And Chain - Janis Joplin': 711,
#  "Ball Of Confusion (That\\'s What The World Is Today) - The Temptations": 712,
#  'Ballad Of A Comeback Kid - The New Pornographers': 713,
#  'Ballad Of Big Nothing - Elliott Smith': 714,
#  'Ballad Of Mott The Hoople - Mott The Hoople': 715,
#  'Balloons (Single version) - Foals': 716,
#  'Baltimore Blues No. 1 - Deer Tick': 717,
#  'Bam Bam - Sister Nancy': 718,
#  'Banana Co - Radiohead': 719,
#  'Banana Ghost - Man Man': 720,
#  'Band of Gold - Freda Payne': 721,
#  'Bandelero - Slightly Stoopid': 722,
#  'Bang Bang - Dispatch': 723,
#  "Bang Bang - Dr. Dre / Hittman / Knoc-Turn\\'al": 724,
#  "Bang Bang - K\\'naan / Adam Levine": 725,
#  'Bang On The Drum - Todd Rundgren': 726,
#  'Bankrupt On Selling - Modest Mouse': 727,
#  'Banned Announcement - Bill Wells & Maher Shalal Hash Baz': 728,
#  'Banquet (Phones Disco Edit) - Bloc Party': 729,
#  'Banquet - Bloc Party': 730,
#  'Baobabs (Bonus Album Version) - Regina Spektor': 731,
#  'Baptism - Crystal Castles': 732,
#  'Bar Tacuba - Café Tacvba': 733,
#  'Bard Dance - Enya': 734,
#  'Barely Breathing (LP Version) - DUNCAN SHEIK': 735,
#  'Barfly - Ray LaMontagne': 736,
#  'Bark At The Moon - Ozzy Osbourne': 737,
#  "Bartender Song (Sittin\\' At A Bar) - Rehab": 738,
#  'Basic Space - The xx': 739,
#  'Bass Solo - Incubus': 740,
#  'Bastards on Parade - Dropkick Murphys': 741,
#  'Bat Country (Album Version) - Avenged Sevenfold': 742,
#  'Batdance ( LP Version ) - Prince': 743,
#  'Battle - Colbie Caillat': 744,
#  'Battle For The Sun - Placebo': 745,
#  'Be (Intro) - Common': 746,
#  'Be Aggressive - Faith No More': 747,
#  'Be Aware - Bobby Lee': 748,
#  'Be Good Or Be Gone - Fionn Regan': 749,
#  'Be Kind - Devendra Banhart': 750,
#  'Be Less Rude - Frightened Rabbit': 751,
#  'Be Like You - Notes From Underground': 752,
#  'Be My Baby - The Ronettes': 753,
#  'Be My Lover - Alice Cooper': 754,
#  'Be On You [feat. Ne-Yo] (Album Version) - Flo Rida': 755,
#  'Be Somebody - 3 Doors Down': 756,
#  'Be Somebody - Kings Of Leon': 757,
#  'Be Wild - M83': 758,
#  'Be With You - Akon': 759,
#  'Be With You - Beyoncé': 760,
#  'Be With You - Enrique Iglesias': 761,
#  'Be Yourself (Album Version) - Audioslave': 762,
#  'Beach Baby - Bon Iver': 763,
#  'Beach Party - Air France': 764,
#  'Beach Party - Hot Chip': 765,
#  'Beat Goes On [Featuring Kanye West] (Album Version) - Madonna': 766,
#  'Beat It - Fall Out Boy': 767,
#  'Beat Somebody Up - MDC': 768,
#  'Beatbox (Nus Track) - Arma Blanca': 769,
#  "Beatnik Beach (Live) (1981) - The Go-Go\\'s": 770,
#  'Beauties Can Die - M83': 771,
#  'Beautiful - 10 Years': 772,
#  'Beautiful - Audio Adrenaline': 773,
#  'Beautiful - Christina Aguilera': 774,
#  'Beautiful - Damian Marley / Bobby Brown': 775,
#  'Beautiful - India.Arie': 776,
#  'Beautiful - Moby': 777,
#  'Beautiful Bride - Flyleaf': 778,
#  'Beautiful Dangerous (featuring Fergie) - Slash': 779,
#  'Beautiful Day Without You - Röyksopp': 780,
#  'Beautiful Disaster - Jon McLaughlin': 781,
#  'Beautiful Friday - Andru Donalds': 782,
#  'Beautiful Liar - Beyonce & Shakira': 783,
#  'Beautiful Life - Ace of Base': 784,
#  'Beautiful Morning - Ace of Base': 785,
#  'Beautiful Stranger - Madonna': 786,
#  'Beautiful_ Beautiful (Album) - Francesca Battistelli': 787,
#  'Beautiful_ Dirty_ Rich - Lady GaGa': 788,
#  'Beauty Beats - Beats Antique': 789,
#  'Beauty School (Album Version) - Deftones': 790,
#  'Bebot - Black Eyed Peas': 791,
#  'Because I Got High - Afroman': 792,
#  'Because Of You (Album Version) - Nickelback': 793,
#  'Because The Night [MTV Unplugged Version] - 10_000 Maniacs': 794,
#  'Because We Can - Fatboy Slim': 795,
#  "Because We\\'re Dead - Slow Club": 796,
#  'Because You Loved Me - Céline Dion': 797,
#  'Becoming Insane - Infected Mushroom': 798,
#  'Becoming [Live Version] - Pantera': 799,
#  'Bed - J. Holiday': 800,
#  'BedRock (Radio Edit) (feat.Lloyd) - Young Money featuring Lloyd': 801,
#  'Bedlam 1-2-3 - Exodus': 802,
#  'Bedroom Boom (Feat. Avant) - Ying Yang Twins': 803,
#  'Bedroom Suite - Joe Christmas': 804,
#  'Beds Are Burning - Midnight Oil': 805,
#  'Been A Son - Nirvana': 806,
#  'Been Around The World (Featuring The Notorious B.I.G. & Mase)(Album Version) - Puff Daddy': 807,
#  "Been Caught Stealing ( LP Version ) - Jane\\'s Addiction": 808,
#  'Beer - Reel Big Fish': 809,
#  'Before I Forget (Album Version) - Slipknot': 810,
#  'Before I Let You Go - Blackstreet': 811,
#  'Before You Accuse Me (Album Version) - Eric Clapton': 812,
#  'Before You Accuse Me - Creedence Clearwater Revival': 813,
#  'Before You Cry - Camera Obscura': 814,
#  "Beggin\\' - Madcon": 815,
#  'Beginners Falafel - Flying Lotus': 816,
#  'Behave - Frightened Rabbit': 817,
#  'Behind Blue Eyes - Limp Bizkit': 818,
#  'Behind Closed Doors - Rise Against': 819,
#  'Behind The Screams - CKY': 820,
#  'Behind The Sea [Live In Chicago] - Panic At The Disco': 821,
#  'Behind The Sun - Red Hot Chili Peppers': 822,
#  'Bela Flor - Maria Gadú': 823,
#  'Believe (Album Version) - Skillet': 824,
#  'Believe - The All-American Rejects': 825,
#  'Believe - Yellowcard': 826,
#  'Believe In Me (A&T Remix) - ATB': 827,
#  'Bella - Angus & Julia Stone': 828,
#  "Bella\\'s Lullaby (Twilight Soundtrack Version) - Carter Burwell": 829,
#  'Belle - Jack Johnson': 830,
#  'Bellevue - Miami Horror': 831,
#  'Beloved - Tenth Avenue North': 832,
#  'Beloved Kitty and the Piercing Bolts of Amor - Ordo Rosarius Equilibrio': 833,
#  'Ben - Jackson 5': 834,
#  'Bend & Flush - Pork Dukes': 835,
#  'Bendable Poseable - Hot Chip': 836,
#  'Beneath The Surface - GZA/Genius / Killah Priest': 837,
#  'Beneath an Evening Sky - Aisha Duo': 838,
#  'Bent (LP Version) - matchbox twenty': 839,
#  "Bentley\\'s Gonna Sort You Out - Bentley Rhythm Ace": 840,
#  'Berlin Heart - The Dears': 841,
#  'Bermuda - Fluke': 842,
#  "Bernie\\'s Funeral/ Auto Asphixiation - Luke Haines": 843,
#  'Besame - Camila': 844,
#  'Besame Mucho - Andrea Bocelli': 845,
#  'Besos - Lucas Masciano': 846,
#  'Best I Ever Had - Gary Allan': 847,
#  'Best Of Both Worlds (Remastered Album Version) - Van Halen': 848,
#  'Best Thing - Usher featuring Jay Z': 849,
#  'Bestrafe Mich - Rammstein': 850,
#  'Bette Davis Eyes - Kim Carnes': 851,
#  'Better Days - Amos Lee': 852,
#  'Better Days To Come - Lonesome River Band': 853,
#  'Better Man - Pearl Jam': 854,
#  'Better Off Alone - Alice Deejay': 855,
#  'Better Off Dead - New Found Glory': 856,
#  'Better Than (Album Version) - John Butler Trio': 857,
#  'Better Than Me - Hinder': 858,
#  'Better That We Break - Maroon 5': 859,
#  'Better The Devil You Know (Showgirl Tour) - Kylie Minogue': 860,
#  'Better Things - Everything But The Girl': 861,
#  'Better To Reign In Hell - Cradle Of Filth': 862,
#  'Better Together - Jack Johnson': 863,
#  'Better Version Of Me - Fiona Apple': 864,
#  'Better in time - Leona Lewis': 865,
#  'Betterman (full-length/album version) - John Butler Trio': 866,
#  'Between A Man And A Woman - Flogging Molly': 867,
#  'Between The Bars - Elliott Smith': 868,
#  'Between The Lines - Sara Bareilles': 869,
#  'Between Two Lungs - Florence + The Machine': 870,
#  'Between Us And Them - Ulrich Schnauss': 871,
#  'Bewildered - The Notting Hillbillies': 872,
#  'Bidi Bidi Bom Bom - Selena': 873,
#  'Big Big Love (Fig .2) - Foals': 874,
#  'Big Big World - Emilia': 875,
#  'Big Booty Hoes (Featuring Too $hort) (Album Version) - The Notorious B.I.G.': 876,
#  'Big Boss Man - Bobbie Gentry': 877,
#  'Big Brother - Kanye West': 878,
#  'Big Calm - Morcheeba': 879,
#  'Big Casino - Jimmy Eat World': 880,
#  "Big Girls Don\\'t Cry - The Four Seasons": 881,
#  'Big Green Tractor - Jason Aldean': 882,
#  'Big Idea - Radney Foster': 883,
#  'Big In Japan (Original) - Alphaville': 884,
#  'Big Jet Plane - Angus & Julia Stone': 885,
#  'Big Lost - Diplo': 886,
#  'Big Me - Foo Fighters': 887,
#  'Big Munny - Swizz Beatz': 888,
#  'Big My Secret - Michael Nyman': 889,
#  'Big Poppa - The Notorious B.I.G.': 890,
#  'Big Sur - The Thrills': 891,
#  'Big Time Sensuality - Björk': 892,
#  'Big Trouble - Man Man': 893,
#  'Big Weenie - Eminem': 894,
#  'Big Yellow Taxi (Remastered LP Version) - Joni Mitchell': 895,
#  'Big Yellow Taxi - Counting Crows / Vanessa Carlton': 896,
#  'Bigger - Justin Bieber': 897,
#  'Bigger Boys And Stolen Sweethearts - Arctic Monkeys': 898,
#  "Bigger Isn\\'t Better - The String Cheese Incident": 899,
#  'Bigger Stronger - Coldplay': 900,
#  'Bigmouth Strikes Again - The Smiths': 901,
#  'Bill Murray - Gorillaz': 902,
#  'Billie Jean - Chris Cornell': 903,
#  'Billionaire - Rick Ross': 904,
#  'Billionaire [feat. Bruno Mars]  (Explicit Album Version) - Travie McCoy': 905,
#  'Billy (Album Version) - James Blunt': 906,
#  'Billy Breathes - Phish': 907,
#  'Billy Liar - The Decemberists': 908,
#  'Bird Song - Florence + The Machine': 909,
#  'Bird Song Intro - Florence + The Machine': 910,
#  'BirdFlu - M.I.A.': 911,
#  'Birds - Kate Nash': 912,
#  'Birds Of A Feather - Phish': 913,
#  'Birds and the Bees - the bird and the bee': 914,
#  'Birthday - Timbaland & Magoo': 915,
#  'Birthday - the bird and the bee': 916,
#  'Birthday Sex - Jeremih': 917,
#  'Biscuit - Portishead': 918,
#  'Bitch - D-12': 919,
#  'Bitch Please (Explicit) (Feat. Xzibit) - Snoop Dogg Featuring Xzibit': 920,
#  'Bitter Sweet Symphony (2004 Digital Remaster) - The Verve': 921,
#  'Bitter Sweet Symphony - The Verve': 922,
#  'Bittersweet - Apocalyptica': 923,
#  'Bittersweet Memories - Bullet For My Valentine': 924,
#  'Bizarre Love Triangle - New Order': 925,
#  "Bla Bla Bla (Abbentenza In FM Mix) - Gigi D\\'agostino": 926,
#  'Black & Blue - Bring Me The Horizon': 927,
#  'Black & Blue - Miike Snow': 928,
#  'Black - Pearl Jam': 929,
#  "Black And White - The dB\\'s": 930,
#  'Black Balloon - The Kills': 931,
#  "Black Betty (In The Style Of \\'Ram Jam\\') - Boggle Karaoke": 932,
#  'Black Betty - Ram Jam': 933,
#  'Black Betty - Spiderbait': 934,
#  'Black Bird - Evan Rachel Wood': 935,
#  'Black Cadillacs - Modest Mouse': 936,
#  'Black Cat (Album) - Mayday Parade': 937,
#  'Black Cherry - Goldfrapp': 938,
#  'Black Cloud - Crazy Town': 939,
#  'Black Door - The Black Keys': 940,
#  'Black Eyed Dog (Album Version) - Nick Drake': 941,
#  'Black Heroes - Ratatat': 942,
#  'Black Hole - She & Him': 943,
#  'Black Hole Sun - Soundgarden': 944,
#  'Black Horse And The Cherry Tree (Radio Version) - KT Tunstall': 945,
#  'Black Is Black - MC Hammer': 946,
#  'Black Is My Color - I-Roy': 947,
#  'Black Jack County Chains - The Del McCoury Band': 948,
#  'Black Mags - The Cool Kids': 949,
#  'Black Man Ray - China Crisis': 950,
#  'Black Masks & Gasoline - Rise Against': 951,
#  'Black Mirror - Arcade Fire': 952,
#  'Black Mission Goggles - Man Man': 953,
#  'Black Mud - The Black Keys': 954,
#  'Black Refuge - Junip': 955,
#  'Black River - Amos Lee': 956,
#  'Black River Killer (Album) - Blitzen Trapper': 957,
#  'Black Rose Dying (Album Version) - blessthefall': 958,
#  'Black Sands - Bonobo': 959,
#  'Black Star - Radiohead': 960,
#  'Black Swan - Thom Yorke': 961,
#  'Black Water - Edward Sharpe & The Magnetic Zeros': 962,
#  'Black Wave (Album) - The Shins': 963,
#  'Black Wave/Bad Vibrations - Arcade Fire': 964,
#  'Black and White - The String Cheese Incident': 965,
#  'Blackberry Stone - Laura Marling': 966,
#  'Blackbird - Alter Bridge': 967,
#  'Blackbird - Sony Wonder': 968,
#  'Blackbirds - Erin McKeown': 969,
#  'Blackest Eyes (Album Version) - Porcupine Tree': 970,
#  'Blagunyo Denche - Kultur Shock': 971,
#  'Blake\x19s View - M Ward': 972,
#  'Blame It - Jamie Foxx featuring T-Pain': 973,
#  'Blame It On The Boogie - The Jacksons': 974,
#  'Blame It On The Rain - Milli Vanilli': 975,
#  'Blame It On The Tetons - Modest Mouse': 976,
#  'Blank Expression - Lily Allen': 977,
#  'Blasphemous rumours - ANGELZOOM': 978,
#  'Bleacher - I Wayne': 979,
#  'Bleed It Out [Live At Milton Keynes] - Linkin Park': 980,
#  'Bleeding Heart - Jimi Hendrix': 981,
#  'Bleeding Hearts - Soltero': 982,
#  'Bleeding Love - Leona Lewis': 983,
#  'Bleeding Mascara (Album Version) - Atreyu': 984,
#  'Bleeding Me - Metallica': 985,
#  'Blessa - Toro Y Moi': 986,
#  'Blessed Be Your Name - Matt Redman': 987,
#  'Blind - Hercules & Love Affair': 988,
#  'Blind - Lifehouse': 989,
#  'Blind Date - Bouncing Souls': 990,
#  'Blinded [When I See You] - Third Eye Blind': 991,
#  'Blindfold - Morcheeba': 992,
#  'Blindsided - Bon Iver': 993,
#  'Bling (Confession Of A King) - The Killers': 994,
#  'Bliss - Muse': 995,
#  'Blister In The Sun - Violent Femmes': 996,
#  'Blood - El-P': 997,
#  'Blood Bank - Bon Iver': 998,
#  'Blood On The Ground - Incubus': 999,
#  ...}

# %% [markdown]
# ### Applying the personalized model to make song recommendations
#
# As you can see, different users get different recommendations now.

# %%
show_songs_list(recommend(users=[users[0]]))
# Out:
# User b80344d063b5ccb3212f76538f3d9e43d87dca9e's recommended songs:'
# Moonshine - Jack Johnson
# Behind The Sea [Live In Chicago] - Panic At The Disco
# I\'ll Be Missing You (Featuring Faith Evans & 112)(Album Version) - Puff Daddy
# I?\'m A Steady Rollin? Man - Robert Johnson
# Por La Noche - Mala Rodriguez
# Apuesta Por El Rock \'N\' Roll - Héroes del Silencio
# Ya No Sos Igual - 2 Minutos
# Bigger Isn\'t Better - The String Cheese Incident
# The Cove - Jack Johnson
# Constellations - Jack Johnson
# Holes To Heaven - Jack Johnson
# Héroe De Leyenda - Héroes del Silencio
# Love Song For No One - John Mayer
# People Watching - Jack Johnson
# Ghost Dream - Hymie\'s Basement
# Neon - John Mayer
# Danse Pour Moi - M. Pokora
# Flashdance... What A Feeling - Irene Cara
# B.I.G. (Interlude)(Amended Version) - The Notorious B.I.G.
# The Message/ Outro - Dr. Dre / Thomas Chong / Mary J. Blige / Rell
# /home/leanh/anaconda3/envs/ml-301x/lib/python3.7/site-packages/ipykernel_launcher.py:25: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
show_songs_list(recommend(users=[users[1]]))
# Out:
# User 85c1f87fea955d09b4bec2e36aee110927aedf9a's recommended songs:'
# The Best of Times - Sage Francis
# Side To Side (Featuring Lateef & Pigeon John) (Album Version) - Blackalicious
# Big Munny - Swizz Beatz
# Southside - Common / Kanye West
# It\'s Me B*#@hes - Swizz Beatz
# You Know Your Boy Did That - Swizz Beatz
# Work (Explicit) - Gang Starr
# Diamonds From Sierra Leone - Kanye West / Jay-Z
# Never Let Me Down - Kanye West / Jay-Z / J. Ivy
# The Food - Common
# Ringing Bells - Masta Killa
# Bring The Noize - DMX
# In Between The Years - Ulrich Schnauss
# Down And Out (Album Version) - The Academy Is...
# Mutha\'uckas (Album Version) - Flight Of The Conchords
# The Choice Is Yours - Black Sheep
# Maxine - Traveling Wilburys
# Is She Weird - Pixies
# Kick In The Door (Soundtrack Version) (Explicit) - Notorious B.I.G.
# Beloved Kitty and the Piercing Bolts of Amor - Ordo Rosarius Equilibrio
# /home/leanh/anaconda3/envs/ml-301x/lib/python3.7/site-packages/ipykernel_launcher.py:25: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %% [markdown]
# ###  We can also apply the model to find similar songs to any song in the dataset

# %%
u2_similar_index = retrieve_similar_items(song_lookup_dict['With Or Without You - U2'], values_kept=5)
print("List of 5 similar songs:\n{}".format("\n".join(song_data_grouped.index[u2_similar_index])))
# Out:
# List of 5 similar songs:
# Decisiones - Ruben Blades
# What I Want - Dead Or Alive
# You Are A Knife - Veto
# Dead Man (Carry Me) - Jars Of Clay
# A Kind Of Hope - Pilot Speed

# %%
bvsc_similar_index = retrieve_similar_items(song_lookup_dict['Chan Chan (Live) - Buena Vista Social Club'], values_kept=5)
print("List of 20 similar songs:\n{}".format("\n".join(song_data_grouped.index[bvsc_similar_index])))
# Out:
# List of 20 similar songs:
# Amor de Loca Juventud - Buena Vista Social Club
# Murmullo - Buena Vista Social Club
# Shaman\'s Blues ( LP Version ) - The Doors
# Until The Morning - Thievery Corporation
# La Bayamesa - Buena Vista Social Club

# %% [markdown]
# # Quantitative comparison between the models
#
# We now formally compare the popularity and the personalized models using precision-recall curves. This may take a while to be done. First of all, we trim the test data and create the functions to check if the songs listened by any users are predicted using our models.

# %%
#if graphlab.version[:3] >= "1.6":
#    model_performance = graphlab.compare(test_data, [popularity_model, personalized_model], user_sample=0.05)
#    graphlab.show_comparison(model_performance,[popularity_model, personalized_model])
#else:
#    %matplotlib inline
#    model_performance = graphlab.recommender.util.compare_models(test_data, [popularity_model, personalized_model], user_sample=.05)

# remove all users that have no data in the training set, just to make sure
sample_test_data = test_data.loc[test_data["user_id"].isin(train_data["user_id"])]
#print("sample test data: \n", sample_test_data.iloc[0])
sample_test_data = sample_test_data.groupby("user_id")["song"].agg(
        lambda x: x.values.tolist()#np.vectorize(song_lookup_dict.get)(x.values).tolist() x.values.tolist() 
    )
#print('sample test after group by', sample_test_data)
def recommend_popularity(user):
    return np.vectorize(song_lookup_dict.get)(popularity.index.values).to_list()

def recommend_personalized(user, song_number=1000):
    return recommend([user], song_number=song_number)["recommend"].to_list()[0]

# %% [markdown]
# Now we calculate the Precision/Recall values for a sample of first 1000 users. Remain patient, preferably with a cup of tea.

# %%
sample_test_data_frame = pandas.DataFrame(data=sample_test_data[:1000])
print('Sample test data frame', sample_test_data)
sample_test_data_frame["rec_personalized"] = sample_test_data_frame.index.to_series().apply(recommend_personalized)
print("Done calculation for general recommendation.")
#print(type(sample_test_data))
sample_test_data_frame.head()
# Out:
# Sample test data frame user_id
# 00003a4459f33b92906be11abe0e93efc423c0ff    [Lights Of Ayodhya - Yulara, Only You (Illumin...
# 00030033e3a2f904a48ec1dd53019c9969b6ef1f                                  [Breathe - Prodigy]
# 0007235c769e610e3d339a17818a5708e41008d9    [Girl Tonite [Featuring Trey Songz] [Explicit ...
# 0007c0e74728ca9ef0fe4eb7f75732e8026a278b        [Thank U (Album Version) - Alanis Morissette]
# 000a5c8b4d8b2c98f7a205219181d039edcd4506    [Stay The Same - Bonobo Featuring Andreya Tria...
#                                                                   ...
# fffce9c1537fbc350ea68823d956eaa8f5236dbe    [Revelry - Kings Of Leon, Wildcat - Ratatat, T...
# fffd6a2bdef646ce9898b628d5dd56c43df69a9d    [Hate It Or Love It - The Game / 50 Cent, The ...
# fffd9635b33f412de8ed02e44e6564e3644cf3c6    [If I Ain\'t Got You - Alicia Keys, The Batter...
# fffe6d1d8500f1c1f31bd63abce35c0f975a86bf    [Let Me Think About It - Ida Corr Vs Fedde Le ...
# fffea3d509760c984e7d40789804c0e5e289cc86    [One More Time (Short Radio Edit) - Daft Punk,...
# Name: song, Length: 58371, dtype: object
# /home/leanh/anaconda3/envs/ml-301x/lib/python3.7/site-packages/ipykernel_launcher.py:25: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# Done calculation for general recommendation.
#                                                                                        song  \
# user_id
# 00003a4459f33b92906be11abe0e93efc423c0ff  [Lights Of Ayodhya - Yulara, Only You (Illumin...
# 00030033e3a2f904a48ec1dd53019c9969b6ef1f                                [Breathe - Prodigy]
# 0007235c769e610e3d339a17818a5708e41008d9  [Girl Tonite [Featuring Trey Songz] [Explicit ...
# 0007c0e74728ca9ef0fe4eb7f75732e8026a278b      [Thank U (Album Version) - Alanis Morissette]
# 000a5c8b4d8b2c98f7a205219181d039edcd4506  [Stay The Same - Bonobo Featuring Andreya Tria...
#
#                                                                            rec_personalized
# user_id
# 00003a4459f33b92906be11abe0e93efc423c0ff  [2051, 9201, 5948, 9862, 7718, 4831, 4, 769, 2...
# 00030033e3a2f904a48ec1dd53019c9969b6ef1f  [7110, 1436, 9873, 4402, 47, 7122, 2062, 9077,...
# 0007235c769e610e3d339a17818a5708e41008d9  [3006, 7858, 5469, 183, 1998, 9829, 9338, 3308...
# 0007c0e74728ca9ef0fe4eb7f75732e8026a278b  [8170, 9825, 3256, 4225, 3340, 8159, 2087, 522...
# 000a5c8b4d8b2c98f7a205219181d039edcd4506  [8374, 1996, 959, 7743, 9345, 309, 5779, 4568,...

# %% [markdown]
# <b>Optional: Can we optimize this process?<b>
# Recall our recommend() function can take in an iterable (list/Series) of users. Can we use a better mapping for rec_personalized? and is it faster?

# %%
popularity_data, personalized_data = [], []
def count_correct(songs, recs):
    return sum( (1 if song in recs else 0 for song in songs) )
    
for num_recommend in np.arange(100, 10, -10):
    #num_recommend = int(float(len(popularity)) * p)
    #print('popularity:\n', popularity.head())
    #print('\n\n\npopularity index:\n', popularity.index)
    #print('n\n\npopularity values:\n', popularity.values)
    #print('n\n\npopularity.index.values:\n', popularity.index.values)


    popularity_recommendation = np.vectorize(song_lookup_dict.get)(popularity.index.values)[:num_recommend]
    popular_fn = lambda row: (count_correct(row["song"], popularity_recommendation), len(row["song"]), num_recommend)
    precision_recall_popularity = sample_test_data_frame.apply(popular_fn, axis=1, result_type='reduce')
    correct, all_entry, all_guesses = (float(sum(x)) for x in zip(*precision_recall_popularity))
    precision = correct / all_entry
    recall = correct / all_guesses
    popularity_data.append( (precision, recall) )
    print("Popularity: precision: {:.4f}, recall: {:.4f}, {}-{}-{}".format(precision * 100.0, recall * 100.0, correct, all_entry, all_guesses))
    sample_test_data_frame["rec_personalized"] = sample_test_data_frame["rec_personalized"].apply(lambda row: row[:num_recommend])
    precision_recall_personalized = sample_test_data_frame.apply(lambda row: (count_correct(row["song"], row["rec_personalized"]), len(row["song"]), num_recommend), axis=1, result_type='reduce')
    correct, all_entry, all_guesses = (float(sum(x)) for x in zip(*precision_recall_personalized))
    precision = correct / all_entry
    recall = correct / all_guesses
    personalized_data.append( (precision, recall) )
    print("Personalized: precision: {:.4f}, recall: {:.4f}, {}-{}-{}".format(precision * 100.0, recall * 100.0, correct, all_entry, all_guesses))
    
popularity_data.append((0.0, 1.0))
personalized_data.append((0.0, 1.0))
# Out:
# /home/leanh/anaconda3/envs/ml-301x/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   This is separate from the ipykernel package so we can avoid doing imports until
# Popularity: precision: 0.0000, recall: 0.0000, 0.0-3861.0-100000.0
# Personalized: precision: 0.0000, recall: 0.0000, 0.0-3861.0-100000.0
# Popularity: precision: 0.0000, recall: 0.0000, 0.0-3861.0-90000.0
# Personalized: precision: 0.0000, recall: 0.0000, 0.0-3861.0-90000.0
# Popularity: precision: 0.0000, recall: 0.0000, 0.0-3861.0-80000.0
# Personalized: precision: 0.0000, recall: 0.0000, 0.0-3861.0-80000.0
# Popularity: precision: 0.0000, recall: 0.0000, 0.0-3861.0-70000.0
# Personalized: precision: 0.0000, recall: 0.0000, 0.0-3861.0-70000.0
# Popularity: precision: 0.0000, recall: 0.0000, 0.0-3861.0-60000.0
# Personalized: precision: 0.0000, recall: 0.0000, 0.0-3861.0-60000.0
# Popularity: precision: 0.0000, recall: 0.0000, 0.0-3861.0-50000.0
# Personalized: precision: 0.0000, recall: 0.0000, 0.0-3861.0-50000.0
# Popularity: precision: 0.0000, recall: 0.0000, 0.0-3861.0-40000.0
# Personalized: precision: 0.0000, recall: 0.0000, 0.0-3861.0-40000.0
# Popularity: precision: 0.0000, recall: 0.0000, 0.0-3861.0-30000.0
# Personalized: precision: 0.0000, recall: 0.0000, 0.0-3861.0-30000.0
# Popularity: precision: 0.0000, recall: 0.0000, 0.0-3861.0-20000.0
# Personalized: precision: 0.0000, recall: 0.0000, 0.0-3861.0-20000.0

# %%
lw=0.5
plt.figure()
popularity_precisions, popularity_recall = zip(*popularity_data)
plt.plot([1.0 - r for r in popularity_recall], list(popularity_precisions), color='darkorange',
         lw=lw, label='ROC curve (popularity)')
personal_precisions, personal_recall= zip(*personalized_data)
plt.plot([1.0 - r for r in personal_recall], list(personal_precisions), color='green',
         lw=lw, label='ROC curve (personalized)')
plt.plot([0.0, 0.5], [0.0, 0.5], color='navy', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# The curve shows that the personalized model provides much better performance, since the accuracy increased constantly as we raise the number of recommendations being made.
