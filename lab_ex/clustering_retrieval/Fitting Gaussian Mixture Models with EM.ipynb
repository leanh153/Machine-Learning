# %% [markdown]
# # Fitting Gaussian Mixture Models with EM
#
# In this assignment you will
# * implement the EM algorithm for a Gaussian mixture model
# * apply your implementation to cluster images
# * explore clustering results and interpret the output of the EM algorithm

# %% [markdown]
# **Note to Amazon EC2 users**: To conserve memory, make sure to stop all the other notebooks before running this notebook.

# %% [markdown]
# ## Import necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import copy
#from scipy.stats import multivariate_normal

# %matplotlib inline

# %% [markdown]
# ### Try the model on simulated data
#
# To visually comprehend how the EM model will work, we will generate some observations from a mixture of Gaussians and then run our EM algorithm to discover the mixture components. We'll begin with a function to generate the data, and a quick plot to visualize its output for a 2-dimensional mixture of three Gaussians.
#
# Now we will create a function to generate data from a mixture of Gaussians model.

# %%
def generate_MoG_data(num_data, means, covariances, weights):
    """ Creates a list of data points """
    num_clusters = len(weights)
    data = []
    for i in range(num_data):
        #  Use np.random.choice and weights to pick a cluster id greater than or equal to 0 and less than num_clusters.
        k = np.random.choice(len(weights), 1, p=weights)[0]

        # Use np.random.multivariate_normal to create data from this cluster
        x = np.random.multivariate_normal(means[k], covariances[k])

        data.append(x)
    return data

# %% [markdown]
# After specifying a particular set of clusters (so that the results are reproducible across assignments), we use the above function to generate a dataset.

# %%
# Model parameters
init_means = [
    [5, 0], # mean of cluster 1
    [1, 1], # mean of cluster 2
    [0, 5]  # mean of cluster 3
]
init_covariances = [
    [[.5, 0.], [0, .5]], # covariance of cluster 1
    [[.92, .38], [.38, .91]], # covariance of cluster 2
    [[.5, 0.], [0, .5]]  # covariance of cluster 3
]
init_weights = [1/4., 1/2., 1/4.]  # weights of each cluster

# Generate data
np.random.seed(4)
data = generate_MoG_data(100, init_means, init_covariances, init_weights)

# %% [markdown]
# Now plot the data you created above. The plot should be a scatterplot with 100 points that appear to roughly fall into three clusters.

# %%
plt.figure()
d = np.vstack(data)
plt.plot(d[:,0], d[:,1],'ko')
plt.rcParams.update({'font.size':16})
plt.tight_layout()

# %% [markdown]
# Now we'll fit a mixture of Gaussians to this data using our implementation of the EM algorithm. As with k-means, it is important to ask how we obtain an initial configuration of mixing weights and component parameters. In this simple case, we'll take three random points to be the initial cluster means, use the empirical covariance of the data to be the initial covariance in each cluster (a clear overestimate), and set the initial mixing weights to be uniform across clusters.
#
# For sklearn's model, there is no internal customization to output values, but fortunately we can still listen to its log through `sys.stdout` stream. **Enable `verbose=50` to save the model running course to a buffer.**

# %%
# redirect the log print into a buffer
from sklearn.mixture import GaussianMixture
import io, sys
log_buffer = io.StringIO()
default_stdout = sys.stdout
sys.stdout = log_buffer

# Create the model using Sklearn's library. Make sure to set verbosity to level 50
model = GaussianMixture(n_components=len(init_weights), init_params='random', verbose_interval=5, verbose=50, random_state=5) 
# model = GaussianMixture(n_components=len(init_weights), verbose=50, random_state=5) 

model.fit(data)
# results = EM(data, initial_means, initial_covs, initial_weights)

sys.stdout = default_stdout
log_buffer.seek(0)
print(log_buffer.read())
# Out:
# Initialization 0
#   Iteration 5	 time lapse 0.00575s	 ll change 0.13284
#   Iteration 10	 time lapse 0.00603s	 ll change 0.00808
#   Iteration 15	 time lapse 0.00567s	 ll change 0.03764
#   Iteration 20	 time lapse 0.00568s	 ll change 0.01459
#   Iteration 25	 time lapse 0.00565s	 ll change 0.00090
# Initialization converged: True	 time lapse 0.02881s	 ll -3.18832

# %% [markdown]
# **Note**. Like k-means, EM is prone to converging to a local optimum. In practice, you may want to run EM multiple times with different random initialization. We have omitted multiple restarts to keep the assignment reasonably short. For the purpose of this assignment, we assign a particular random seed (`random_state=5`) to ensure consistent results among the students.

# %% [markdown]
# We can extract related information from the fitted model in variable `model`. Specific parameters can be found <a href="https://scikit-learn.org/stable/modules/generated/sklearn.mixture.GaussianMixture.html">here</a>.

# %% [markdown]
# *For the following quiz questions, please round your answer to the nearest thousandth (3 decimals)*
#
# **Quiz Question**: What is the weight that EM assigns to the first component after running the above codeblock?

# %%
# Your code here
model.weights_[0]
# Out:
# 0.5193462514759948

# %% [markdown]
# **Quiz Question**: Using the same set of results, obtain the mean that EM assigns the second component. What is the mean in the first dimension?

# %%
# Your code here
model.means_[1, 0]
# Out:
# 0.021343771100858847

# %% [markdown]
# **Quiz Question**: Using the same set of results, obtain the covariance that EM assigns the third component. What is the variance in the first dimension?

# %%
# Your code here
model.covariances_[2, 0]
# Out:
# array([ 0.35587078, -0.01519138])

# %% [markdown]
# ### Plot progress of parameters

# %% [markdown]
# One useful feature of testing our implementation on low-dimensional simulated data is that we can easily visualize the results.
#
# We will use the following `plot_contours` function to visualize the Gaussian components over the data at three different points in the algorithm's execution:
#
# 1. At initialization (using initial_mu, initial_cov, and initial_weights)
# 2. After running the algorithm to completion
# 3. After just 12 iterations (using parameters estimates returned when setting `maxiter=12`)

# %%
import matplotlib.mlab as mlab

# provided function to display bivariate normal contours
def bivariate_normal(X, Y, sigmax=1.0, sigmay=1.0,
                     mux=0.0, muy=0.0, sigmaxy=0.0):

    
    Xmu = X-mux
    Ymu = Y-muy

    rho = sigmaxy/(sigmax*sigmay)
    z = Xmu**2/sigmax**2 + Ymu**2/sigmay**2 - 2*rho*Xmu*Ymu/(sigmax*sigmay)
    denominator = 2*np.pi*sigmax*sigmay*np.sqrt(1-rho**2)
    return np.exp(-z/(2*(1-rho**2))) / denominator


def plot_contours(data, means, covs, title):
    plt.figure()
    plt.plot([x[0] for x in data], [y[1] for y in data],'ko') # data

    delta = 0.025
    k = len(means)
    x = np.arange(-2.0, 7.0, delta)
    y = np.arange(-2.0, 7.0, delta)
    X, Y = np.meshgrid(x, y)
    col = ['green', 'red', 'indigo']
    for i in range(k):
        mean = means[i]
        cov = covs[i]
        sigmax = np.sqrt(cov[0, 0])
        sigmay = np.sqrt(cov[1, 1])
        sigmaxy = cov[0][1]/(sigmax*sigmay)
        Z = bivariate_normal(X, Y, sigmax, sigmay, mean[0], mean[1], sigmaxy)
        plt.contour(X, Y, Z, colors = col[i])
        plt.title(title)
    plt.rcParams.update({'font.size':16})
    plt.tight_layout()

# %%
# Parameters after running EM to convergence
results = model.predict(data)
plot_contours(data, model.means_, model.covariances_, 'Final clusters')

# %% [markdown]
# **Quiz Question**: Plot the loglikelihood that is observed at each iteration. Is the loglikelihood plot monotonically increasing, monotonically decreasing, or neither [multiple choice]?

# %%
# extract the log likelihood from the buffer
import re
log_buffer.seek(0)
buffered_text = log_buffer.read()
# YOUR CODE HERE
# use regex to get all number then replace ".-" with "" then check whether that numberic
loglikelihoods_num = np.array([float(x) for x in re.findall("-?\d+\.\d+.", buffered_text) if re.sub(r"[-\.]", "", x).isnumeric()])
# [::-1]  reverse np array, cumsum: cumulate sum, loglikelihoods_num[-1] 
# is last loglikelihood, -loglikelihoods_num[::-1][1:] negative of inverse of changing
loglikelihoods = np.cumsum(np.append(loglikelihoods_num[-1], -loglikelihoods_num[::-1][1:]))[:-1][::-1] 
loglikelihoods
# Out:
# array([-3.24953, -3.24145, -3.20381, -3.18922, -3.18832])

# %%
plt.plot(range(len(loglikelihoods)), loglikelihoods, linewidth=4)
plt.xlabel('Iteration')
plt.ylabel('Log-likelihood')
plt.rcParams.update({'font.size':16})
plt.tight_layout()

# %% [markdown]
# ## Fitting a Gaussian mixture model for image data
#
# Now that we're confident in our implementation of the EM algorithm, we'll apply it to cluster some more interesting data. In particular, we have a set of images that come from four categories: sunsets, rivers, trees and forests, and cloudy skies. For each image we are given the average intensity of its red, green, and blue pixels, so we have a 3-dimensional representation of our data. Our goal is to find a good clustering of these images using our EM implementation; ideally our algorithm would find clusters that roughly correspond to the four image categories.
#
# To begin with, we'll take a look at the data and get it in a form suitable for input to our algorithm. The data are provided in a folder and organized as needed:

# %%
#images = turicreate.SFrame('images.sf')
#import array
#images['rgb'] = images.pack_columns(['red', 'green', 'blue'])['X4']
import os
from matplotlib.image import imread
image_location = "images"
for root, d, files in sorted(os.walk(image_location)):
    for f in sorted(files):
        print("File {:s} located in {:s}".format(f, root))
        #pass

# Show the last file read in the location
last_file = os.path.join(root, f)
last_file_data = imread(last_file)
plt.imshow(last_file_data)
#print(last_file_data.shape)
# Out:
# File ANd9GcQ-HRsM6J42Mc2BJaSFXbxIidQEep8bjhaHdn-xUCfw91f0MHtE.jpg located in images/cloudy_sky
# File ANd9GcQ-yIJezGGCylI2cGGcg9bwTOiVh9iz0mmqI6KVfsdZZqvzBSfQ.jpg located in images/cloudy_sky
# File ANd9GcQ03vCKUO0WH8yUmU3Pt8RFSXpREVrUva_vN7dZnRo5OIt6xoJw.jpg located in images/cloudy_sky
# File ANd9GcQ0sa93MklyNXW_oukodvV0P1-Wyl_bpOLmibpxxbYEkkl4_2Mc.jpg located in images/cloudy_sky
# File ANd9GcQ1D4YUCLe5MCG4xd5iNJGh2f84w-oayS1Gwo4x_hWGthcKB3X9.jpg located in images/cloudy_sky
# File ANd9GcQ202oYoqyMIVhVfSsFu-jmY2KfNQYx5MZuJ8NmwE_DebUmfi7Q.jpg located in images/cloudy_sky
# File ANd9GcQ3G3vcXYRM3wDt31_Uc5M7aZYoNkR6oz1K3qWfXriPQTml3H7J.jpg located in images/cloudy_sky
# File ANd9GcQ44Rr7AMWW8pt_rVDDlyrvaOZvKxTS4MYbDxdanNe8I_mZavPQ-w.jpg located in images/cloudy_sky
# File ANd9GcQ4aRrWRi7PaKSC55a-GHGqEnKoWe9WIcGPI-1ra_2vAJveUEPaZw.jpg located in images/cloudy_sky
# File ANd9GcQ7o765xVKBRmxQV86d_tNQDLYtQDdqTVEkq7NCQaOaNwgKDmjC.jpg located in images/cloudy_sky
# File ANd9GcQ88hel4_MLyc_zJjbxGX3tDkb1GCF6aGNx0KEll3c9Cpxuk7-p.jpg located in images/cloudy_sky
# File ANd9GcQ8aVsiop_6jvwv9gAjF-tM33K00W2nR8o-taJIjEKcjt0OmwlmQQ.jpg located in images/cloudy_sky
# File ANd9GcQ8n7XwIJxEZuJkxpWSqAsSxoR4itQBY3-Uq8B7Wdl3p4jvp4Tw.jpg located in images/cloudy_sky
# File ANd9GcQArho3P1-HKCO0CaxP2b-rdOM9GWOBCny0ZkhZV_-Xxn6iZZX2.jpg located in images/cloudy_sky
# File ANd9GcQBQVSSR6g0Yyi_I94Wu4uc0Q9uTIDm6nx_yFyNJJh4DK_b46Z7.jpg located in images/cloudy_sky
# File ANd9GcQBrvTM9C7sj7UndKDmJz4UZUdMe5ZpoHIIEfUg0iRPW1ycM9gsRw.jpg located in images/cloudy_sky
# File ANd9GcQCpmJHNl41fvMwqPjlEm6X-pHhneT6heju6H9DRz9rBMeSfIwkpQ.jpg located in images/cloudy_sky
# File ANd9GcQD8mhFLRE7B4gNQVSYZX0fkZTQWAnHKy373A8jrGj7wO_S3Ep6nw.jpg located in images/cloudy_sky
# File ANd9GcQDQ1Pvj82zVMLL0-fImRm3XV_NpctgXMkKGgrvKORUeuocfkopjw.jpg located in images/cloudy_sky
# File ANd9GcQDqkIaGATpjrQtDahjItrY47WJ_eMiC5IQXhowlHg64UvunTrnVw.jpg located in images/cloudy_sky
# File ANd9GcQFn22ol1aQZXQ-1nOUCxtxW10CcLhtE70_1Qro-ofW_7sTKOYq.jpg located in images/cloudy_sky
# File ANd9GcQHd24C1XCc_Yk0g2Co75Il2vnze29GXLZEj8x9ut76iFEb3SvIpw.jpg located in images/cloudy_sky
# File ANd9GcQIRMBSTZZhuMak4d3Oh_qd93cLRlwwXjEf3ozWEOCFv2EH4wBa.jpg located in images/cloudy_sky
# File ANd9GcQJ_sQE2fknT5fM8OgP0pBbfVazEfnKsFT6FNQXwgKyPnc76a7r.jpg located in images/cloudy_sky
# File ANd9GcQK6VlNG9yem4C3SdssiD8H4rEUzJJNzaLvBTuYdiMT0Ey3MYv1XQ.jpg located in images/cloudy_sky
# File ANd9GcQKjYb0kFxdKisOvq9WWrpyBgVwCOCVsapzCuLHquSMDZWTadJc.jpg located in images/cloudy_sky
# File ANd9GcQM4l8aL1ZUPs5cnFI1274zF0K-LkRiYzRZCBX89thjYlTadkTxMg.jpg located in images/cloudy_sky
# File ANd9GcQMz3JJJ1i5sjH4dsVykz3AfHJ2ydIwrMhOi2jMjSzAVjFHpYKC.jpg located in images/cloudy_sky
# File ANd9GcQO2tk65UiRmtsdIEtr69urhDbjohFboozxLBHm8TaMT-JXbl2t.jpg located in images/cloudy_sky
# File ANd9GcQO4WVZK_WIGJMEFOMm0M-B20kUbY0b23QzeQO-K1BDsUXRLBQQ2Q.jpg located in images/cloudy_sky
# File ANd9GcQOw3R6Yx9e8KsywpmhKGish-UWoPaZ11_Xyfh44IciTlvXluPO.jpg located in images/cloudy_sky
# File ANd9GcQPJ0iuiQ8qo-lR2KspwEG9LZLuJEdW1oWcLiDbOxo5Ik9OB54kew.jpg located in images/cloudy_sky
# File ANd9GcQSaxQN9ClX1CpXF0fj-ATB6t7cNg78XnkuvqpyijD9eWY1mD8h_A.jpg located in images/cloudy_sky
# File ANd9GcQT-YJ3hICQNXOy8uOK7Y9lm0aObuhrfnCAHGsIVz217ZcwSn12.jpg located in images/cloudy_sky
# File ANd9GcQT9yhx9qwcA4xre40-Cd0tqHd8Zf9NYPlLhGLT5lSCfhC9KrH0MQ.jpg located in images/cloudy_sky
# File ANd9GcQUsf6AbJhY_H_lU05PyzqbAH669tFNdimaoRRATbstYnhBSi4U.jpg located in images/cloudy_sky
# File ANd9GcQVPT03Y6zK6j7ieoWduXIgqiFADBg5Ip1rU4IUJsH5WhoEMWV8.jpg located in images/cloudy_sky
# File ANd9GcQXtN_PXmBq_Es-OJCsSyXo9TSK4xGqg9lkFD1BcQGvi5AXIoNL8g.jpg located in images/cloudy_sky
# File ANd9GcQYEtPaO6uZnrUMvYrhplutoRXO_uPI_Q4ZstVpcccOfzKh4PT0.jpg located in images/cloudy_sky
# File ANd9GcQZLP_oAqN3rH2q2BqEGMMz866Foz8A6DW7F8FvWEh3dAv1oga4Zg.jpg located in images/cloudy_sky
# File ANd9GcQ_MYLHdE6eNM6DwFHygumkXbQc2rymDitibdBJaEUPsJUFg39gUQ.jpg located in images/cloudy_sky
# File ANd9GcQaoOxrMFowXI7eQDHr6d8Uzw5fOgUAKwZt3LpuPYAOCwk4yOwCxg.jpg located in images/cloudy_sky
# File ANd9GcQbM19ibVFi7quH_Jcn0f1j-FuQteanv_cmL7Cnc2YKAlV3Jjj6qw.jpg located in images/cloudy_sky
# File ANd9GcQd79AVr70cCXHbFN5GTStxxyiLYstdCUfhi8eadj_Npb6VEYQY.jpg located in images/cloudy_sky
# File ANd9GcQdO8fq0bjkTkbki3pvNinXBfPie8i1BLOT3XAXIlb_RsYiyK1Tdw.jpg located in images/cloudy_sky
# File ANd9GcQelVb2it2eod9HF62Rteyb7lMmIXd12IwFrf5RUWZag3UB1jzLoA.jpg located in images/cloudy_sky
# File ANd9GcQf_j9m1Ml9rNy-wO0VI5fjq08FyptF-qTc3xgZc_6DUJP7YNMF.jpg located in images/cloudy_sky
# File ANd9GcQgQ-VQAuMOUKMf0EjIdR8zSrgr9pTWUkJdx5-YoD7p4UAm24Us.jpg located in images/cloudy_sky
# File ANd9GcQgSTKxIMOWR8yPks47kYoRH3qnrOfCeicoBqpb-N6lhj4iU76jAA.jpg located in images/cloudy_sky
# File ANd9GcQgV4dJZnzDr6JHCRWDEwBe3a9cp_hoo9fbeZXNJLjzC5RePl4Fuw.jpg located in images/cloudy_sky
# File ANd9GcQikmr2viXcTbVck9sUMN4TdxdBYUgT-Dmo3x1ywRTCjPiGllz_SA.jpg located in images/cloudy_sky
# File ANd9GcQiwXUivlncq-lw1R93qyNzqdaXNp6StkDzqxfdJ2UkZMuXmlZZBg.jpg located in images/cloudy_sky
# File ANd9GcQjKdI8HMvod2TuVkA7TAJZrtpYArEoYpnMrRIcDLX45mPnKG74.jpg located in images/cloudy_sky
# File ANd9GcQjP_siJFh6XOr4X_Kw5UMv4VyfSmixaKP-ZKLG0lIDGb4EA_mA.jpg located in images/cloudy_sky
# File ANd9GcQjScigGm_U88xxwdEXfFdzCxDIDcpTL5FJKg72T6mI8Cta8s-J_A.jpg located in images/cloudy_sky
# File ANd9GcQjpKa2FnH-xBsTtCBl0s3VCW0KL3L14kq65czEpf9g-WHETwqY3g.jpg located in images/cloudy_sky
# File ANd9GcQk0hXpCb8kt50MFM-Yb5IbmotGwec0b99uUDHMX2J8hRUO4v24fA.jpg located in images/cloudy_sky
# File ANd9GcQk2r6zXi0yhW9Prl2Mm1kXaw_TicQ-V4cLaVfEbLv9HbSvZOIW3Q.jpg located in images/cloudy_sky
# File ANd9GcQktrEKdCuyfZuAMfxs4EWvWrsOUjKFxqy7BHdVieu-5NSuetVRBg.jpg located in images/cloudy_sky
# File ANd9GcQl7FBWMWiijWpjI2sQ6BGcRwdQAD6VOxlpYJ47SZljOtDCum86.jpg located in images/cloudy_sky
# File ANd9GcQlCTsTGBIJjgs5Zr3dQbCtIGBVs3FHthCi91bueP1Uf7-mnJu5.jpg located in images/cloudy_sky
# File ANd9GcQls9Ygofmq1jYpH5AMlnc3Tojs2NIIhOLzRm6SDZYDrtuVmXKwLg.jpg located in images/cloudy_sky
# File ANd9GcQnWPitCRAiuKZ-FXAq29ip3rU4-Nf4SgLFfAK-ncbsNj0lfE1Tbg.jpg located in images/cloudy_sky
# File ANd9GcQndGVJcrDZM8cBi69myoXRvpUdKgHyJ3RHqcsVwIU6jBroqkHB.jpg located in images/cloudy_sky
# File ANd9GcQooF458yErkA79PNj14NblHu8sFOQnFbrACJ8XhLsKHUtXBb_-ew.jpg located in images/cloudy_sky
# File ANd9GcQouo2VICwSfdtLYfPudCwPgUbt5glJ5yxLiyUz5RiyeBnPyEf9.jpg located in images/cloudy_sky
# File ANd9GcQpnbZgrtKqtPwGIicxvlxQ8b42efKooxo3sWxrUUPEm-82Rkv6Xw.jpg located in images/cloudy_sky
# File ANd9GcQpsfbMhUgOBDJUq4iVUQ-Wivtc61X6ohPG4jAXS37YTN1O2c4.jpg located in images/cloudy_sky
# File ANd9GcQpwuBPfHNGbMWppmRMbtaZlxmwv4D9j_K_RDbAgLGIcMMPM2RX.jpg located in images/cloudy_sky
# File ANd9GcQqRess069PPw970xOn56aqtqj_1J-Cc1JQ9mR_CzLkwd99hJoz.jpg located in images/cloudy_sky
# File ANd9GcQrNbHEQmpbA-TdI4tCGQLtExOy7vAvmhvAV0QE00ApVCH7y0ZBBA.jpg located in images/cloudy_sky
# File ANd9GcQrt7PhgzX6S7TUBbSr076yA4q3DNkvThriETgMR4aMJ32hvTn_.jpg located in images/cloudy_sky
# File ANd9GcQrz1UgrU3pCv2kvoQ8GyFTTX9zM0bYCGyqQRmSS3IOn18KQAJe.jpg located in images/cloudy_sky
# File ANd9GcQsj-BdubYPClYe0UPxEJNxZaB0PHV0TsYbJVp-YSyO2TXgd0tD.jpg located in images/cloudy_sky
# File ANd9GcQtJeBbVmmnq6My_Z22NC-bKpmkzEX46FUOmrVG-S4rqwK0gpD3.jpg located in images/cloudy_sky
# File ANd9GcQuLuliiB-Udqt59YVeF5SvK3lTS-MxAgDFw05EPa4lPtRPwKx8.jpg located in images/cloudy_sky
# File ANd9GcQurG9OonPUzm6tJNxv5EhpRIty81O8lstxyIEvGyFtwbzzLUMMgA.jpg located in images/cloudy_sky
# File ANd9GcQvfKjhROG__B70sgDT-cdDULrvy0a0EEW_DQW78xDsWcWZ6azQIQ.jpg located in images/cloudy_sky
# File ANd9GcQxWZRF3Jk-YhHi8V-3dmryaSx-8JGpn0_UEcxvp-hQwCBvcxwX.jpg located in images/cloudy_sky
# File ANd9GcQxft4u1BetHXVluPbror5PxaDFwvuAS1uipQ5qMWp8mXUQ7AtG.jpg located in images/cloudy_sky
# File ANd9GcQz1S4MFhnHjb74W9CaCBB4FNiwQlDVYssedl0l6R_3eByqhFs2TQ.jpg located in images/cloudy_sky
# File ANd9GcQzD-gmBj5AmxyL61MDiCLXJRIfdod4FaIhHJajiy-uAxAWmJ9V.jpg located in images/cloudy_sky
# File ANd9GcQzqfPWK-w79rJCAmjfrg9dxh6XxH27jmXJKkrH5qCKjpPWqCLb.jpg located in images/cloudy_sky
# File ANd9GcR-ItBmuGUW0V_RN1QOc5R1SQg1FnAjwMsZGZFFiRe4T4vnju2k.jpg located in images/cloudy_sky
# File ANd9GcR1UN0P6GLGyIPqAvAbvXs_rMO8FFu6qR8_3oMPO4GACRol95xK.jpg located in images/cloudy_sky
# File ANd9GcR1detf0u2Rfm-3nBZ1czpM8xDddNf4YPYu1YL86i8hEhJeMMS0Sw.jpg located in images/cloudy_sky
# File ANd9GcR2Br797HCBU2t3D45BjoXhyia3Ix6p0gydlrUte4EXpBPlO9fwlA.jpg located in images/cloudy_sky
# File ANd9GcR6UFLAnCaCTg3TljQCleldSDDqZMxBQDvFYrPnAXNAPNxaqATY.jpg located in images/cloudy_sky
# File ANd9GcR85WCguS08Hdgo2wM8BJUTfNR3m8aNIQnz3Bk5n-yfzq-oSxWK.jpg located in images/cloudy_sky
# File ANd9GcR9QpLdrv6SIg2aotDtfbX8mY8lPDXxLb3k2Lr-R4oQ-xem-6Nb.jpg located in images/cloudy_sky
# File ANd9GcR9VoCOrcM-2NA5dVlcn--RfTbyUW9NZb-CR4SKqHxnaDzyuGJI.jpg located in images/cloudy_sky
# File ANd9GcR9ntkMXdRFM9xKmfyL8KR4cLV250JBYDvg3GKRlEebvHOMSJgL.jpg located in images/cloudy_sky
# File ANd9GcRAW9Y2ZRUvbKqc1QKy1YBq7LfChUB_05oOPAZnBb4G1dKwXsuV.jpg located in images/cloudy_sky
# File ANd9GcRBD-xPxUwT4AbDd6tvoiYwfndzkweqH6bkkAVwU563D4AL_9zWQg.jpg located in images/cloudy_sky
# File ANd9GcRBgpE0OoNVIpp-BUCff3pbzFwOk-XFTUXgyOMazPGqMKY6jsm6.jpg located in images/cloudy_sky
# File ANd9GcRCm9wT51slz6thEtX4pluaKB-hfTJ1rA2zPPOzs_zC5fy3U9lASA.jpg located in images/cloudy_sky
# File ANd9GcRDmts_La47BKRph6jZvhUOjJ_6fSk_YTknr1UsgrO1-ITh5lDc.jpg located in images/cloudy_sky
# File ANd9GcREw-ilf7J6V1BFMXz6HbS7oaxVjf_VPJQOiC22Ttlzhba30Xehyg.jpg located in images/cloudy_sky
# File ANd9GcRGL7zNNs1QzDR3OsEagGyKf6mFRXjPLYhPclYlUO4Monq27i66.jpg located in images/cloudy_sky
# File ANd9GcRH9mmmfnwq02SVlwerMudrDxhnwofzMwbS_3IYr2wxtEyVMP6pfA.jpg located in images/cloudy_sky
# File ANd9GcRIbGO4ChyMvGCZQw3kGZAkycfwnCdO7r9zDvVx9g_iodFCoYBFdQ.jpg located in images/cloudy_sky
# File ANd9GcRK5H9TMSepTf7PMyj5hkGia4ysBRH2yhe00OqWJroN4C6npPVr.jpg located in images/cloudy_sky
# File ANd9GcRKx8R5eTCE0V-_ML7tk0A4NtFf44rTP1qphSJg_QhmytkwtORn8Q.jpg located in images/cloudy_sky
# File ANd9GcRL7W04upsKt4IWesvk7fok69t8eCeG7lP-hDWkruqmNY8IvM2Dig.jpg located in images/cloudy_sky
# File ANd9GcRP9YApifU4NkShTN_1tKaigNsjKqVWmr5S7wcTRlZOMk1apVlXZw.jpg located in images/cloudy_sky
# File ANd9GcRPEWJeFuvmWeXlnDoWhtAa1oMSIIBkCLBNaYO2jJY3n0P1rHR6.jpg located in images/cloudy_sky
# File ANd9GcRQbE12EgjEuvVx66QnSlux4dVTv7NcfBOb3jpUt0ba96onmi2stQ.jpg located in images/cloudy_sky
# File ANd9GcRRqNkTYB2IQ7B2WYBZM7wnISJO3LtlsI_q9BjfPNHaQS6sRh68.jpg located in images/cloudy_sky
# File ANd9GcRTfbVGwktWj1ihfzPlG-4R7Q-IVUIyyIZRhoYJNzLwyQysQ54y9Q.jpg located in images/cloudy_sky
# File ANd9GcRTkOlBV5VS5Tz8Fpq7ALoqmaSfb2JM3DsQXzBAmXrhZu6XBHsj.jpg located in images/cloudy_sky
# File ANd9GcRU-NkTtKnCYXCTRPsgoyQIsqQxIj4q2OMTx2aGEz-KU2LYzAOBjA.jpg located in images/cloudy_sky
# File ANd9GcRUAOFWD_-MHyndeY__UjLitKWs4edfOX5dJ9iio4Ypj5Y-UnME.jpg located in images/cloudy_sky
# File ANd9GcRUx3FIiAu23D4zH2gGMPmdmqCNcI8cYppESICvB0Ji1gJP1Gl-8w.jpg located in images/cloudy_sky
# File ANd9GcRVIfduo2MPVZ_Of2Lw_pv0C1ZhmdfprIX5Eo8cFLi5L0GM_DMZ7g.jpg located in images/cloudy_sky
# File ANd9GcRWSReylooLl2AR_j9b1JQN48JpaMWqY4lAOe0avHpGyUoUzjuL2g.jpg located in images/cloudy_sky
# File ANd9GcRWV1mOycY_Iu6iSwaoFaBcvb1Vpmn2GqmSJl0DVPb5kmzq2lZkIA.jpg located in images/cloudy_sky
# File ANd9GcRYHRwMJaKjesS1MNbhNX3XTWnXRstMpSyX9Sqj5iPt7EQbMXNe.jpg located in images/cloudy_sky
# File ANd9GcRYhTjJMJ8KXvKiqCST3iRUn6pP2tTm7fYBWbJ0Gqk4KLJoesxL.jpg located in images/cloudy_sky
# File ANd9GcR_5Xnb2dhogi5uACykRMWT9fOgBfLV6-DkQLGjmikPj2qY0FTVWA.jpg located in images/cloudy_sky
# File ANd9GcRafWJBBnQ-t2fB3bc3TRUlBgd-wl1cHM0jVPxDkyBoOMBQaHIhSA.jpg located in images/cloudy_sky
# File ANd9GcRbDRc8--YoYoMPOLK8q_TasAAeJjfF0dq4iSoylAmuQJSwgBqG5g.jpg located in images/cloudy_sky
# File ANd9GcRc5T40gaTFXFPajGTERo8yP3KDa9lNo1i7isFxkU12Rn6cdiw_.jpg located in images/cloudy_sky
# File ANd9GcRcuf5UX7wSdZVdbeIWx_MO6GMI4Hb0MWzjk0ToNkF_RrbumXgJ.jpg located in images/cloudy_sky
# File ANd9GcRd8MNs_p8ZWZZKbl76PGzgfucHleKXSqrYiYSKOCuK-T57XnClmQ.jpg located in images/cloudy_sky
# File ANd9GcRdXca4H54CdRDnOKdDE8QP3hUxwz_hMsRhLdpq7wA9ug0LXKHCnw.jpg located in images/cloudy_sky
# File ANd9GcRfSHu5VJSRdw-FJt0SvftyXF_adph4d8sKhYamjqlwkEzzHVCCAg.jpg located in images/cloudy_sky
# File ANd9GcRgJhp5m-mUwX02FOIDM6Et00grHg3iU6ADYinBYtB0Hq5moz9h.jpg located in images/cloudy_sky
# File ANd9GcRgdPQQJVrj2fpuNjivTrJ6AIEXuQjnCFGR23NA792KbD43deji.jpg located in images/cloudy_sky
# File ANd9GcRhctwqFlTW4SXNqKE8VoVHGjKMOE2HoFFtGC05hNzoVnShgeHNlw.jpg located in images/cloudy_sky
# File ANd9GcRkeA3mg5g4XmmRqA35ueoLV56NJr7KLoiyhB63VQv9VKtQA0kN.jpg located in images/cloudy_sky
# File ANd9GcRkpkXCZQDntGrtJmiTN0dAnFEpgfLHtXGrbJfFoz3HjyZrsvRF3g.jpg located in images/cloudy_sky
# File ANd9GcRlJQOU9l0SJld0sw2foxqfpVaXf9xAvLLxIJ1yT0cUMQequxdp.jpg located in images/cloudy_sky
# File ANd9GcRmMeb2V-u6PQYXC_JrUIXPr-z1FAmOZQqopzc7plbiqHvEaiP-0w.jpg located in images/cloudy_sky
# File ANd9GcRoC6BLv7BLL_HZhdO0ZU2axU_AuCEH5sjgLizn8WT4dqlqbl1W1A.jpg located in images/cloudy_sky
# File ANd9GcRoiTdeKWZawX58aVdis_jclewv1VERkbbPhAQ0jUcjH_Uj2FFbww.jpg located in images/cloudy_sky
# File ANd9GcRom0Q3KUY_NAuaVJmpsoGHkBC7xhQWSbhMYgpbkP_yeBd71NQ8.jpg located in images/cloudy_sky
# File ANd9GcRotFD-RtZl9EY6YZex3oLJQF1PFGMC-tGXFfQJqfLR8ofJdiFP.jpg located in images/cloudy_sky
# File ANd9GcRpGf0YIlkLuwMSZP7_TARa3haJcbuv63SvHLbFelqNoLuRfzqY3w.jpg located in images/cloudy_sky
# File ANd9GcRqciloLaaMlz4BD3NE4ECuHF1AsQMASVwGk3op3kpuoNFNkWKS8w.jpg located in images/cloudy_sky
# File ANd9GcRreUd_tzoJ3tOH9TeLWpWJ3Ws1xOilv_aJ8rvLptkJc7Bff-DUSQ.jpg located in images/cloudy_sky
# File ANd9GcRrsYudn9XNsCnicZV11qlO6SpUqXteM9_gSoUVphdJ46puoVKBGA.jpg located in images/cloudy_sky
# File ANd9GcRsY5hQwQf0XE26jJvP8bsYvziBa0IbV4HnshYy-UNhxP3-LEX_.jpg located in images/cloudy_sky
# File ANd9GcRsuJncfBCjKX0jLT-3SxsDkLbEcuS8Iql9rgiS2WdaMW9kIEPb7g.jpg located in images/cloudy_sky
# File ANd9GcRt2-lSaF3IVpPxHyptyAJQ4XgGh-yrrUucX7gWo1dKafo5604W.jpg located in images/cloudy_sky
# File ANd9GcRuMhfwZLezC2TkRwtwh2onoAZeqm6PI77iLiLfgLNFAfsHK3w4.jpg located in images/cloudy_sky
# File ANd9GcRvMpbcH6PsDqWeOExS7sT5FMDjICptm0hiljrly-L0TwNeCTkh7Q.jpg located in images/cloudy_sky
# File ANd9GcRwCU34NOJGTJjTSMZeQIBN13NuMiKtXrrugMuJzy3sG43qW6nx.jpg located in images/cloudy_sky
# File ANd9GcRwia-pOPFLf9dEKBEU88Rlf6s9UfwGNpGnZLlbuqX-nJNfbxBFKw.jpg located in images/cloudy_sky
# File ANd9GcRx1ni6aLKtRQikl76R3lgVKGJ_IzvdPw_eTbdyVuh2ZoP_9aAalg.jpg located in images/cloudy_sky
# File ANd9GcRxKfaAh_MBF8lujRSrUdDfrNkk7UnJn5yBrTCxkBmgfoI4Jbg5SA.jpg located in images/cloudy_sky
# File ANd9GcRyhsc_sltK2eCRalb4z-S3kcbVQVa7mu1ZronTu6CF0tjpfS4u.jpg located in images/cloudy_sky
# File ANd9GcRz6-JTUK3KZN0NO36XDooxSuDohUuH_lXBPbfDzk3ctGQzXYWQSA.jpg located in images/cloudy_sky
# File ANd9GcRzPSrZb2y5Y7OPNSUiXP4VQOc9wTkKrDcNI6W_5aKZ7QyPJqmr.jpg located in images/cloudy_sky
# File ANd9GcS-NqLZD5PgFXWdjCd_oh07nEL1QQzJSqI6Rmw_nIkSHPBR7QWU.jpg located in images/cloudy_sky
# File ANd9GcS-a-3H6Am33WBrwsTdpKIAciGVVCcpx27dZFxGpkeVE0m3ttDB.jpg located in images/cloudy_sky
# File ANd9GcS0Kr4CGdiokj2vKhZUp2VT7mTnGrpxdc4qjy5Oz_ca4nFaoSUT.jpg located in images/cloudy_sky
# File ANd9GcS10UFYiOANLrUfvmyxoExSSskebKlKgxluRlMmvwbv6zxMhSIdDw.jpg located in images/cloudy_sky
# File ANd9GcS3IELU1SG7zEDqSMFOaugxBfwBr4TculkMTS2Xt5HxOTYpPTzu4Q.jpg located in images/cloudy_sky
# File ANd9GcS3T8g84Ia8QUyryaSkgTVUv8m7Ewd7tjwiBPAfKIZqe-tQu1zs.jpg located in images/cloudy_sky
# File ANd9GcS4hp--I2GMLfr7vtBTvJYfmfD0IDTbZmWF49Li4wyLo2HdecsyfQ.jpg located in images/cloudy_sky
# File ANd9GcS4iIkYhCtoEBrtUsmF0aGLBq8WvKcgTsYZA_3sC4XDvlISrlRiKQ.jpg located in images/cloudy_sky
# File ANd9GcS5h7OTIatlcULw6ItT6I3CMw6D30P6BB_9oxzWBd3XuSXr473f2A.jpg located in images/cloudy_sky
# File ANd9GcS82iczDjgijy969pDA4xpl-VBQW3-k2QEsZA2a-AjTcWvPvoZDZQ.jpg located in images/cloudy_sky
# File ANd9GcS8BIsnTJ2_3QV7p3IIzn9rLKX6iv0irRrwL1g9A3TPnxPyxSYV.jpg located in images/cloudy_sky
# File ANd9GcS8I7ECuOaE3qs9p5_GMNfdMp5FL4PYpsEwaCJGOEBEtZ-8GC_hLw.jpg located in images/cloudy_sky
# File ANd9GcS8Qgl5zQWKn7ZuH-fbdiP-ETzBAQa-NqBeBoSU-N3ltarwBEri.jpg located in images/cloudy_sky
# File ANd9GcS8_4qyvPC67OSdHEm8pLvsET5wqzI7h4NRMvEjkbUpgHox-AZ8Ug.jpg located in images/cloudy_sky
# File ANd9GcS97fKA5kAVyvGvJBTusm3Yomb7UZqYKlObR3PxHLnVcjA9HdgisA.jpg located in images/cloudy_sky
# File ANd9GcS9ossXh9RVcWDE1Z79wb5M9y2zMgUwVf5TByVjR7c8Qjy4cqYuQg.jpg located in images/cloudy_sky
# File ANd9GcSBN0licW70W1FkNQVL1alNy3aTKEPegRjZiT1fpvxJV1Ih4Kw7.jpg located in images/cloudy_sky
# File ANd9GcSC-Nvc83AM7j8HTRFzNaZ96BSW2fV2krOC3Uexm68xsRbJYkXkPQ.jpg located in images/cloudy_sky
# File ANd9GcSCVz9LEuy-llDDGpt4NtTFEmSDfPI5ryK5bGK9iYxbt6KryGiS_w.jpg located in images/cloudy_sky
# File ANd9GcSCnJIOPNktYuWqVi0tsn4nHXSjprBLd1FTAbLBvZQu5Hd6wFz5.jpg located in images/cloudy_sky
# File ANd9GcSDPXlKMheHH_5EAp9AenKTgg1-d4WvXP7xXORH8Wg_oYavXCmc.jpg located in images/cloudy_sky
# File ANd9GcSDR121Z4liUIql9P3ost0e7zVae73RUVhpyeiPgXpIhGoY9ZDc.jpg located in images/cloudy_sky
# File ANd9GcSDbcpFoMkCOl58fgtIpgfb7JWrNreMW1WygqjrU8xGAoZ9SINbAg.jpg located in images/cloudy_sky
# File ANd9GcSF6g-GHeOdxrHAVsAMN1xAcTBjWeMNDUVDQFb62IzBDGGSdRlX.jpg located in images/cloudy_sky
# File ANd9GcSGSZkZfF9lbhhkaPatRV7M72psTFqkOgu3br8FIQ7v0RvWCvNTgA.jpg located in images/cloudy_sky
# File ANd9GcSH_QcDJkq6_f4zivVqcpqYKrck2JPIkR2359RAxSkltb1jWkxvtg.jpg located in images/cloudy_sky
# File ANd9GcSHlm5RONeKRY2wDXDkAxeWQDecuyneYhOSQPIlXHJoNQ3ef_THxA.jpg located in images/cloudy_sky
# File ANd9GcSHuWfZw3ed0lL0CM3QhFukEgheIVT6MU4BfFowqxFScd1cRVh2.jpg located in images/cloudy_sky
# File ANd9GcSLbazJoP_1IR9tHkREp0Ra90pgk9B3Czt12NUN0cSofkk0nJaf.jpg located in images/cloudy_sky
# File ANd9GcSM9V2bjoE09QiIsoB23J_W6QuUAqPN8yordVOS9VdrUlhkAfLj.jpg located in images/cloudy_sky
# File ANd9GcSMZ0InIDnY_sShCi5n9mSA66JK684n8jhPyrNz72d9b_Xvfd8GBQ.jpg located in images/cloudy_sky
# File ANd9GcSMn56D5jPJhdQigfYG93O2TZc499EG7CrJSOXohw8s3N4Ms1Df.jpg located in images/cloudy_sky
# File ANd9GcSN4oTPrQN20VzmIj-D2KNIYmVw5WFUsxptM7FMrQZODoCg22PJhQ.jpg located in images/cloudy_sky
# File ANd9GcSN9qKisQg1zwxzwfgdgejsGlWoKK8T3yKH-N3XXX88FW2AL1Nw.jpg located in images/cloudy_sky
# File ANd9GcSOaFxAOBvJCNg4YU3jX88FMUWFaQq2fat3hsdW1Swm7CNL-1uA2Q.jpg located in images/cloudy_sky
# File ANd9GcSP6XalW4F-Vc8C1sNbG9Rf-Am74I3Oe428Ykxnzj9RktFNSn0tiQ.jpg located in images/cloudy_sky
# File ANd9GcSPckO-sz2VxzcPUH3uYMEWiLH_yryn-nyR6pCmmIFfQ0U5dTvA.jpg located in images/cloudy_sky
# File ANd9GcSPqX8EjpZkOMjt4hUXeRV0rENFbSxSAXBYv4deCUiqHTwgLn_o.jpg located in images/cloudy_sky
# File ANd9GcSQ68dNzfp47djqV0jYxezx2buJjpA7KXbTdyWPxMWf3CYH0H5u.jpg located in images/cloudy_sky
# File ANd9GcSSimRraWZAci1YTbOys6Qf2DOJn1v2yW3iBa-fLT-AB3ksqADhWw.jpg located in images/cloudy_sky
# File ANd9GcSSoLcfatJCURaFfXuIQDvTHpVu2G2eyhbX5K4v5IQ0IzrYA1yp-g.jpg located in images/cloudy_sky
# File ANd9GcSStZ17hZgoM_7FI8EWF5FouK1lgYKy5wSttt9Bx7ariFl3C6Ub.jpg located in images/cloudy_sky
# File ANd9GcSWCyANHQjkwLmHUPbZzUuMQPFe7hqe79G1R0dCcqcZkPL_yOg3.jpg located in images/cloudy_sky
# File ANd9GcSX1i8GqUw4Fn6sM46w0-rCyEhyRI0O2txOtzifLfUyi7sxBjZg.jpg located in images/cloudy_sky
# File ANd9GcSXkIBknWQCUz-5vCM1YLcOYstOLGmSvC65cv3gqt32X1T_QjXn.jpg located in images/cloudy_sky
# File ANd9GcSYDlAfzXXON-s8pHk9C2nxxwOm_a0tmonevseyOF80SfrCQXeESg.jpg located in images/cloudy_sky
# File ANd9GcSZif961ZZC-CNdVh3wiHC-mGtcIcIrX5YYiJB8euyxhgUgwxEq.jpg located in images/cloudy_sky
# File ANd9GcSdSxLgfQ2PAk9iuaxwf3WH1NccvJviNVM9cmtGfb-ithLJSsqtRw.jpg located in images/cloudy_sky
# File ANd9GcSdtvgt-kczCFL5g6TJaJITuq7x8SWOezJdynd_v5dPRoRlMu2b.jpg located in images/cloudy_sky
# File ANd9GcSePcE1-787NrrWyn213hYhfBL3Tzfq5ZCafJ_Y7SjSeyqzq-kV4g.jpg located in images/cloudy_sky
# File ANd9GcSh92mi4dV7nLmhuLeCJ2WPFdMWE68GvhV-lPoW9gvZ_sCMu-uu0g.jpg located in images/cloudy_sky
# File ANd9GcSiEOnPfewPIU56_zDE3HwhC4BRGIqnsf251QsnWn-oQxWU0h2wPw.jpg located in images/cloudy_sky
# File ANd9GcSj_93PyGNdgKELgUCWOeyYuM4fhlP-TzgRKPQ564AG5I2CV__RKg.jpg located in images/cloudy_sky
# File ANd9GcSk8gxjhdXEEloP3whWEh4VYYK7VeoKEQNKDXmsllelDLViy3pB8A.jpg located in images/cloudy_sky
# File ANd9GcSko10mSXv4fiZAZ7RO2ZpJ8DgjfOG66wBmxvdnHGPDp3rrAaIQ-w.jpg located in images/cloudy_sky
# File ANd9GcSmJf46Ko3nRIUKv_o9tY204dv9WDwGs659D8l8tFffkNBsLHpw.jpg located in images/cloudy_sky
# File ANd9GcSoj2JK-dp-_S8P_GS2QPtsjvK_wDtJ1A4b42Eh2P8vxNSZ5YIGXQ.jpg located in images/cloudy_sky
# File ANd9GcSqKJsMLusKrmSOXfj6hBdw4EmHFga7nuIuno5pn4BZ-iq--eD54A.jpg located in images/cloudy_sky
# File ANd9GcSqWpnaDvDEQao5dKCdX5xWFZDAquiB4CThHScm8ISFR0UciiiM.jpg located in images/cloudy_sky
# File ANd9GcSr317EUFTT1DbbwNkXv8hqSTOG4NmsxMVlkfutJLjgCaYbJmlU.jpg located in images/cloudy_sky
# File ANd9GcSr79ZDpuBOGQVQfYNWEAqF9NJ_g8r4RBJGbhxQw2lemardEIoj.jpg located in images/cloudy_sky
# File ANd9GcSrBFfB-vfl1-tMOumSkcjOq4x3ohIl09l8JQUjyEXfd-8sBit2WQ.jpg located in images/cloudy_sky
# File ANd9GcSt0nS86zqcNIITHKGrOVZ9_pGdXnGAq6zI32FNkpTxyxqCyb7K.jpg located in images/cloudy_sky
# File ANd9GcSvFSM-pfrRtxXkUiyDbkfgBgIi5nRIwCcsYXyoAtWSLGK5vEEs.jpg located in images/cloudy_sky
# File ANd9GcSx1q83ETzHI_sOpNAJrhk7Lia6Mio4Gfwy_2sRoXy9mMNA81KA.jpg located in images/cloudy_sky
# File ANd9GcSz8IpEN9SWDAzga2Qqa3fktA9IBdQSMhnWNhG9GkzCghw0isjy4g.jpg located in images/cloudy_sky
# File ANd9GcSzlib8a-TDBSlQRjw_zRQ8xwDLra_Y0Wr0Xg3k0QdDUc31KpnO-A.jpg located in images/cloudy_sky
# File ANd9GcT-xEDjTS7Ql7KQXcdH0TsryrgtaUEM9CtTJz9uqfsF3ZsNNAWz.jpg located in images/cloudy_sky
# File ANd9GcT-xwT3Hq4lO_2yTYTwIFKkdyQNK8WXa2O9CPzpPQjcq9yyFU1Upw.jpg located in images/cloudy_sky
# File ANd9GcT0h3OgOmM2VmgsV3vz1fmSJY3teWY5lYXWcHfo-Qm05vrFchuVdw.jpg located in images/cloudy_sky
# File ANd9GcT0r9PtZmoIND6a4_fXyHMjPx5Zij0UTmVcYhZu8bybskF26c73.jpg located in images/cloudy_sky
# File ANd9GcT1o6unhpSabeNwCJGD9J1nE8OubUbAyzLOu6uQt3UOukuaxF6R.jpg located in images/cloudy_sky
# File ANd9GcT2CvPyKzAP2D_wM8bptjuvwQPcUIjsF7naOayDE-ealJ1P7eIuDA.jpg located in images/cloudy_sky
# File ANd9GcT2TJ3hEoUE5v43M2Ul_nji83kXYNIjj6Rs_9hxVzaqFd1hkTWerw.jpg located in images/cloudy_sky
# File ANd9GcT3LrcEVUR9uawyaVbmp0Lutr5zjmlR1JBX6FywZ5u3BoxUfuA_.jpg located in images/cloudy_sky
# File ANd9GcT3klVYgt9LmkeRD7Xh7zYoTL1ODi6V15Bec8UDDVsmGbLiOzl5FA.jpg located in images/cloudy_sky
# File ANd9GcT3wW-VmkLw05AN6tbcEH8O2NDvDZ-oZuLFIwlGBG5lMPypB5RT.jpg located in images/cloudy_sky
# File ANd9GcT5ijDC2wC4WYghc1HKr4AGD3kUfiCb9wu1y7-fvCh8lqztZD7nYA.jpg located in images/cloudy_sky
# File ANd9GcT64GsHYdpOAp8C6Nbs1xkwERtQrkJvNBFErKbNTST64v6x6oLBDw.jpg located in images/cloudy_sky
# File ANd9GcT6gIWGvncz1Ze90dKuB2rfSEi9XYM34XEkmY_4I8hQtmAdj0TL.jpg located in images/cloudy_sky
# File ANd9GcT7324w-qNvWmStkp8UYp0WYqX9aYmlUXIoC9aacTvEfylMT3jQCA.jpg located in images/cloudy_sky
# File ANd9GcT7j2yq4-7D0-2yNOaK1EwGXuHCWEnB32UBXqTEhfuD6vCb0uopGA.jpg located in images/cloudy_sky
# File ANd9GcT7oMN0WlsNdO3uPxTd4L_DBFw99l0WPtv_TM1oyUoGa7YaTN0sZQ.jpg located in images/cloudy_sky
# File ANd9GcT852qrQI1RcoAd9-3xnqMPC37O-2cfwHHZiRKSd8ek0PoZ5fA0dg.jpg located in images/cloudy_sky
# File ANd9GcT9WhnNmdPtNcytlssFw90iB40sfdpPKZOYCYgnWlAys5DglOF1vA.jpg located in images/cloudy_sky
# File ANd9GcTBel3tGAhEYkS67wnCyJ2iXMD4eTQXqm63uJ0CaBPatWQr6XrQbA.jpg located in images/cloudy_sky
# File ANd9GcTCHXOqA0ZdJGkRtk3J3Jf0HEEvfEXWA_kfRfAVlfvymt8VdFfA.jpg located in images/cloudy_sky
# File ANd9GcTECqXKoMTVcE84T5WP2a5zFjpdIATxI5uOFKWupX4s3qf9753AEg.jpg located in images/cloudy_sky
# File ANd9GcTEKh1NBPi7dhdlncfHp-EKUnhKviNvfjZSDX30TvhKQuyM8ooa.jpg located in images/cloudy_sky
# File ANd9GcTEobBb_9ZJN5BuCeX9vXGrIjxZvWV9LeyJU-ZWnG2m53ZgXA-4.jpg located in images/cloudy_sky
# File ANd9GcTFjwHeoGNSY2FfJg07ze3JeoBwF-bMZs45KLbUoGvLSfCqCZEc.jpg located in images/cloudy_sky
# File ANd9GcTGWO6pnQzfs0rffCsdiz7puprjB5hTm--LYws1ju7VuyBvyqDB_g.jpg located in images/cloudy_sky
# File ANd9GcTHLgoEDl-1y6QL5T2wxUbrtI32hww3GjFA3oIKNkHtyCjyJPtk.jpg located in images/cloudy_sky
# File ANd9GcTHYp-5B-A7-fRnv9wXVPuqVRDe874MC664ghfzk4k0_SoEx7PNVg.jpg located in images/cloudy_sky
# File ANd9GcTHczGw7zjMiMhDkP4Zfc2w2-659tJrIBzBMSxELfJwPyD8g91yNg.jpg located in images/cloudy_sky
# File ANd9GcTJTix4z5Q3eiqZAkpzYIMvjPk5fL9Xv5PsRo_lCIWaw5hur1V23A.jpg located in images/cloudy_sky
# File ANd9GcTL7Q3nIC5sjhLQv7ymJbfzm1BqKohT2YG8QZKuy6fJIgwGOksq.jpg located in images/cloudy_sky
# File ANd9GcTMop9vIbHspJagFfcOHs3tE-4HWrCGPwjgSQ7_1Rgf8dQVcU9N2A.jpg located in images/cloudy_sky
# File ANd9GcTQ7YGA7bxVaKGsWpLEst1JnIeNiQywA0N7OdnVNTvRVarDtG-P.jpg located in images/cloudy_sky
# File ANd9GcTQWsxnS9X1jWem-2kiIiblrqm1HogkmlBgV4tXksBmkc8lzWzDFg.jpg located in images/cloudy_sky
# File ANd9GcTQylYtnXNtf_ixVDA1c10DuEOk9edPaZG3Ng_ZTlvKpGZwsLphuw.jpg located in images/cloudy_sky
# File ANd9GcTRtNU9etPs-CBOABEu-T-I6reBJMWSCDamPLUQ2V93ROzQgcpr.jpg located in images/cloudy_sky
# File ANd9GcTS4uo4YDjTuZ77NAsBZW94QyDhZoKU91UE7t-GFVljHezk6YiwvQ.jpg located in images/cloudy_sky
# File ANd9GcTT72mxSmAPjQiyIU7zLwqhO4hWSc5EQHUijwrRPsRsgLtHZsjx.jpg located in images/cloudy_sky
# File ANd9GcTTzFGdD-FQZIPmgvqBfnIGg41wV4fNbi84838vLM0AK7BQi3Qx7A.jpg located in images/cloudy_sky
# File ANd9GcTWecHiLn_mRLV3uPwlF_oHzAdLlxiPcAK9T01UF1vuaKC34fnm2g.jpg located in images/cloudy_sky
# File ANd9GcTZDSAPAzAR5DHMToO8zgAOipwTGvUL2qdffWirM0FkqeGj-M40hg.jpg located in images/cloudy_sky
# File ANd9GcT_tcAQPcarZ1UMDICzOI8NcHOAyy4bsk8P6wnqjfuVFoU9nPGq3g.jpg located in images/cloudy_sky
# File ANd9GcTc5baxh24bUZquZqPNHya5mZPyfWBLxINMxDl4gJECMyqP_cvUdA.jpg located in images/cloudy_sky
# File ANd9GcTcFueHS7VPx0S_80dKogvj_0cFO9F7Mgr10g5QoWV9CkhrHiyNAw.jpg located in images/cloudy_sky
# File ANd9GcTdQZKqbtRrwT_Z4Tm0mSg4S9EtCIw-C_2yviXZUdLkTsyb4ZER.jpg located in images/cloudy_sky
# File ANd9GcTfaQL2gqBCmF5I_toT4OyHpj2gytvZV9lkAyfk_I_MsHZGX4BO4Q.jpg located in images/cloudy_sky
# File ANd9GcTfrsNgHkQQB_X7nl8nQRweB7u3AsG8ayjvAssk_5jdpm_dcIec.jpg located in images/cloudy_sky
# File ANd9GcTh44MvCWgTAlQ6gnR2zDY235w0JLp2Napyg-5sdEt_FIW7NuOs.jpg located in images/cloudy_sky
# File ANd9GcTjL4GhUYW-8KE1n8-Dyki_PRaBjBti3xC0uHC3fbtzEwphWwB3.jpg located in images/cloudy_sky
# File ANd9GcTjzu_EqTTfdptUUBIuddb418wOhWl8AmaYqWzrvZ4rLdeODc3yMA.jpg located in images/cloudy_sky
# File ANd9GcTlADpzfN8JMMqIH_CD4Sh4hnwTon34h8Sxn39viPVKlIEGxsU7.jpg located in images/cloudy_sky
# File ANd9GcTlOl2S_wTLwSi9yO8vJijOW6smUdcORZtOmI3LHMkRi4tK0YkQ.jpg located in images/cloudy_sky
# File ANd9GcTlr2C5MS8_xwhpGYPhsgHr9gkiMPYXaxouwU0dhOk9kKvVIFDA.jpg located in images/cloudy_sky
# File ANd9GcTn9AwS9Spqxp1FrBD9Z0KPDGmOWlG8cbxOmdwqoPBQtqwi-K99.jpg located in images/cloudy_sky
# File ANd9GcTqBRgzjR3BRz1k7AZr2QHv_QskiCbQuK-fz6YptlKXluUdIL_5.jpg located in images/cloudy_sky
# File ANd9GcTqE0FQDwxjWwBI2zRAmjX-7JWiYXuAC06YhYMydN4dTBaDSPDx.jpg located in images/cloudy_sky
# File ANd9GcTr8CwCGOs40rWyVDaauY0s1BhDx6_iiY3YTX6QQJ4a0WgU1IIQ.jpg located in images/cloudy_sky
# File ANd9GcTrRP_8QOzL8SuTRpY_S1S7RLJay1RE0lS7yIBqN0O2A9NwUktYpg.jpg located in images/cloudy_sky
# File ANd9GcTrhY6R9cqBa8KTQwb0iVQuHWtQF6fNwDAx5464k8qusvcFvkou.jpg located in images/cloudy_sky
# File ANd9GcTtF-CeFcKx8WIujQnRjxytg6cyejnwkdGS0NxJ0yvztrECd6Xy.jpg located in images/cloudy_sky
# File ANd9GcTtUbQ7FRfFRLZ6I9bQElBVx7MYfx6a3rPLcrUrGSPwzY40wP9tiA.jpg located in images/cloudy_sky
# File ANd9GcTtVWAbD00rzgtOBjp9tm5odGrMlh4l5pEHTtlAPzL8gqDWaia9.jpg located in images/cloudy_sky
# File ANd9GcTtvgbSp0PvYTze66Febw8YkvNZzTqm61dZkWsoC_Ygm6uP5k79.jpg located in images/cloudy_sky
# File ANd9GcTvEtYMVzjsJiprVGckqV0i2FJZf_ZgxXFetzltvt_1iJSXhU3ywQ.jpg located in images/cloudy_sky
# File ANd9GcTvvulnjWt_KnqyVZ6pDzQZBMDvJru-TToxBKM0IQPDwnlUbN7Z9Q.jpg located in images/cloudy_sky
# File ANd9GcTx0s2REAARHNDICg7nB-X1HkRF2oNxkqiYwwfBvPNbnJI5rsokwA.jpg located in images/cloudy_sky
# File ANd9GcTy7WCGMa9wMJdwS6uIOEJNJpmAJFFU3Et7sw8mnwJ-hDHC6t2r.jpg located in images/cloudy_sky
# File ANd9GcTyLVfobsMaccxFbympHb9lXS4eZx6YOYMZZ1IsjjaLCfh6mae8LA.jpg located in images/cloudy_sky
# File ANd9GcTyMBxgcxYrSutKkK-OhVhet3BZxZEq1Uqh_tq_EUSZq8JfhzOf4w.jpg located in images/cloudy_sky
# File ANd9GcQ-9q7fjHdCPVLZHzTvLPvtklacP7xAO82eCTM2EuOxEL4Sl3qpzg.jpg located in images/rivers
# File ANd9GcQ-Y4lf0VySCfoago7CrpHOCl1LHcbHaB2BMf6UvUSkeV4dtoIKlA.jpg located in images/rivers
# File ANd9GcQ0VAnOVSM7Jt0rWfQAbKAzpmjhY_NRc4Wnsf8VsOG8HSB-dgYi.jpg located in images/rivers
# File ANd9GcQ0W4zSfC1L5XbzSup3sflvvu10z4CDiheIA39HHvAd6ZgcOmaTkQ.jpg located in images/rivers
# File ANd9GcQ0XNnCueBMO1yMQbMIEjA9yy0dnDGTCa1N1LQ-eyscY_louA-HuQ.jpg located in images/rivers
# File ANd9GcQ0p0VhR7dXlGVaCDrmjPiWolZXDzA9882JcLja6au0zCpRZLdv.jpg located in images/rivers
# File ANd9GcQ155gIdV-BHQ1aUxoTX32O2VFtJhHrYB-h5X1x4LjsMiqJR53LGQ.jpg located in images/rivers
# File ANd9GcQ1O55e0PJcYuSLDZMyl0sP2fja4OJWp09Z2l4mUK4s4LbZlx3F.jpg located in images/rivers
# File ANd9GcQ1hvqTjojWKvUcifxEkFYwd20YJ370RpChBgdKQkZQoZdwf7B1dw.jpg located in images/rivers
# File ANd9GcQ3-U1iFeTeromrkQz-Wl_oCKdNZX_JE_57_wDHEcy2fVCPpPwuMg.jpg located in images/rivers
# File ANd9GcQ34EpqQbnJHZIzsaWOFUJmvFSl88oolAQlaBUoHtVV4M3Nw0IDJw.jpg located in images/rivers
# File ANd9GcQ36m9IkUgJyixD-5UKPTE2FOA3EmG4jnC1_Gk2tAbVyB8DgyOw.jpg located in images/rivers
# File ANd9GcQ3whYfUGrHELoCiurYMmOps_dNp0p2mIMPcV7PVMJM2Vl9zkvodw.jpg located in images/rivers
# File ANd9GcQ42LTPJRt5lRQc6SDm-jXxBRtqLFEN1hQTNfpeviZQ3s7JUemI1g.jpg located in images/rivers
# File ANd9GcQ4HmanLwwYpoDvuMV2gZ-hPHUKe_pEfASta1XhcQsdwAvYzEN-.jpg located in images/rivers
# File ANd9GcQ4JP-7ZLgGwC2qrsx_Z5a-plNug0qhp3N9IRDo6sshcLyfxzWO6w.jpg located in images/rivers
# File ANd9GcQ5CqYkr1Cb2Ya8TEOSlgmOSXTHXjl2DMuevAxNgj7HaLoWvJvPKw.jpg located in images/rivers
# File ANd9GcQ5EUHDl9-SF9BaYEhvQubvdzWwTDN-PnPDfez32vy9eIFMuwl3.jpg located in images/rivers
# File ANd9GcQ65q43sQs6EJ4mKQsxKfMBGWP4D_i0MJiMu0qta5fK7QNeuWDKFA.jpg located in images/rivers
# File ANd9GcQ7GxZrY7hGRmi8BJRu9o3W481eNLRX9cvRrUFQUyH20dcIWEdXxg.jpg located in images/rivers
# File ANd9GcQ8flX7rfBV2lAuV0MlAwKTdxnL8JCbCWsSKm43JQfegqcgOJDY.jpg located in images/rivers
# File ANd9GcQ94dpmqwIQQyYMSOl1k7vjsIQpiYMCtquwrc5eHCFUSlZgI3Eu.jpg located in images/rivers
# File ANd9GcQA3y12z2JUN3_1BvTjEYYIMU4VrWowaufHSfp-K8r2vwOUpQ2JIg.jpg located in images/rivers
# File ANd9GcQBLStj7Fn48YKX_-y1Iv6IjTCvrtDVwGMzS-OyqPiNuONj1_O55w.jpg located in images/rivers
# File ANd9GcQByP1-p5okUsTrNnKELK9u9H1nNQzyj_DFlXxA6PIUfuQu-WVB.jpg located in images/rivers
# File ANd9GcQD4GqFNJm5hcYrHpy-xiQsr2j1SCI77moYWxXnQtgr2XyxB7q5.jpg located in images/rivers
# File ANd9GcQDDNcWydnlaWszUgPNTmi9KP6p4Qf3ztL2q6oQkH5UL8WIJzzh.jpg located in images/rivers
# File ANd9GcQDGSZ9N43B3iWlHPTDfWmshtZTMZh2Nqno3ebfOemfLsqaZ5Pjpw.jpg located in images/rivers
# File ANd9GcQDp3treJcAK40io_glROJ38Y1HYU5EJWu67xis78uQl1M8Ks9B.jpg located in images/rivers
# File ANd9GcQEUIzEWx-HFx1_qZLX4Jx9GIpOdNPIVb7DnoLjND_5NlWG_ys7AA.jpg located in images/rivers
# File ANd9GcQExPxKiafUCJYDkd3CeugMR3vtazHcpc7JiBbQKmUIGsWLsSrA.jpg located in images/rivers
# File ANd9GcQF_DtnDG6kDB3JsWN2sTcKFYB6SKXeC1AZ4gx7e6WfLLBu7R5ItA.jpg located in images/rivers
# File ANd9GcQITCvs5-C0CmthmZqFivvB_IM2ueTvQhuOwUzATAO9JgIJA4n_mA.jpg located in images/rivers
# File ANd9GcQKdXI1yshDXXRTsCK0nD4dLfoSs5W1XVor9ACDDEZEVOtRjmYTsw.jpg located in images/rivers
# File ANd9GcQLdZUsZYNj61o5I17ZWWqSYDTzQtp1wrXevShk6HfrG8mT_zJW.jpg located in images/rivers
# File ANd9GcQM38N2aXAH-RQz2UmlHUTLouR6mHWiDvIPVsbdJew5J8h-u38F.jpg located in images/rivers
# File ANd9GcQMAVmx5-HIQ_nyIXU88jmbN1LRb6Qq88VM2VFSyCcVKuifFNcE.jpg located in images/rivers
# File ANd9GcQNiGQ5n9agpOwOAH3GLiKzKBOxbJJJqXZVrNergPCebkm0kfeUDg.jpg located in images/rivers
# File ANd9GcQNqBA9TaMBWaislhYerZBbcusu2DYC6UH-fFU5KOs9R8rXIF7e.jpg located in images/rivers
# File ANd9GcQPPblWWxrx4M2D5LjUqOCcs_8J7CBgnHv36Bpw3HT91ParVXSt.jpg located in images/rivers
# File ANd9GcQPvoPaOHF02HBVeafeQPeMdqzUG6Ry1t-WX9RklAKwvBPAPdCmhg.jpg located in images/rivers
# File ANd9GcQQGE7WjywcbKvbEpw-Vt_UAoBRMQqdeAh-iQ20BK149ZhlKplKlQ.jpg located in images/rivers
# File ANd9GcQQg-BuqfCHiHsPFYmZlyF51GOK6JbeIubFLQOIYfoMdl83jXbB.jpg located in images/rivers
# File ANd9GcQQliE4bXzbhUCew8zDMsCMslTL5GCj7dyUZnludWdvlBX4ZnWxgw.jpg located in images/rivers
# File ANd9GcQQrhgUMog-BNhgTpdOft_jW6Ji5SoVCTphvbXjCIyHkf6qydfS.jpg located in images/rivers
# File ANd9GcQRnAtUWToiZybbhuddZEnXND7aJO6qvCj6BAAHbCPldTMSj4WB2w.jpg located in images/rivers
# File ANd9GcQSOY8p2xvEExee70w66OHQSRbeq23fOzSP89uUgXJtYVt_QMmZzg.jpg located in images/rivers
# File ANd9GcQScY61Ha44xcQ6t0l5VCdRWACJrlk6n4lx3DVCUxASJQjAzY6Z.jpg located in images/rivers
# File ANd9GcQSo1V6sulSmfrse07EmrAeLEsbsHQuMZm2VVpntRZINtiTgd2t.jpg located in images/rivers
# File ANd9GcQTnYY5oVmftLKjFp0CQUWrNAG1hZwVFK1-CalaNMKXwxgmSTzt-g.jpg located in images/rivers
# File ANd9GcQTyA2gMDH7HRgybvfEwM3ODRvsoPn8e2Br2-5QbvXxc--16VyFsg.jpg located in images/rivers
# File ANd9GcQUqgBcG0dTb1Tv56U9ElCzLi4PoKgL8fi-Ls8orEVWUIchWGNxnw.jpg located in images/rivers
# File ANd9GcQVCkSN-bkBMccPCTTriTuXTURUVZmFeHpvsuU3BS6rDH2hyIYE.jpg located in images/rivers
# File ANd9GcQWI0-i2RVTI5VcmTrFPTCa4Gz467ceHDQ_lgLPAgLyyvm1ltFvRA.jpg located in images/rivers
# File ANd9GcQWToN3pzlE3BK9z45iRDwVT25eI92JbSrActsJThEHW16sLExxfw.jpg located in images/rivers
# File ANd9GcQX-WqxXP22kPMu6y7cL59s_AUxY9qXZzrKp6r3u1Zg_U5FlBlr.jpg located in images/rivers
# File ANd9GcQXFtqStFxzwh0FEAGFmptE35z_b8kJfdxnNnrkh6k5BCMpALAFwg.jpg located in images/rivers
# File ANd9GcQYJei-mpS8JRZTpEkj5HBB8pdSuCsNNNzNJ3g0uvY0aoz8ez_lZw.jpg located in images/rivers
# File ANd9GcQ_-V8iCfffr1zv6QqnrmuZfgwmaji37Wg86mHrmBX06OTXgJjp9g.jpg located in images/rivers
# File ANd9GcQ_1pq_ShKuY-P_MT9KaYP0iI5bAo3N8nEV3h87O7-16ykdX803nA.jpg located in images/rivers
# File ANd9GcQa3PvIHC-YnpMcLzK0cVpbKlIjHHSL0kz29phpQRX6Xax-rE0IPw.jpg located in images/rivers
# File ANd9GcQb2QZyGykdlIDjj1iBZ6TCF_Vy7zCbZoYJAAgWkUXsbSQlCQXZZQ.jpg located in images/rivers
# File ANd9GcQbNXkgKUKGShZfqCxT0ID87NtJ31c_DWfy8yDpb6nBY6YzaLUn.jpg located in images/rivers
# File ANd9GcQboq1Gg0Q7aTErq9oKiwSq2-X2Hu8lFbelvk6SX25N6SuJ5eG1cg.jpg located in images/rivers
# File ANd9GcQcqqIUMeERnExCExHSX403_vl1wR823izA-Ef_m4UudQzeBp7i.jpg located in images/rivers
# File ANd9GcQctqQc75qFFokozjwtQnPheUnCIZEmkMi1ECUtVJKsteyp9tmw6A.jpg located in images/rivers
# File ANd9GcQd6rdmNd95ZOG0LMAK3osxA_tHAvRE1PPbSNUU3OTiYLpvb8e4UQ.jpg located in images/rivers
# File ANd9GcQgmqJQRrMjUgnv9Pq_IOyUuD-a02d_mvGV_g2NnulB9IcAc9gz.jpg located in images/rivers
# File ANd9GcQgnAASYgfLOgX7h-lpdM1zHT02V3km28el7IgY3PEw2iHsoes5_Q.jpg located in images/rivers
# File ANd9GcQhkPQhWJ84zGDQm3zFaAgrjWNi75qA7vhqMriM9ghii_3RG6Yv6Q.jpg located in images/rivers
# File ANd9GcQiMjgo7-6x1D5Jheta1ulJs1XsU7W1UcayFwL3uQw6CjP-5lO0.jpg located in images/rivers
# File ANd9GcQimnYyaYcQELr1XxKZTNzbuX_nVu7dNwk28XqEIUBva5olw47x.jpg located in images/rivers
# File ANd9GcQkOr7i4WJFlKnj2ya8i3qMyl2i2OU89mFmDzJnwhG3kST4G3lCOg.jpg located in images/rivers
# File ANd9GcQkdQ3a5F38NhP_AnCK7juFo2tIQ4RhfPLTJP2u83lxS2OwpTQv.jpg located in images/rivers
# File ANd9GcQlrygVtbatEwplSAUdifUPKViCYiYA93z9YAGMhSUJynAxyDaK_w.jpg located in images/rivers
# File ANd9GcQltg7ksBMOTINiXB448-nTTSeBwZWzzQLUaI53Xtewd_WDqk0G.jpg located in images/rivers
# File ANd9GcQmtbzAniQuL3GzHmFiU9HqkqypbvpckUT4EHGCMckDF9ioqsY_.jpg located in images/rivers
# File ANd9GcQnLG3qS2zzZIqacY5IlCixrjjrGUbTbJ10WPnGcLqAIgfvER5j.jpg located in images/rivers
# File ANd9GcQo-vUqELyjz6eyuhbu-8x-uXTRtIipFv3pYlOnnzta5F32Sh6s.jpg located in images/rivers
# File ANd9GcQrQP3vgcw4ge3kgvcI0cPewZTu-b1jYaI0dpOHd5zLzhWl26L9.jpg located in images/rivers
# File ANd9GcQslwfto_62zMFGjxv03059kgdQLmjbij-4NvJqYvYXDzcG_NplpQ.jpg located in images/rivers
# File ANd9GcQuUCd0sA19K8NA2LjOuofcZMDDoS6PDr7OAeJyzMaVAQTa2-Jp.jpg located in images/rivers
# File ANd9GcQwCy8g7u_D2mpAQlB3YgZCEH4SrXC3prCQy1ZS-z0GaCOax1zJWQ.jpg located in images/rivers
# File ANd9GcQwbJ1hVSQxWoEv1yS8zJEnL2ZTHJ60CVPrrtHL-_j5zwgOEw8I.jpg located in images/rivers
# File ANd9GcQwg1qJP00NRZgDot_aghowWx1Mpy0xAkoYPtbc0SkF5tZC3xJttg.jpg located in images/rivers
# File ANd9GcQxeO-JhNR5ZkkMdnXCTWydlaxOfyhwfvUfbbxPFm0CnzjhXuDQ.jpg located in images/rivers
# File ANd9GcQyMvH219WcFQKV0Jm6Zw1LxliP9crL_QsG5g8AK79kVmZ1XbbQ.jpg located in images/rivers
# File ANd9GcQypC6rhosIl4n97Gtm0Jm0G76eUP9GnW3oOf5t1YqIWrMIc5dCEQ.jpg located in images/rivers
# File ANd9GcR-TQIxtn3ateoDJ-pRJEAM5aPFZDSj9CBaYzC7vrSlCNeA_UI.jpg located in images/rivers
# File ANd9GcR0VcQuJwGzndY5vEXZRocuzdW-qv9KT73qC8KF8oWNgS_GaBJv.jpg located in images/rivers
# File ANd9GcR1JGV3uLonrDCQBkoAlWNx3hGBB628J18u0G92EqJDcRCepCWM7g.jpg located in images/rivers
# File ANd9GcR1Kj3j52NhIyOUgPG22jjCeTHpC-WVEwMXWJZMpablYh8DUO_R.jpg located in images/rivers
# File ANd9GcR2FCtkUDDAJSQHmIGWbf5qbmcu_gvpPfGg3oN0JOvhScZm9YqidA.jpg located in images/rivers
# File ANd9GcR3BbPwCp6S8KfumE0k55OaqOc0aWfn_aHEp38tswI1PMwLrk6o.jpg located in images/rivers
# File ANd9GcR3CInzE63yFCPsWUdE_8AYmt32gpUxKhiforVu1HdBLjMXkjTOvA.jpg located in images/rivers
# File ANd9GcR3HX9zNOg_leVURJluUFFG7rc0hs9XD8EQ4B38ZhUR895lq6qv.jpg located in images/rivers
# File ANd9GcR3kr3fEREIme9ZCsVxtMpmx77e1dwT3Se2aGxVj39da9hC54BC.jpg located in images/rivers
# File ANd9GcR3lAOyj12x1dIz84FNPos5q1lZTz1WodIl5AmyiXxdETj04V5ung.jpg located in images/rivers
# File ANd9GcR3yHbYMjAcGANRu4ep_KkNYeLnQ1KTeo6Y8TTcYamC0yPmxIbr.jpg located in images/rivers
# File ANd9GcR5f2ITjjlXqjM7esu52w3uNorU7Hfh8lfi4fnpiS2aGO48rX430A.jpg located in images/rivers
# File ANd9GcR5kTfbURotlgKnQufnlV3JzXcU6DfP7yRmIoTjZNq2DfKLmGEpkw.jpg located in images/rivers
# File ANd9GcR6-yF7ns3thAykuqLPccK0KssYvtIHn1FpH9I1OvK5F5C9MK7tSg.jpg located in images/rivers
# File ANd9GcR7_yIhfDd8-75PogDaIQl5o_IyCjjdtK-_k9Nleamfj_owoaYFaw.jpg located in images/rivers
# File ANd9GcR7i0JXQsYtSXLGSz4HZLqy1oa7IgRyHQFVVuzGslA4PKLe1L5OaA.jpg located in images/rivers
# File ANd9GcR80GWyP3KFXsLuhad5ty5-d7Vl4YbsvepoGq5fFu9LA8xw0FFXCQ.jpg located in images/rivers
# File ANd9GcR9f6FJ3Mz5Jc-Yqcphv5EAJJLwpi-eT2bp5HoxNf3V3XGk430W.jpg located in images/rivers
# File ANd9GcRAE39pX-kqM3Bkru9sqoUJy-iVKFkgEFzKj6_B0zzvwpCHb3dtRg.jpg located in images/rivers
# File ANd9GcRAdOJMLDpXrq6Rrv0kkp2pvAUlehYoKXAH9S0o2G4FWReGyR2B.jpg located in images/rivers
# File ANd9GcRAhWi0jhErjBGuPtiW8ZPe1eGK63vV9OJPERGO4NkZgxvw4sxYEQ.jpg located in images/rivers
# File ANd9GcRAosbhIzOChT3qbnf6jxsnPOz1bJUzqpZZeHnToQ-d-JN6ikTP.jpg located in images/rivers
# File ANd9GcRCp1c4zkgi-OOchW-u-f8rL40FbwIk4sWTwhux8lJCLXMk800OIw.jpg located in images/rivers
# File ANd9GcRDQ1sSlFRscSSD155-hJL3HqKSUG6UF_r_f09CNbU_plgL8LIXKQ.jpg located in images/rivers
# File ANd9GcRDafbJYEPQelYfrAFPNO-LW-rfuuTEf_gXlJOUCK6yco5PdX8R.jpg located in images/rivers
# File ANd9GcRFOoCJNb_8BKAScANNsdSUfvr8dsweZF4dDTPAd0O5wmh8oCk3Ig.jpg located in images/rivers
# File ANd9GcRFcGKznPsuC9pQ54KjgeeIMQRFnV4_CsZoISu3Txza8d06LTud.jpg located in images/rivers
# File ANd9GcRGcjtVNlncptuL9GMdVqaxhYmksU5o2OwN_IGiUsHXMbVK6HkHAQ.jpg located in images/rivers
# File ANd9GcRHJf0o8Xdyd6NQiiHMSEEY38xiVSTKZNL2PAt36BTeHxhbbmRv.jpg located in images/rivers
# File ANd9GcRJIMgw9eENi6VKn8TRw3HWJLG5m-ukyTtaH01i8wDmnPFuvm1L6w.jpg located in images/rivers
# File ANd9GcRJYlbjfn3TkSIIFJZu-V73dNGTjJr56LXyj4jwm3sobVibLkxL.jpg located in images/rivers
# File ANd9GcRK60zs63HEp4FdoYxIx6mp-ApbN4XWEn4liy-VBVoH400LO_ao0g.jpg located in images/rivers
# File ANd9GcRKffIBraoZOoC5UJdse8bNB2DmqyiG5pLIedP7tL8fEXAFDC4mCQ.jpg located in images/rivers
# File ANd9GcRKh9cBXVQIqAthqNJG7OGYI_3cdKHfbp-4Ft3iOJNXtTvJrzee-w.jpg located in images/rivers
# File ANd9GcRLtyA25Mx1V_GyHmikjCxTPknDSVM2GAe4ix-nw19kSIgbUXtj.jpg located in images/rivers
# File ANd9GcRLyviWM4QHzGg8DyoEjOaKLRQayECrNU4de27xnjOX7sA_R4PW5Q.jpg located in images/rivers
# File ANd9GcRM6wBNLAu2fGcNtwhZWER9HSV5VObogHInADnPYCOAjMIkmFfWvA.jpg located in images/rivers
# File ANd9GcRMDGzn7Q6CASpoYJyFmR6Lkv-VvnaP_j6RTGdkNpwSg1Zd7Zhz1g.jpg located in images/rivers
# File ANd9GcRNQDDlRRerbyCVEm1-ixzePxl1WoyDlyDmCPUHjZ1IHis-L44R_Q.jpg located in images/rivers
# File ANd9GcRNqNFV9XD8qS8ed-r0a61AUeDqZXSDL93sRqNzOWecjAVBI0czoA.jpg located in images/rivers
# File ANd9GcROAWDsg_3Sxz2hR6fPSX39Kvbqt-skVrrvdlXUEsj2mOiVJSG7BQ.jpg located in images/rivers
# File ANd9GcRObtPifNQmDMlNJIO9H3esYEdLPYKso-oeHrhG9K_B-GS5GRk9.jpg located in images/rivers
# File ANd9GcRPXfXW-2UPoWI-XxpE56S3hI7xrPRr_D4RLEwWeyeH8y6b7nDE.jpg located in images/rivers
# File ANd9GcRPinvcLyKfPxfFFXFVfY_R_06U0a-vlF_MVeDthlH2G_CX_lk3.jpg located in images/rivers
# File ANd9GcRR_z4ZZghtNlcOMSVXHspdDJC-G5vSLcCfCkzsDC2EBowQ0Z8z.jpg located in images/rivers
# File ANd9GcRSDnabysbXffxD4zqQlX70doRpAKqNAgZORnvUZ7L8qMV1BeX8gA.jpg located in images/rivers
# File ANd9GcRTlBkCs6ILmDyfytCztisiE9r459O9SbJYxvNoX95wO6lwCJdKhA.jpg located in images/rivers
# File ANd9GcRUegvhuBSU4Zw5xwafsCI5Cn9x1bRlw5FXGEC03nWnzCITGzGP.jpg located in images/rivers
# File ANd9GcRUjrI5osuyps5PNBzUJ4jS4DK50xbc-LL7RUTaHNvdJpsPgbEx.jpg located in images/rivers
# File ANd9GcRVJ4E7UMNi_hN5lYyv9GiBFS6dtdKy7XGCPt4cP8nz-rPPLx08.jpg located in images/rivers
# File ANd9GcRVPDByXHkienB4LbA5CZMabGeQiyKBuPTiHA_rHFm7Guvns5fS.jpg located in images/rivers
# File ANd9GcRX4Inf0Bs1b6tKTjxfbjB17lVF0bMxZuPQHY529g5Sk_o_wmUm.jpg located in images/rivers
# File ANd9GcRXLeOcV5_w52ifTfuIfQoMIDqWXHcETQ5CPBn7tAxz8EDW59depQ.jpg located in images/rivers
# File ANd9GcRXQYJeMTkySOFt9e4-E-PLninohDK5nTDEAMUT202t7mF0cdYDfA.jpg located in images/rivers
# File ANd9GcRY_5EabJ_ldLD7_KAD7L3wicsSIWOEr2FnOJUkbDN4fHQlNolWUQ.jpg located in images/rivers
# File ANd9GcRZTqtm6b1WF3g9JZQvk5ZUlJXR_KHTxmR3O4bQSGZY0KQR-MWX.jpg located in images/rivers
# File ANd9GcRZrm1NcPNfbhAfaSwPKDZTOXBptle-yLbfq8TCIolWNXqgwIpWEQ.jpg located in images/rivers
# File ANd9GcRZt-NP2Cdsy1aXO_RU-BKheQhrraY-qxtS2Yfy90RWGAoiEcXL.jpg located in images/rivers
# File ANd9GcR_AgfgQdXQkYq4S9yal-xsuvrmU69cXm5nAXV4ygIYFypT9vVG.jpg located in images/rivers
# File ANd9GcR_MxfxEZtxFdJWAS_m20a05XbtmCajSZ6V0rnHSAv1U5VeNstOKQ.jpg located in images/rivers
# File ANd9GcR_uIdd1kLusskSmpBcKiKZaKDbV5ZmsS1VGqbz8ioNsxj8wSyE.jpg located in images/rivers
# File ANd9GcRaZp0STfVLa68EhvtfYj_AWEXgA1rcmXsveFMamYizm3lgPFWr9g.jpg located in images/rivers
# File ANd9GcRc_X7W0liYW_rSzBWSgD4r7f5EDAhvCxyx-z1ydkxSbTJzzuql8Q.jpg located in images/rivers
# File ANd9GcRdTIRkBm387QhxYiLkyg4JpfuduJxGbIbQUSG-5uA4dnKp906ytQ.jpg located in images/rivers
# File ANd9GcRdqKcAMLjhMNaoXf9r1CZlAi3TQ7BBPapdzVVAx6j9dfcTTzEEJw.jpg located in images/rivers
# File ANd9GcRetEFfEBk9l66ncFP5wRTocK7O6rgCahshBUrhd7qI_zLi_M-XBA.jpg located in images/rivers
# File ANd9GcRfig6mcoh1MeJ6o7g2dUufbqYG8d92gZ996m429o6tQyl3T8IZ.jpg located in images/rivers
# File ANd9GcRgY4kA8zyjMezKG7Fhh8jwYO7R8YqaMEu6fORGUhIXE4dT6UCx.jpg located in images/rivers
# File ANd9GcRi0IXuqH77uRcrHa6-wP2nxxRs5ZSATMfnimazqJQE-W3dz6w-Xg.jpg located in images/rivers
# File ANd9GcRiRMryUEO2v6-fny98HCqNViGiSKvY_oll2q3YdIj5bkZ0sHnA.jpg located in images/rivers
# File ANd9GcRiVlVzoV7i-Qt7Wi5Rn1LoMXaEEnnkTK91erJhNbDOUUf6-7D9cg.jpg located in images/rivers
# File ANd9GcRjv7l4U_iDwyaGwcdLfxwWO7FaiFNeqbPN-5vHYG-oiP74nrY7vA.jpg located in images/rivers
# File ANd9GcRk7I5V1FOKTUnlGyjPUGYcmnWjMHPlcXcj1YHYQiluikZ8khty.jpg located in images/rivers
# File ANd9GcRm-t0PkztEycv-bvgC074deR5luJjLMEcgMX05d7UsSxdbGVoQeg.jpg located in images/rivers
# File ANd9GcRnL5jGGaGX7Dka7rBiS0HB__vIdktwTv69P1FOB2a3eZ_A7-E1.jpg located in images/rivers
# File ANd9GcRnlrFLqJ6PqoTEHTtTSgFe2PPt3iPfT9fPBm2dxY_EVubFSbHL.jpg located in images/rivers
# File ANd9GcRoKWQl2yL_IZzfkdOpSaBL2WTv7Xczpv6gq2U3z4z5Yh7Cl4GU-A.jpg located in images/rivers
# File ANd9GcRp6X9oclsADwUMxHUdzOFsTxHz2-PJM0qoy9CcTEjiTGzD3E-a4g.jpg located in images/rivers
# File ANd9GcRpRkdLD1XKK4IJxPnvkQ_Gl_TrqYVpNE1NbGb8ZuY4nBhItrIX.jpg located in images/rivers
# File ANd9GcRpplyVeK11B8IclQUnMfNPY83GDb1soOmhAfpnzXL2PtpnnifS.jpg located in images/rivers
# File ANd9GcRqHeQQ1fb6xaYTVcsLOLGiyZqjicMzKCUzA8R9vHP0fCVetD_K.jpg located in images/rivers
# File ANd9GcRrKFdh53X21eFpOLDu8xxaJfg1YE294ohXmub5ri9ArhwXX126.jpg located in images/rivers
# File ANd9GcRrk6pdCQqcCIXSKqSFEtbx_4lo-KEdLpGtwt6jx2mz0AACmS3Jgg.jpg located in images/rivers
# File ANd9GcRsiWgVkOjYa-g7CR5oDNClXbb3Lxs-d6bSqCXHAsMc5KVVAOypBA.jpg located in images/rivers
# File ANd9GcRt-EtR7nBhP8sQ-ns7QovkTbYV8fY08yhjVicOPXzcG-c9EfYpWA.jpg located in images/rivers
# File ANd9GcRtXCCfxlThksfROeK0B6OG5NcNEfNMcZuJIrJT1jxMC1b2ywl8Cg.jpg located in images/rivers
# File ANd9GcRtdrxnZOg3VSjjaZA4J4UR3eDPU_q70X-GSh4vZKdl4CzYmX1QHA.jpg located in images/rivers
# File ANd9GcRtk89HaQdb2w0xnlw5RvxHpOqTwdiYvJE-XpsoofT5OdXKAO4Y.jpg located in images/rivers
# File ANd9GcRupsMunpBTMlCf_kbwy9UFj81SpVUBkgLRK6-AUrSUYkDUa1RMlA.jpg located in images/rivers
# File ANd9GcRvWK8hHZZt1qaYYrnYZ1q3FldRSVvt-b5gE0Iqw25v4w2YjHW2.jpg located in images/rivers
# File ANd9GcRva6jwlq1JGNWDrFy1TNybcAdxtlqHPi6xJe69sY1mSTplhlge.jpg located in images/rivers
# File ANd9GcRw4TDxB7GKkYu7KnzXa3a4WPQ_DsuZWX_6o3fpgwGE13CSW_i3.jpg located in images/rivers
# File ANd9GcRyNyPaaWPp65jF-ZB-z2Zs1I2tOTk4DkftnbbNvQwqrNsPcPSQ.jpg located in images/rivers
# File ANd9GcRzuL2JmhiVuxOY_vcXSlhIUoDnrhSZ7e8BcnTxdD2Ws5pUWsmq.jpg located in images/rivers
# File ANd9GcRzwEYpXZO8ODQv0-3S9bUk-EqvjDwbIQtNmpHb_v889nXFPFM6.jpg located in images/rivers
# File ANd9GcRzzpMP5qknK_R4EyWBP17eQVAdtsn-aa6n6SUgyR4gfs3PAr6-eA.jpg located in images/rivers
# File ANd9GcS-3mxwBdqwymDjxPXYvkSNf5OFiWs0HVzYguAbZqStO2Iyls-W.jpg located in images/rivers
# File ANd9GcS-6FB3XaYBeHvXb5PMJxcA2B9FoDSOaQgkCbJA2jiH9MUqtd3n.jpg located in images/rivers
# File ANd9GcS1D7EEjiyG9RiPxzzEiQSrE18nKwA4vhRfGO-DOHJ5J0XsRH3jYQ.jpg located in images/rivers
# File ANd9GcS4mRt24mljxTx0eaVGZ5D2mMcKFSBiCJ2wr3kZrHBrgcbuLMC3.jpg located in images/rivers
# File ANd9GcS5GoLBrGPiuLfcmfx7f6G2bylIILMEZ4gEGoBH2Gg7aywsvdjyXA.jpg located in images/rivers
# File ANd9GcS5nuDP6CHsCXWWahz0UqKC5JdZtMgeo1iJ89pC2URGLr4IvVOH.jpg located in images/rivers
# File ANd9GcS76jI7qbcacMaAiXHX1R5vISqpzg5jl20ZyDg2xzyV0LjWlDV2.jpg located in images/rivers
# File ANd9GcS7BUM69BjIZYeHl08l618814Q9cPvKrBG31-TVtDQU0voC5aMt.jpg located in images/rivers
# File ANd9GcS7V7oOfy88GYNHRYLO3cBksPcFptEHtNfatxvCVX7Jn2owekgcaw.jpg located in images/rivers
# File ANd9GcS7atSXHWW034EtjjqEjZcbe07-JakiELgsRfqcNFXrI0KAz8I6NA.jpg located in images/rivers
# File ANd9GcS9yS9sheiBz9Z9LA4cNja35lemyqJFWk_5aw8cO6GCHqT9ebOMfg.jpg located in images/rivers
# File ANd9GcSAoxSexQWAkH1UQVG8XZDpZtEetRQ7lI1Jy5VthSLtGrT8yWukwA.jpg located in images/rivers
# File ANd9GcSCmWcmt3shlLZXuDJykAz8STRCb0djUm-ME5SN7crkFiSuU21I.jpg located in images/rivers
# File ANd9GcSD8ZJ1D8_FnSrQjAVe-YfvJNlcuFqReNrw4UWwYAZ_hObA3czqig.jpg located in images/rivers
# File ANd9GcSDLGmWkKtr830I_5u8EgakQA2eHio4UnYkHRIRzVyxeuWPzgp0Uw.jpg located in images/rivers
# File ANd9GcSDa4NQVdcle7gAw53O1SuSrZ75_jf_BFJ_a5uhOKmzE5lGR0xHTg.jpg located in images/rivers
# File ANd9GcSEMNyKsPy85BbhqZ8Rhv0-hyHQnOyg9j51b3eVvxPOUywjAvMK7A.jpg located in images/rivers
# File ANd9GcSEiSDSgl_aVQKr1aECkinki-4Be45Sts2jXLke3c7ddHWpXh6t.jpg located in images/rivers
# File ANd9GcSF9YE3TCilxGBHKSjckDEBPZa8_paEymiuqsyhegj-zluIu14I.jpg located in images/rivers
# File ANd9GcSFrBqxT3v_IaLYGNfcO6zkSiMbmaEIcQIoO5PzozqdihNVI4ejKA.jpg located in images/rivers
# File ANd9GcSG97fTqJXE-qGzgXihoP_wrV3Uo9cq71LCETi3vqSoC6geKpPvDg.jpg located in images/rivers
# File ANd9GcSGHsjuLAM2OH4TnXVxi4cwLlyjHlRxJXoUiUJtZFfuhneYf8Pz.jpg located in images/rivers
# File ANd9GcSH2HgdUsSkJFkvdPwzw2dZWjI_6spJPDhZt-8GdgLTV4KEfO54.jpg located in images/rivers
# File ANd9GcSIQ_UIrGapUQBa-OEsIn0K7FXEuGKMzWB27slb2OBX-BlxUbCu.jpg located in images/rivers
# File ANd9GcSK3j_K6ot3SoduIvUy3sS0GvrzcWIVElfcTy2ocAhEj0iY4wud.jpg located in images/rivers
# File ANd9GcSKyeqjnK_KmQfzCTZuIoXreVKIL4W55NGEgvABwPJJYV9HzUczhA.jpg located in images/rivers
# File ANd9GcSL4gS88i17M6QNE8aJLCaxRL1jQEGfBuXCjxow0LN5_gzcOAkw.jpg located in images/rivers
# File ANd9GcSL84wJN-ELgHqHdC3OCdo6I5DNw6RPfR0TKnsiCmeKXwHW62NS.jpg located in images/rivers
# File ANd9GcSMxeIbybPD1g_0s6R9pkRaPXLPPCGAOJCFd6LAeENj8qwZxZqg.jpg located in images/rivers
# File ANd9GcSNaSYsUrXXMbI6a36o5s4tzb8NoMOvOsr44-w3G2L4T4YO2wfC.jpg located in images/rivers
# File ANd9GcSOIUoSRSLV6kxF2c5x0I8PYodFqN-QRqEr6-oKPh2K5x2gFWk4qg.jpg located in images/rivers
# File ANd9GcSObtswrGM-aiq54fhmvz9GAg8_a1aaErMOfKStL7oYE7WFty9RpQ.jpg located in images/rivers
# File ANd9GcSOkZvLfZ7-JLWl-pBHXQdT0qtxyVtgMm9O1-azCLUZb6mALg_4hg.jpg located in images/rivers
# File ANd9GcSPlpaY73dbjqL-8ffbmalAS0tiQRogAlMbMdIDUnpaW1YIPhIK.jpg located in images/rivers
# File ANd9GcSQVT-rqk3KPTR7_Ixv94JTElYnXzNsIL4TELisIvK69F_kjC8nUw.jpg located in images/rivers
# File ANd9GcSRG5D5x-DGFv3xtsHuVGIz3GW_xY-si0ifWGTsU5YQ5xPp_QY7rg.jpg located in images/rivers
# ...
# File ANd9GcS95WZBPIeMGiZYW1bzicGv-bEmQpiRdfenWxza8xMqUpWDrE6Z.jpg located in images/trees_and_forest
# File ANd9GcS9KnlefU_7ACh51Ti2e99GOdeEmHRDXOaEWsqeYvhzJ0lq8Pf4Cw.jpg located in images/trees_and_forest
# File ANd9GcS9UhyOVi-qgUd8nAvq5dE43nCGYrfopTo2Q2G8zfriuh2cHQB-.jpg located in images/trees_and_forest
# File ANd9GcSAVbg2fK42ql_1bDreCuP_dMwv-VLSYegeVdvh8FNZ5v8DpLmRQA.jpg located in images/trees_and_forest
# File ANd9GcSAmu71Shmsk3fWPLmTh6E02pPhruBpQu-KEfnMK3h1j9o-PSi-5g.jpg located in images/trees_and_forest
# File ANd9GcSAyt5fmWFutU78UjgENTje0bcag8ITmf86y1X-7IkCObcvmteg.jpg located in images/trees_and_forest
# File ANd9GcSBAjw_xZrRu8mCsEPbHeb9yX81Tp29ouEvTzJv-_fYRw74yNlm.jpg located in images/trees_and_forest
# File ANd9GcSBMFmh63QrpamHduLDBMzmkh9s0G8bvZsMwHxuJNq3I4D9dzC9Nw.jpg located in images/trees_and_forest
# File ANd9GcSCyu0TuwbwaCFAG-HJl2-DyPOWS_RP6xCU7of53ofEmsE7oWSwWA.jpg located in images/trees_and_forest
# File ANd9GcSDBekUfT0HUBMFSDDvdYrBCpfJRNgAbzOzX9mnqbTIiTieJAVDuw.jpg located in images/trees_and_forest
# File ANd9GcSDevGLPlyOTnLwSlFULki30H2UgG7JDo73ZJKvkJ3BL_HvdQ_V.jpg located in images/trees_and_forest
# File ANd9GcSE-l2ZDNgl-wT6pSxS5_R9-0-8CwHl-t7MGJqWLxC4_tkkfGW7IA.jpg located in images/trees_and_forest
# File ANd9GcSEiJCN2Qx2j0hIaRb8nRV7bEqn5Nm9CcALlPdcykgFHSt2P78d.jpg located in images/trees_and_forest
# File ANd9GcSFHxKSKDa8tm5lyVKuEdn-E6x5zAIc3qtZEvU6bXN_VWfH2kah.jpg located in images/trees_and_forest
# File ANd9GcSFW7RpLRBSjtSGS4jlLTzwsow898_wMTXGLG-3AFUKpkhMzUAnIg.jpg located in images/trees_and_forest
# File ANd9GcSG9DKMefcwHuNuRaSK98nowiOahpPMX5C1LW9SuY8FXj7HLmKN.jpg located in images/trees_and_forest
# File ANd9GcSGKsKjdUi2GlxYB_X06r-d8haa05B5W2b5lk1q2okJ6bQBtuk9CQ.jpg located in images/trees_and_forest
# File ANd9GcSIZz2mYtQ3EjbDNQT8rHDT_mJpB0mgcbSqC76j6p1QtG5FgtsV.jpg located in images/trees_and_forest
# File ANd9GcSJ2i_cBY2yyNcPgH2v86zRmRoruZuI1uBL5P2nV7KV-Wjef8fkpQ.jpg located in images/trees_and_forest
# File ANd9GcSJDh40W9E0j7O8QUb7B_8aRkDRQ4hl0YSyPUwpfy6hSY3jnf6mGg.jpg located in images/trees_and_forest
# File ANd9GcSLW_pBPLroKH6g_hPQ7STEDZ2LyOibTEnX3uLszaccC-2OHxpQpA.jpg located in images/trees_and_forest
# File ANd9GcSM4FJcxaAYZ-sY-uLf3g2xXS-_bQX_p09cJ-7Rdy_ZQzEWbZod.jpg located in images/trees_and_forest
# File ANd9GcSMa-JWx5ShOhIz56NFZqFaMtmhkzQ77fe3xXebLYTiQ2R7kk6b.jpg located in images/trees_and_forest
# File ANd9GcSMhtDdu38vScAAn-_pLWgUsgA0GMx4JDwyfZmBk0FkzgFZq-kQ.jpg located in images/trees_and_forest
# File ANd9GcSMxH6xPVAig4cMZvh0907Ot7TPsy_zY3J4wA6R4Y5uuV-Aokh_.jpg located in images/trees_and_forest
# File ANd9GcSN4bnXXRj5RN49o34qw2-srr_Genbr3K-RwRUbvdX2MqSMRNfC.jpg located in images/trees_and_forest
# File ANd9GcSNT5_Cary0HdL3bU9CAsbGCePYDFlXpcbPDwpNriXNJFLgwAq4zQ.jpg located in images/trees_and_forest
# File ANd9GcSOCmHpNDLcslEWQtXlz42JgEeAxbxHc8y0n-iGo3OFxLVtmLCOhA.jpg located in images/trees_and_forest
# File ANd9GcSOY3BdlsjwxzX2e-i8mOEjpw3vrAmaZsaL7lACw6u1_JhL1cYC7A.jpg located in images/trees_and_forest
# File ANd9GcSP7DNfO0b5Qrqw3X7YPZ3MSZx-OruaVUnbttCK2FIDUe2QRxIdXw.jpg located in images/trees_and_forest
# File ANd9GcSPzH24lQ6COOFqiRVH9-bPPHnJ9TNKxRbAkfgO0i04MppOlYpXcw.jpg located in images/trees_and_forest
# File ANd9GcSQl7YQZItiY4q6ETbsT9cfw2Fl2y0Skj60asc2OKy6_5HuAbQ8.jpg located in images/trees_and_forest
# File ANd9GcSSF8U7px6Xcxr7YeJIzb-xovqtTGCjrpWUlSU57WDUhBsUSDtw.jpg located in images/trees_and_forest
# File ANd9GcSSTHQIhY4Mza_LPipmD0cC3VD192kPxf07sJhqae51xKlzkc3d.jpg located in images/trees_and_forest
# File ANd9GcSSc65H4c06aDU9_NWRdHbMDHn69gMyPqnvx5vH76_GFyJ7XRdw.jpg located in images/trees_and_forest
# File ANd9GcSSjmfw5STWlhFcJxtW6kgHeJbw-knAeDQYO4X9p9ZZNGbfEcwkPA.jpg located in images/trees_and_forest
# File ANd9GcSTYuNFd36csaxm9nSjRGWmNRc7Xr7in-H-2sK9MbhQsANrtDZ_pQ.jpg located in images/trees_and_forest
# File ANd9GcSTvvCIVw8II9PxO0ZGUIc9EE6zuo8UBZXlv3hkLSm2InDjXXZ7hA.jpg located in images/trees_and_forest
# File ANd9GcSV1KUlzVP-mrwoT4xLXzNnYh2oaSwma1oQhbwaFTxDJzKLnMc.jpg located in images/trees_and_forest
# File ANd9GcSWOaVBhS5ZPNydImCko0I1Evr4oJhqYJlWRAqARFz7MSrZuFg-qg.jpg located in images/trees_and_forest
# File ANd9GcSWifXIvSCE-cLz_QukFSzBWNprEol7iKu7UoeGPnmnFuiLI-tG.jpg located in images/trees_and_forest
# File ANd9GcSZHjVYNhqBkLqiVWP-a66uZjnZQ2l55z8JvGBar3Zr72LVEFwn.jpg located in images/trees_and_forest
# File ANd9GcSZsuEI250NpGqPIJ3OXaQ7OGmm6amctvbl_zk0VcVA9Lde89xxoA.jpg located in images/trees_and_forest
# File ANd9GcSa8X98QaDzdTvj6dyF44VU3LMwsAK2GtZI8knydvmPctbvlh3EbQ.jpg located in images/trees_and_forest
# File ANd9GcSaBuhXc3WUNbaIybmFyQuOOkEi1_umwAXQQJxUW-BRkjB9rERY.jpg located in images/trees_and_forest
# File ANd9GcSb-mxB6dtQfcqeOfa-6saa63XbPBt0x1nLwq6qCJvRtn1B-kc_.jpg located in images/trees_and_forest
# File ANd9GcSbDH-v2sixFCrooV_mAyRK2_Qsrv1YlktNaPnC4U58ZDv9xmyvew.jpg located in images/trees_and_forest
# File ANd9GcSbEfY4fUCKZR0jV-RXOwq4oGlDEvEpidnLV3rSOniMCNImi-iE.jpg located in images/trees_and_forest
# File ANd9GcSbNcfzKq9ZgKwiFPszSsQ7QvSm4dhwWyydaGdve6EyROOfRtcKsQ.jpg located in images/trees_and_forest
# File ANd9GcSbuojaXrWeftQQ-vvSRu_ges0JFoSlHTipX86ciC70CK2L-0YkoA.jpg located in images/trees_and_forest
# File ANd9GcSexekyvYZ9G19MghViZPP2oP1856UON64V6b21K9nYv6fXqYMC.jpg located in images/trees_and_forest
# File ANd9GcSfnN43LgS-ZV2CGROXIbgpd5L1gzVT6BcsS7SxMhPCjy4MoLYI.jpg located in images/trees_and_forest
# File ANd9GcSgfb6vdXkmMFFSlGOc8VCmyfjrucLa_KcYvM3dIwFwgYxscZsR.jpg located in images/trees_and_forest
# File ANd9GcSiBjQ2kECFhcnbmNvYxANJOavo694iE4FxW-AFunvt7B3z_sgc1g.jpg located in images/trees_and_forest
# File ANd9GcSijwoq9BAQJ1Cp45URpggfjZiv7fQVpxEVZVl0Lw7-6tztVWIy.jpg located in images/trees_and_forest
# File ANd9GcSjLfSp1Sqe5WDfwxskCjC9wn8HIeTt8Sq2QQDID9l9e76M1fCx0A.jpg located in images/trees_and_forest
# File ANd9GcSjLxqBXihLKdl2J-va8JDtW8AUgTeZSih9ViXuO0D2I4SEr4FN.jpg located in images/trees_and_forest
# File ANd9GcSk-6fU0nzk6adzij1IOfxp7qq7q38IntVCc0e8jJFWn8N_aHBgHw.jpg located in images/trees_and_forest
# File ANd9GcSk6DvfcykdtIDtydjI4a2NEs3UIe_V2MfvC--cwKDNku3xGdWt.jpg located in images/trees_and_forest
# File ANd9GcSkeodf3uQeny1qseez6Z8d6VRKudGn5gb18LDGNjk87MNZdOroeg.jpg located in images/trees_and_forest
# File ANd9GcSkhRJdHUKdIaoDNbn6ff4pCDP77NylZ4iltSKr_rzFeUtbyOqh.jpg located in images/trees_and_forest
# File ANd9GcSkjtG5zr5c3BjuFtfleNhNbAzfPg-1jEyvL-biXdxm5F7JHTXM1g.jpg located in images/trees_and_forest
# File ANd9GcSlNNPCS9vLqxCRgXy463nwwSgr26t-qWUzUsk8azFHErCG8Irl.jpg located in images/trees_and_forest
# File ANd9GcSlxw0Rw2x2Mn-pqXpoZlWku6fiUxyigWlrsmPjqJgqRtrCQfhErg.jpg located in images/trees_and_forest
# File ANd9GcSnFHSajFqRUpbInqfk0VDBufL9TsAgQ-SQJvzVtJ69Ywwq2nWdUA.jpg located in images/trees_and_forest
# File ANd9GcSnpNvskfnlVMhtq4muGkg1iRUol47_T5DizYComjWjW1iUz5MI1w.jpg located in images/trees_and_forest
# File ANd9GcSoIB-6d3E-U0YIluN-R1rSIKFvafmY-AyALPv7yom31QOvyQXD3A.jpg located in images/trees_and_forest
# File ANd9GcSoMvi1L0rREM1oVk3TNgQTWNilPKHb4gtWX7pqi9tAMNb0HJdnuw.jpg located in images/trees_and_forest
# File ANd9GcSpZAcwjLCsurlCMADDtgTDkxJLiyZaKKj1GhPzJpU4prd-YyR4Mg.jpg located in images/trees_and_forest
# File ANd9GcSt3fo2fcpVj_p2YNvch6kjYEtaA70BnkvVi5VHigute1QPiePj6g.jpg located in images/trees_and_forest
# File ANd9GcSuEBi95SuwXVuNlI2UQFul7TFu7fN5eKAxkaiVS4L-2qxNdAqyDQ.jpg located in images/trees_and_forest
# File ANd9GcSuGE3HAQQ5AhLZo-pVBX4snB0VO0UfBbNPYQxJW3LyFgmWxPZL.jpg located in images/trees_and_forest
# File ANd9GcSwW8uc3BYjrq0UX_RYh5KN_WjTTYvCvp7r9JwX_Zzm9YvR9NGENQ.jpg located in images/trees_and_forest
# File ANd9GcSwzvgOZ9ubcb221BikVqLxZjIdUSRZZ0p-evaPs1E3iCmYqvEFVg.jpg located in images/trees_and_forest
# File ANd9GcSxbZuqGH82pxzN2pU5FCDHx-l8-AqfvpvOCLDR6ZFCWHA_uUM_.jpg located in images/trees_and_forest
# File ANd9GcSyiMOZnlbIhCKM8H3R4GJO_QE6HP1QphEG8_q17q4K6zstinT1ZQ.jpg located in images/trees_and_forest
# File ANd9GcSzuuuX4HVsno6mhTTz080KUdvaOLnVwZtSlBblzui0DpTIEJud.jpg located in images/trees_and_forest
# File ANd9GcT-h2jUcU8VNVmN-US_QbnL9FtHq1JINlBUD_t-L59YC2u3bNes.jpg located in images/trees_and_forest
# File ANd9GcT0jq6tV1f4IjX2P-Ku7vR5pLZuxJbv2ljtI7FxFOr6Q6tz6kKT.jpg located in images/trees_and_forest
# File ANd9GcT4C0Vno57l7iFR44mRQ96611FnbaJ49EUDaUFG-xMQ_kxp1hrv.jpg located in images/trees_and_forest
# File ANd9GcT4vXBq1qg5TjzD-_ErJAtxrjoaWhY0CUV2w4--JYGkCb6_R-Xc.jpg located in images/trees_and_forest
# File ANd9GcT5RDKdt6F9cdDU6Tiy8uD5vV6NjO7mmK_qlL2qpmAnei_0tsBBsQ.jpg located in images/trees_and_forest
# File ANd9GcT7jovl7CmHSRhz2-qpHYCgeyDyQu-jX5iumlY2k8gXzxvVIXCx.jpg located in images/trees_and_forest
# File ANd9GcT7qOtqW0IZHgio61Ry38HhRpHBazHk1FSvtTOmTM_qMtR8nE_PyQ.jpg located in images/trees_and_forest
# File ANd9GcT8795DsEJHjGfl9NgJhXK71PeaJgBa1_A8YpsIBiEDWUmf15fa5A.jpg located in images/trees_and_forest
# File ANd9GcT92lOlIavilAhZkEcFdjnybYdotMhKve9JNP0l4v2B0k2Srn3h.jpg located in images/trees_and_forest
# File ANd9GcT97HyNAR5Bs4EYTqTeU57r_Pxnk9RtPYKPI3ajNw9GWeeHNc4H.jpg located in images/trees_and_forest
# File ANd9GcTBlsVnr4RXW-8aWEQsTErxhJqnGHf20eDrm2BgdwBc9ttDDIT3kA.jpg located in images/trees_and_forest
# File ANd9GcTCLvJZnrO_3C6HwxZ7w2F9hQFPLYtqZhMx9qrUlCDtFXZAfwjm.jpg located in images/trees_and_forest
# File ANd9GcTDfqfk3jTI1ZH2HaBbyGnGVJFUWK62t_Ng3JtqEcSG8xGxSHpk.jpg located in images/trees_and_forest
# File ANd9GcTF9ARH-rpsMLCFuqS1gnHPVGbEC7sFWSgzQpiy3bX9arvtjfA6.jpg located in images/trees_and_forest
# File ANd9GcTFLKKcnJBHbwHyc7LZQoTj0mmsTfEuZY_b6RdGeNQdvE1kyOR7.jpg located in images/trees_and_forest
# File ANd9GcTG2yNHIlNQ27u-C7NLpgv6Y5SbhP4d3y2j7fsI6NPV9psP3vGG6A.jpg located in images/trees_and_forest
# File ANd9GcTGZtksbDh1hLGGRcLASoAXeRl4Ipisb28wlyRHGxmQ8_THbHZ4.jpg located in images/trees_and_forest
# File ANd9GcTHCmUbHr_3s2fTmBHkFcJ3bfCZVBE82ZSEwNxFOR1kDkdPZMIu.jpg located in images/trees_and_forest
# File ANd9GcTHrIew_C5bT8tV2eo8wtyiHVo5ppCNd5_HqhcG_Kc1Fi9n4U__Gg.jpg located in images/trees_and_forest
# File ANd9GcTILefI6iGt4Nzlq8xlje1CnnAFUIqj36NPN45FcQsqbdcM7uSY.jpg located in images/trees_and_forest
# File ANd9GcTIqZK15AgrFYovisFTd-z7H6qeioUTcUkf6SWushtz48lZjntJoA.jpg located in images/trees_and_forest
# File ANd9GcTJuWdGfnuIaugvacc4BkRFjvmdMWhmQhxHaznXgu9INdeX0fAA.jpg located in images/trees_and_forest
# File ANd9GcTKjP9lFbXPFv95XFzfACdgq-Z2BfOeYsI3V5gb2ksIDKy0V6s5.jpg located in images/trees_and_forest
# File ANd9GcTLupkjbhuH_S-Af9Z9c60emTcK1TWw2D4GLYjuLIEpU-kX5Emxkg.jpg located in images/trees_and_forest
# File ANd9GcTLy-Xie5fbgGS4Fu4jgu5z0XndFvVFAjiWUB48aJzPtpTPk4SrDg.jpg located in images/trees_and_forest
# File ANd9GcTMDbORGQqtfUEIu4zYFBIV42PTSQ6KTkedF3AfzZw60Ft0oP_oZw.jpg located in images/trees_and_forest
# File ANd9GcTNZX-Cf-HAv9SwzUbrXOyYp9PZ6yMHYqQtFkDZNRTaPQ0fgsrnPA.jpg located in images/trees_and_forest
# File ANd9GcTNuGI-fXTqx0rMMu9M-WPdEgJVOR5lSvslvfTslTjJQS76i3aMSQ.jpg located in images/trees_and_forest
# File ANd9GcTOPdNvrCeailkrwyMwqee3Xt-3soBv-UuJDYg61XI7xP3mEcBP.jpg located in images/trees_and_forest
# File ANd9GcTQJb_OhSOq2n1-NkjnprVp6lc8wUnRJnKS6XlcJljAV57ZV7BeaA.jpg located in images/trees_and_forest
# File ANd9GcTQmQg2ZygzDwWmvTDvroE6S0gMYAIPmFIAAQ6Eu4TbDRv6NZKO.jpg located in images/trees_and_forest
# File ANd9GcTRyvZ-41QehA0RNZn2qPrfOIdxeKltcAmViCbi_OVdbIT9vSh4.jpg located in images/trees_and_forest
# File ANd9GcTSIxcLjKomsTgVx4sM43a8HxfjgyWNKOl1zbbRob4p7fPQj4qs9w.jpg located in images/trees_and_forest
# File ANd9GcTSZfy56sspDlJKKDfuOOMt42ji_gFMg-3NZeGFeFrcSOOpADrjqA.jpg located in images/trees_and_forest
# File ANd9GcTTJCZQiwRIC553pVEM4yE4E0kbJZmnqACBEJCi2EcFFeYnE9-INg.jpg located in images/trees_and_forest
# File ANd9GcTT_Sim1rVl9Md12FPvh6OWmzwoNCVNDk5erW2Lz8hEQFALF_XM6g.jpg located in images/trees_and_forest
# File ANd9GcTTt1MvDQ6vj4828rf1PgdWyerL4Gd1hZgNWUqHJAySZ3jFUGZYrw.jpg located in images/trees_and_forest
# File ANd9GcTVAzoGhPOjBRWyDsaJQDBwAWqwNW9L4Tois0ich9li-WQAL3kh5A.jpg located in images/trees_and_forest
# File ANd9GcTWQ40J2_uxlMIYDYmwPnBOqRRxjmNtQLX-AO1RjFFsFrhcfD4p.jpg located in images/trees_and_forest
# File ANd9GcTWo4twM7UurLWReHI0h-oeju8Q-UAn_30qZF30YNww7HcAW5SE.jpg located in images/trees_and_forest
# File ANd9GcTYXH07tA59nAfNdsImhF0nwHp_q_nNWSGJUjoe46NbYbn-WDPX.jpg located in images/trees_and_forest
# File ANd9GcTZGhDE1yRBjAbbqkomxT__7q-f2GpqnNv3XYs9TmOTg3ZKfMOX6A.jpg located in images/trees_and_forest
# File ANd9GcTaKg_d8TIonWxRWZ26SMOXPc0cNPcyDZECpHZItz_bBVqDqTlTZg.jpg located in images/trees_and_forest
# File ANd9GcTbaHCJ9EQZiSdqlN9qJ7Y1WqB2sVakw9rL3jFOS08rBKwWf3F61w.jpg located in images/trees_and_forest
# File ANd9GcTcWMIGJKj-62xKjrTU1eth2ErZtgyvzSNWRczVMyWt1YMk5WGYcQ.jpg located in images/trees_and_forest
# File ANd9GcTeCyHvSJs4YthkRyyO9Jg9y2odaqZSWRuf1ctCHVsC5FwkvosxyA.jpg located in images/trees_and_forest
# File ANd9GcTeUlueEoyAZkLhw2N54kYIZF6YERdtkzEJMfbwQG0p74N5809-.jpg located in images/trees_and_forest
# File ANd9GcTeaax2ZdxlBMrK6gwr7Gxhg72GMpR1BHKuVkO9b9vYuOtpKk67.jpg located in images/trees_and_forest
# File ANd9GcTgpQh_yKxGBI05EI9DvfOz0FqW98O3HFPImTd3834DfFJ_x2G0.jpg located in images/trees_and_forest
# File ANd9GcTgrsLfSciVZ1Aec7QzIzViKPaimxcEg7oeELGKlQomHzGJ7qMYGA.jpg located in images/trees_and_forest
# File ANd9GcTjQ-1VgbtSTcA2vX_-x45FWuGarEDA35SrMHgvpvYcOHUygcp1.jpg located in images/trees_and_forest
# File ANd9GcTjRHFoo-a--Je9WEjWv4kZCcQiEGUsqGmHF9tYlvTvFm3pQgWcmg.jpg located in images/trees_and_forest
# File ANd9GcTjRi-M3VmkYXuxYVeTV0gNHaW0zzxp3uzWYgIKnV8qkzq9K_-k.jpg located in images/trees_and_forest
# File ANd9GcTjcblLiCWz9FAwMKyqcFHs52eo2-tx12eXlaSNpXbjsTlBaeljng.jpg located in images/trees_and_forest
# File ANd9GcTjjto7bKTduKIvTLJLHaoWIpG4INso_e-eM5dgGONehqsrJBVJ.jpg located in images/trees_and_forest
# File ANd9GcTjssafo7MH_dj96AGMGT1BTg-HepjXLJ2pCb7yulj7hwKkcoN8.jpg located in images/trees_and_forest
# File ANd9GcTkE_YCtY2vqJnCmGjEPFOwSi8SvAWZIQ8JA4NdTe92pS95iB1jAA.jpg located in images/trees_and_forest
# File ANd9GcTkvX6vyBavJZiyUgna3FShuPwe7RAOkvwIt4WZaiNvAM2Hoo8HwQ.jpg located in images/trees_and_forest
# File ANd9GcTlwJLc6ZNjKBvgO_qAF0hkRq3_7zozkzBH75O5dTc06hDJh2M_zw.jpg located in images/trees_and_forest
# File ANd9GcTnj3ZQw2D_DIPmZnNovrWKZUs36wAgTU-ssiiMDz8XpaRmV44wvQ.jpg located in images/trees_and_forest
# File ANd9GcToaQgerrUTncM7JdxNdf0xFUo5Qrjk1Rmacc5_0xhX8qXZC9xjAg.jpg located in images/trees_and_forest
# File ANd9GcTpYydRLKp_K3aHCrjIeCh7PN-VDr8aKRJB9OwMRSlBirylXWiMHA.jpg located in images/trees_and_forest
# File ANd9GcTqz8Zjk7Q2rKtiynGHuWasam6PNJFkrKhHGXAX07rQYp1TdsdF.jpg located in images/trees_and_forest
# File ANd9GcTrV45oOB5At7wMRjY9R8U3dpAC3lc-SIpg33RTXYXJBT1jJMKw.jpg located in images/trees_and_forest
# File ANd9GcTrg2t_XvhY266-2xpUKB2RiOOao9IkZ5OGJFaEzPWPnpIdGoIJ.jpg located in images/trees_and_forest
# File ANd9GcTryPaiBQu_7rxT-mfP8IrtqFpR4VERl0yue5RI_R0yVBwwe7CHoQ.jpg located in images/trees_and_forest
# File ANd9GcTs0Wkz0LFlPJDvu-vp_l0h_LRsR_VdPPECVwRMnARscIOPVQGX9g.jpg located in images/trees_and_forest
# File ANd9GcTshOURjjYTSsoFYkj-E_LaekbXpBXy4tbeLYLb0XaqkixBBY5uww.jpg located in images/trees_and_forest
# File ANd9GcTtCyhhJuVSf_54aEwZFezjnFzIQ4AiwGWEKfkKC3qQqq4zSHaB.jpg located in images/trees_and_forest
# File ANd9GcTtgGoYXlVdghwDrm20Z_XcW0P_bnqeJQtU7TsOpZlFYC1RA8wU7g.jpg located in images/trees_and_forest
# File ANd9GcTudVR2orqVdRahad-vIKMrTNOG3LXafKJQggdN8o4YAuCRoPi1cg.jpg located in images/trees_and_forest
# File ANd9GcTupwOPjhWCnHEOSfhrqcl1yxYO-69Ls8rjEugZgOaNJE3cWs0eaw.jpg located in images/trees_and_forest
# File ANd9GcTvEm1XUSOAH_kGSoTOMgc6lLkKFzoxm1bfIAegGxfMODBn1kV7Fw.jpg located in images/trees_and_forest
# File ANd9GcTw2Te9eTAT0j95vc5ucYz4Sa-jJKvulmAaGEPl_MB2UKgkITZK.jpg located in images/trees_and_forest
# File ANd9GcTw57oLn0-wQxlhqDZeVhYaDHvX5XQc_JUY-bt9aCJTsLFj0ZpYWQ.jpg located in images/trees_and_forest
# File ANd9GcTxG_ADDB5a-AK7AQwjcEp2e43hv-pQpAx9ZdR4ji47F5YayLuU.jpg located in images/trees_and_forest
# File ANd9GcTyB-TGHClM8D3sKtzee19i1Y4EJ8CnVgIN4s4svDQniUlrYOTT.jpg located in images/trees_and_forest
# File ANd9GcTz4m-bJFb9KU3iSf2hrQ2-TXBe_F_3WlHrqir0VmD2Gn4-ue2p.jpg located in images/trees_and_forest
# File ANd9GcTzYdwl9Bw3DgkhLfAQSf2z889kTrI0HNL3_E2xbB_19TNP3pqy.jpg located in images/trees_and_forest

# %% [markdown]
# Your challenge is to load the data into a `pandas.DataFrame` and convert the data into required format. The DataFrame <u>must</u> have two fields: *label* and *mean*. The label should be provided by the parent folder, and the mean is the average values of R/G/B loaded in from `matplotlib.image.imread`.

# %%
def get_images_data(image_dir):
    data = np.array([[], [], []])
    for root, _, files in sorted(os.walk(image_dir)):
        dirname = os.path.split(root)[-1].replace('_', ' ')
        for f in sorted(files):
            image_data = imread(os.path.join(root, f))
            num_pixels = image_data.shape[0]*image_data.shape[1]
            data = np.append(data, [dirname , image_data, \
                                   [np.sum(image_data[:,:,0])/num_pixels, \
                                     np.sum(image_data[:,:,1])/num_pixels, \
                                     np.sum(image_data[:,:,2])/num_pixels]])
    return data.reshape(-1, 3)

# %%
# Read data from the selected directory and land it into DataFrame
data = pd.DataFrame(get_images_data('images'), columns=['label', 'raw_image', 'mean'])
data.head(5)
# Out:
#         label                                          raw_image  \
# 0  cloudy sky  [[[118, 127, 132], [113, 122, 127], [110, 119,...
# 1  cloudy sky  [[[27, 71, 136], [28, 72, 137], [28, 72, 137],...
# 2  cloudy sky  [[[20, 33, 75], [20, 33, 75], [20, 33, 75], [2...
# 3  cloudy sky  [[[67, 75, 78], [67, 75, 78], [69, 77, 80], [7...
# 4  cloudy sky  [[[197, 199, 194], [196, 198, 193], [195, 197,...
#
#                                                 mean
# 0  [135.30520374449338, 137.4203606828194, 139.95...
# 1  [106.52859929148589, 145.3949966166461, 194.78...
# 2  [88.5058910162003, 120.38462763205031, 165.848...
# 3  [135.4260836683517, 138.5161206862238, 139.086...
# 4  [112.60765036022768, 120.62691557536918, 127.7...

# %% [markdown]
# Similarly to another code block, you must set `verbose=50` or higher to listen to the model's log. Unlike the prior block, failing to put it in will stop you from completing the section **Evaluate convergence** below.

# %%
import sys, io
log_buffer = io.StringIO()
default_stdout = sys.stdout
sys.stdout = log_buffer
img_data = np.stack(list(data["mean"].values))
# don't forget verbose=50
img_model = GaussianMixture(n_components=len(set(data.label.values)), covariance_type='full',\
                            init_params='random', verbose_interval=1, verbose=50, random_state=5) 
img_model.fit(img_data)

sys.stdout = default_stdout
log_buffer.seek(0)
print(log_buffer.read())
# Out:
# Initialization 0
#   Iteration 1	 time lapse 0.00638s	 ll change inf
#   Iteration 2	 time lapse 0.00410s	 ll change 0.00241
#   Iteration 3	 time lapse 0.00273s	 ll change 0.00983
#   Iteration 4	 time lapse 0.00285s	 ll change 0.02907
#   Iteration 5	 time lapse 0.00277s	 ll change 0.05774
#   Iteration 6	 time lapse 0.00343s	 ll change 0.07684
#   Iteration 7	 time lapse 0.00326s	 ll change 0.06674
#   Iteration 8	 time lapse 0.00246s	 ll change 0.04468
#   Iteration 9	 time lapse 0.00256s	 ll change 0.03135
#   Iteration 10	 time lapse 0.00269s	 ll change 0.02354
#   Iteration 11	 time lapse 0.00288s	 ll change 0.01666
#   Iteration 12	 time lapse 0.00390s	 ll change 0.01094
#   Iteration 13	 time lapse 0.00319s	 ll change 0.00711
#   Iteration 14	 time lapse 0.00298s	 ll change 0.00495
#   Iteration 15	 time lapse 0.00295s	 ll change 0.00373
#   Iteration 16	 time lapse 0.00280s	 ll change 0.00292
#   Iteration 17	 time lapse 0.01302s	 ll change 0.00230
#   Iteration 18	 time lapse 0.00336s	 ll change 0.00179
#   Iteration 19	 time lapse 0.00360s	 ll change 0.00136
#   Iteration 20	 time lapse 0.00365s	 ll change 0.00102
#   Iteration 21	 time lapse 0.00280s	 ll change 0.00076
# Initialization converged: True	 time lapse 0.07838s	 ll -14.00783

# %%
# -14.00749

# %% [markdown]
# The following sections will evaluate the results by asking the following questions:
#
# * **Convergence**: How did the log likelihood change across iterations? Did the algorithm achieve convergence?
# * **Uncertainty**: How did cluster assignment and uncertainty evolve?
# * **Interpretability**: Can we view some example images from each cluster? Do these clusters correspond to known image categories?

# %% [markdown]
# ### Evaluating convergence
#
# Let's start by plotting the log likelihood at each iteration - we know that the EM algorithm guarantees that the log likelihood can only increase (or stay the same) after each iteration, so if our implementation is correct then we should see an increasing function.

# %%
# Nitty gritty details that aren't that useful. Used to extract the log likelihood changes from verbose output.
log_buffer.seek(0)
buffer_text = log_buffer.read()#.strip().split("\n")[:-1]
#print(log[-2].split("ll"))
# final_ll = float(log[-1].split("ll")[-1].strip())
# # ignore first line and first change (inf)
# changes = [float(l.split("ll change")[-1].strip()) for l in log[1:-1]]
# current_ll = final_ll
# backward_ll = []
# for c in changes[::-1]:
#     current_ll = current_ll - c
#     backward_ll.append(current_ll)
# ll = backward_ll[::-1] + [final_ll]
# use regex to get all number then replace ".-" with "" then check whether those numberic
loglikelihoods_num = np.array([float(x) for x in re.findall("-?\d+\.\d+.", buffer_text) if re.sub(r"[-\.]", "", x).isnumeric()])
# [::-1]  reverse np array, cumsum: cumulate sum, loglikelihoods_num[-1] 
# is last loglikelihood, -loglikelihoods_num[::-1][1:] negative of inverse of changing
ll = np.cumsum(np.append(loglikelihoods_num[-1], -loglikelihoods_num[::-1][1:]))[:-1][::-1] 
ll
# Out:
# array([-14.20904, -14.18431, -14.16801, -14.15138, -14.13425, -14.12025,
#        -14.10936, -14.09931, -14.08719, -14.07571, -14.06693, -14.06051,
#        -14.05521, -14.04963, -14.04367, -14.03868, -14.035  , -14.03226,
#        -14.03   , -14.02784, -14.02546, -14.02278, -14.01998, -14.01727,
#        -14.01476, -14.01257, -14.01079, -14.00944, -14.00845])

# %%
#ll = out['loglik']
plt.plot(range(len(ll)),ll,linewidth=4)
plt.xlabel('Iteration')
plt.ylabel('Log-likelihood')
plt.rcParams.update({'font.size':16})
plt.tight_layout()

# %% [markdown]
# The log likelihood increases so quickly on the first few iterations that we can barely see the plotted line. Let's plot the log likelihood after the first three iterations to get a clearer view of what's going on:

# %%
plt.figure()
plt.plot(range(3,len(ll)),ll[3:],linewidth=4)
plt.xlabel('Iteration')
plt.ylabel('Log-likelihood')
plt.rcParams.update({'font.size':16})
plt.tight_layout()

# %% [markdown]
# ### Evaluating uncertainty
#
# Next we'll explore the evolution of cluster assignment and uncertainty. Remember that the EM algorithm represents uncertainty about the cluster assignment of each data point through the responsibility matrix. Rather than making a 'hard' assignment of each data point to a single cluster, the algorithm computes the responsibility of each cluster for each data point, where the responsibility corresponds to our certainty that the observation came from that cluster.
#
# We can track the evolution of the responsibilities across iterations to see how these 'soft' cluster assignments change as the algorithm fits the Gaussian mixture model to the data; one good way to do this is to plot the data and color each point according to its cluster responsibilities. Our data are three-dimensional, which can make visualization difficult, so to make things easier we will plot the data using only two dimensions, taking just the [R G], [G B] or [R B] values instead of the full [R G B] measurement for each observation.
#
# **Note: this code is using image loaded from imshow as-is, which is in BGR. Modify it if you have formatted to a different form such as RGB.**

# %%
import colorsys
def plot_responsibilities_in_RB(img, resp, title):
    N, K = resp.shape
    
    HSV_tuples = [(x*1.0/K, 0.5, 0.9) for x in range(K)]
    RGB_tuples = list(map(lambda x: colorsys.hsv_to_rgb(*x), HSV_tuples))
    
    # imgread values is actually BGR
    B, G, R = *img.T,
    #R = img['red']
    #B = img['blue']
    resp_by_img_int = [[resp[n][k] for k in range(K)] for n in range(N)]
    cols = [tuple(np.dot(resp_by_img_int[n], np.array(RGB_tuples))) for n in range(N)]

    plt.figure()
    for n in range(len(R)):
        plt.plot(R[n], B[n], 'o', c=cols[n])
    plt.title(title)
    plt.xlabel('R value')
    plt.ylabel('B value')
    plt.rcParams.update({'font.size':16})
    plt.tight_layout()

# %% [markdown]
# To begin, we will visualize what happens when each data has random responsibilities.

# %%
responsibilities = img_model.predict_proba(img_data)
N, K = responsibilities.shape #out['resp'].shape
random_resp = np.random.dirichlet(np.ones(K), N)
plot_responsibilities_in_RB(img_data, random_resp, 'Random responsibilities')

# %% [markdown]
# We now use the above plotting function to visualize the responsibilities in the last iteration. We will see there are fewer unique colors; this indicates that there is more certainty that each point belongs to one of the four components in the model.

# %%
#out = EM(img_data, init_means, init_covariances, init_weights, maxiter=20)
plot_responsibilities_in_RB(img_data, responsibilities, 'Last iteration')

# %% [markdown]
# Plotting the responsibilities over time in [R B] space shows a meaningful change in cluster assignments over the course of the algorithm's execution. While the clusters look significantly better organized at the end of the algorithm than they did at the start, it appears from our plot that they are still not very well separated. We note that this is due in part our decision to plot 3D data in a 2D space; everything that was separated along the G axis is now "squashed" down onto the flat [R B] plane. If we were to plot the data in full [R G B] space, then we would expect to see further separation of the final clusters.  We'll explore the cluster interpretability more in the next section.

# %% [markdown]
# ### Interpreting each cluster

# %% [markdown]
# Let's dig into the clusters obtained from our EM implementation. Recall that our goal in this section is to cluster images based on their RGB values. We can evaluate the quality of our clustering by taking a look at a few images that 'belong' to each cluster. We hope to find that the clusters discovered by our EM algorithm correspond to different image categories - in this case, we know that our images came from four categories ('cloudy sky', 'rivers', 'sunsets', and 'trees and forests'), so we would expect to find that each component of our fitted mixture model roughly corresponds to one of these categories.
#
# If we want to examine some example images from each cluster, we first need to consider how we can determine cluster assignments of the images from our algorithm output. This was easy with k-means - every data point had a 'hard' assignment to a single cluster, and all we had to do was find the cluster center closest to the data point of interest. Here, our clusters are described by probability distributions (specifically, Gaussians) rather than single points, and our model maintains some uncertainty about the cluster assignment of each observation.
#
# One way to phrase the question of cluster assignment for mixture models is as follows: how do we calculate the distance of a point from a distribution? Note that simple Euclidean distance might not be appropriate since (non-scaled) Euclidean distance doesn't take direction into account.  For example, if a Gaussian mixture component is very stretched in one direction but narrow in another, then a data point one unit away along the 'stretched' dimension has much higher probability (and so would be thought of as closer) than a data point one unit away along the 'narrow' dimension.
#
# In fact, the correct distance metric to use in this case is known as [Mahalanobis distance](https://en.wikipedia.org/wiki/Mahalanobis_distance). For a Gaussian distribution, this distance is proportional to the square root of the negative log likelihood. This makes sense intuitively - reducing the Mahalanobis distance of an observation from a cluster is equivalent to increasing that observation's probability according to the Gaussian that is used to represent the cluster. This also means that we can find the cluster assignment of an observation by taking the Gaussian component for which that observation scores highest. We'll use this fact to find the top examples that are 'closest' to each cluster.

# %% [markdown]
# Now we calculate cluster assignments for the entire image dataset using the result of running EM above:

# %%
responsibilities = img_model.predict_proba(img_data)
assignments = np.argmax(responsibilities, axis=-1)
probs = np.max(responsibilities, axis=-1)
    
clustered_images = pd.DataFrame({'assignments': assignments, 'probs': probs, 'image': data['raw_image']})

# %% [markdown]
# We'll use the `clustered_images` DataFrame to find the top images from each cluster by sorting the datapoints within each cluster by their score under that cluster (stored in `probs`). We can plot the corresponding images in the original data using show().
#
# Create a function that returns the top 5 images assigned to a given category in our data (HINT: use DataFrame's `.nlargest` to find the k top values according to specified column).

# %%
def get_top_images(clustered_images, cluster_idx, k=5):
    # YOUR CODE HERE
    select_cluster = clustered_images[clustered_images['assignments']==cluster_idx]
    top_images = select_cluster.nlargest(k, 'probs')
    return top_images['image']

# %% [markdown]
# Use this function to show the top 5 images in each cluster.

# %%
# images are plotted in 
fig, axes = plt.subplots(2 * 2, 3 * 2, sharex="col", sharey="row")
for component_id in range(0, 4):
    offset_x, offset_y = (component_id % 2, component_id // 2)
    images = get_top_images(clustered_images, component_id, k=5)
    for i, img in enumerate(images):
        img_offset_x, img_offset_y = i % 2, i // 2
        ax = axes[2*offset_x + img_offset_x, 3*offset_y + img_offset_y]
        ax.imshow(img)
[ax.axis("off") for subaxes in axes for ax in subaxes]
#fig.tight_layout()
pass

# %% [markdown]
# These look pretty good! Our algorithm seems to have done a good job overall at 'discovering' the four categories that from which our image data was drawn. It seems to have had the most difficulty in distinguishing between rivers and cloudy skies, probably due to the similar color profiles of images in these categories; if we wanted to achieve better performance on distinguishing between these categories, we might need a richer representation of our data than simply the average [R G B] values for each image.

# %% [markdown]
# __Quiz Question:__ Which of the following images are *not* in the list of top 5 images in the first cluster?

# %% [markdown]
# ![Images](chosen_images.png)
